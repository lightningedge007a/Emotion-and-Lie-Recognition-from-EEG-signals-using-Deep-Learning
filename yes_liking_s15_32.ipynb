# %%
# !nvidia-smi
# Out:
# Sat Nov 16 20:08:41 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 441.20       Driver Version: 441.20       CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 166... WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   40C    P3     9W /  N/A |    153MiB /  6144MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import sys
# import sklearn
from sklearn.metrics import precision_score, recall_score, roc_auc_score, f1_score, confusion_matrix, roc_curve, auc
import os
import pandas as pd
import pickle
import tensorflow as tf
import numpy as np
import time
import math
import scipy.io as sio

from keras.layers import Conv2D, Dense, Flatten, ELU, BatchNormalization, LSTMCell, StackedRNNCells,\
    RNN, Permute, Dropout, Concatenate, Input, concatenate, Lambda, Reshape, Lambda

from keras import backend as K
from keras.utils import plot_model
from keras.models import Sequential, Model
from keras.layers.merge import add
from keras.callbacks import TensorBoard

from keras import callbacks

from keras import regularizers

from keras.callbacks import ModelCheckpoint

import datetime

from keras.models import load_model
import matplotlib.pyplot as plt

import gc
# Out:
# Using TensorFlow backend.

# %%
data_files=[]
for i in range(1,33):
    if(1<=i<=9):
        s='s0'+str(i)
    else:
        s='s'+str(i)
    data_files.append(s)
print(len(data_files),data_files)

# emotions=['arousal','valence']

#baseline_preprocessing=['yes','no']
emotions=['liking']

baseline_preprocessing=['yes']
# Out:
# 32 ['s01', 's02', 's03', 's04', 's05', 's06', 's07', 's08', 's09', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20', 's21', 's22', 's23', 's24', 's25', 's26', 's27', 's28', 's29', 's30', 's31', 's32']

# %%
# data_files=[data_files[0]]
data_files,emotions,baseline_preprocessing
# Out:
# (['s01',
#   's02',
#   's03',
#   's04',
#   's05',
#   's06',
#   's07',
#   's08',
#   's09',
#   's10',
#   's11',
#   's12',
#   's13',
#   's14',
#   's15',
#   's16',
#   's17',
#   's18',
#   's19',
#   's20',
#   's21',
#   's22',
#   's23',
#   's24',
#   's25',
#   's26',
#   's27',
#   's28',
#   's29',
#   's30',
#   's31',
#   's32'],
#  ['liking'],
#  ['yes'])

# %%
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)
        

# Example
createFolder('./data/dd')

# %%
data_files[15:]
# Out:
# ['s16',
#  's17',
#  's18',
#  's19',
#  's20',
#  's21',
#  's22',
#  's23',
#  's24',
#  's25',
#  's26',
#  's27',
#  's28',
#  's29',
#  's30',
#  's31',
#  's32']

# %%
data_files=data_files[15:]
data_files
# Out:
# ['s16',
#  's17',
#  's18',
#  's19',
#  's20',
#  's21',
#  's22',
#  's23',
#  's24',
#  's25',
#  's26',
#  's27',
#  's28',
#  's29',
#  's30',
#  's31',
#  's32']

# %%
np.random.seed(32)

window_size = 128

cnn_suffix ='.mat_win_128_cnn_dataset.pkl'
rnn_suffix ='.mat_win_128_rnn_dataset.pkl'
label_suffix ='.mat_win_128_labels.pkl'

for with_or_without in baseline_preprocessing:
    for arousal_or_valence in emotions:
        for data_file in data_files:
            
            gc.collect()
            
            print('---------------------------------------------------')
            print(with_or_without+' '+arousal_or_valence+' '+data_file)
            print('---------------------------------------------------\n')

            #data_file    ='s17'
            #arousal_or_valence = 'valence'
            #with_or_without = 'yes'

            dataset_dir = 'deap_shuffled_data/'+with_or_without+'_'+arousal_or_valence+'/'
            ###load training set
            try:
                with open(dataset_dir + data_file + cnn_suffix, "rb") as fp:
                    cnn_datasets = pickle.load(fp)
                with open(dataset_dir + data_file + rnn_suffix, "rb") as fp:
                    rnn_datasets = pickle.load(fp)
                with open(dataset_dir + data_file + label_suffix, "rb") as fp:
                    labels = pickle.load(fp)
                    labels = np.transpose(labels)
                    print("loaded shape:",labels.shape)
            except:
                continue
            lables_backup = labels

            print(cnn_datasets.shape)
            print(rnn_datasets.shape)
            print(labels.shape)

            #print("cnn_dataset shape before reshape:", np.shape(cnn_datasets))
            # cnn_datasets = cnn_datasets.reshape(len(cnn_datasets), window_size, 9,9, 1)
            #print("cnn_dataset shape after reshape:", np.shape(cnn_datasets))
            one_hot_labels = np.array(list(pd.get_dummies(labels)))

            labels = np.asarray(pd.get_dummies(labels), dtype=np.int8)

            print(labels.shape)
            # shuffle data
            index = np.array(range(0, len(labels)))
            np.random.shuffle(index)

            cnn_datasets   = cnn_datasets[index]
            rnn_datasets   = rnn_datasets[index]
            labels  = labels[index]

            print(cnn_datasets.shape)
            print(rnn_datasets.shape)
            print(labels.shape)

            #print("**********(" + time.asctime(time.localtime(time.time())) + ") Load and Split dataset End **********\n")
            #print("**********(" + time.asctime(time.localtime(time.time())) + ") Define parameters and functions Begin: **********\n")
            print('cnn_datasets.shape,rnn_datasets.shape,labels.shape : ',cnn_datasets.shape,rnn_datasets.shape,labels.shape)
            #important
            cnn_datasets=cnn_datasets.reshape(2400,9,9,-1)# imp
            print(cnn_datasets.shape)
            print('cnn_datasets.shape : ',cnn_datasets.shape)







            print('========================Train / Test Shapes==============================')



            fold=10
            curr_fold=0
            #for curr_fold in range(fold): # kernel dies
                
            #   print('curr_fold / fold : ',curr_fold,' / ',fold)


            max_acc_acc_list=[]

            max_acc_loss_list=[]


            min_loss_acc_list=[]

            min_loss_loss_list=[]

            fold_size = cnn_datasets.shape[0]//fold
            indexes_list = [i for i in range(len(cnn_datasets))]
            indexes = np.array(indexes_list)
            split_list = [i for i in range(curr_fold*fold_size,(curr_fold+1)*fold_size)]
            split = np.array(split_list)

            cnn_test = cnn_datasets[split] 
            labels_test = labels[split]
            rnn_test = rnn_datasets[split]

            split = np.array(list(set(indexes_list)^set(split_list)))

            cnn_train = cnn_datasets[split]
            rnn_train = rnn_datasets[split]
            labels_train = labels[split]

            # train_sample = labels_train.shape[0]
            # print("training examples:", train_sample)
            # test_sample = labels_test.shape[0]
            # print("test examples    :",test_sample)
            print(cnn_test.shape,rnn_test.shape,cnn_train.shape,rnn_train.shape)

            print('================================ DNN ============================================')

            input_cnn=Input(shape=(9,9,128))

            print('input_cnn: ',input_cnn.shape)

            conv1=Conv2D(32,
                          kernel_size=(4,4),
                          strides=(1,1),
                          padding='same',
                          input_shape=(9,9,128)
                         )(input_cnn)


            bn1=BatchNormalization()(conv1)

            elu1=ELU()(bn1)

            print('elu1: ',elu1.shape)
            #?,9,9,32
            conv2=Conv2D(64,
                          kernel_size=(4,4),
                          strides=(1,1),
                          padding='same'
                         )(elu1)

            bn2=BatchNormalization()(conv2)

            elu2=ELU()(bn2)

            print('elu2: ',elu2.shape)
            #?,9,9,64

            conv3=Conv2D(128,
                          kernel_size=(4,4),
                          strides=(1,1),
                          padding='same'
                         )(elu2)

            bn3=BatchNormalization()(conv3)

            elu3=ELU()(bn3)


            print('elu3: ',elu3.shape)
            #?,9,9,128

            # mc.add(Flatten())
            # mc.add(Lambda(lambda x:x,output_shape=(9,9,32*4*128)))
            # mc.add(Lambda(K.reshape((-1,9,9,32*4*128))))
            reshape1=Reshape((9,9,-1))(elu3)


            print('reshape1: ',reshape1.shape)
            #?,9,9,32*4*128

            conv4=Conv2D(13,#32*4*128,
                          kernel_size=(1,1),
                          strides=(1,1),
                          padding='same'
                         )(reshape1)

            bn4=BatchNormalization()(conv4)

            elu4=ELU()(bn4)


            print('elu4: ',elu4.shape)
            #?,9,9,13 #32*4*128

            # mc.add(Flatten())

            # mc.add(Lambda(lambda x:x,output_shape=([13*9*9])))
            # mc.add(Lambda(K.reshape((None,13*9*9))))
            reshape2=Reshape(([13*9*9]))(elu4)


            print('reshape2: ',reshape2.shape)




            cnn_out_fuse=reshape2


            # cube=K.reshape(e3,(-1,9,9,32*4*128))#(e3)


            # flat=K.reshape(e4,(-1,13*9*9))#(e4) #1053

            # rnn_in=K.placeholder(shape=(None,128,32))
            # rnn_in=tf.convert_to_tensor(rnn_datasets,dtype='float32')


            # rnn_in.get_shape().as_list()

            # rnn_in=K.placeholder(shape=(None,128,32))
            # rnn_in_flat=K.reshape(rnn_in,[-1,32])

            # print('rnn_in ',rnn_in.shape)

            input_rnn=Input(shape=(128,32))
            print('input_rnn',input_rnn.shape)

            rnn_in_flat=Reshape((-1,32))(input_rnn)
            print('rnn_in_flat',rnn_in_flat.shape)
            # rnn_in_flat = Lambda(lambda x:x[:,0])(input_rnn)

            # rnn_fc_in1 =Dense(32)(rnn_in_flat)
            rnn_fc_in1 =Dense(1024)(rnn_in_flat)
            rnn_fc_in=ELU()(rnn_fc_in1)
            print('rnn_fc_in',rnn_fc_in.shape)

            # rnn_fc_in =Dense(1024)(input_rnn)

            # lstm_in=Reshape((-1,128,1024))(rnn_fc_in)
            lstm_in=Reshape((-1,1024))(rnn_fc_in)
            print('lstm_in',lstm_in.shape)

            cells=[]

            for i in range(2):
                cell=LSTMCell(32,unit_forget_bias=True,dropout=0.5)#'forget_bias'=1.0,'state_is_tuple'=True
                cells.append(cell)
            #     print(cell.shape)

            # lstm_cell=StackedRNNCells(cells)
            lstm_cell=RNN(cells)(lstm_in)
            # print(lstm_cell.shape)
            # op,states=RNN(cells)(lstm_in)
            print('lstm_cell',lstm_cell.shape)
            # output=K.transpose_shape((1,0,2),lstm_cell)
            # output=Permute((1,0,2))(lstm_cell)
            # output.reshape()
            output=lstm_cell
            print('output',output.shape)
            rnn_output=output[-1]
            # rnn_output

            print('rnn_output',rnn_output.shape)
            # shape_rnn_out=rnn_output.get_shape().as_list()
            lstm_fc_out=Dense(1024)(output)#shape_rnn_out[1]

            print('lstm_fc_out',lstm_fc_out.shape)


            # lstm_fc_out_2=Dense(1053)(lstm_fc_out)#shape_rnn_out[1]



            lstm_fc_drop=Dropout(0.5)(lstm_fc_out)
            # lstm_fc_drop
            print('lstm_fc_drop',lstm_fc_drop.shape)

            # fuse_cnn_rnn=add([cnn_out_fuse,lstm_fc_drop])

            fuse_cnn_rnn=concatenate([cnn_out_fuse,lstm_fc_drop])
            print('fuse_cnn_rnn ',fuse_cnn_rnn.shape)
            y=Dense(2,activation='softmax')(fuse_cnn_rnn) ## ,activity_regularizer=regularizers.l2(0.5)
            print(y.shape)
            y_pred=K.argmax(y,1)
            # y_pred=K.argmax(K.softmax(y))
            # y_posi=K.softmax(y)
            print('y ',y)


            directory_le007a='./lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file
            try:
                if not os.path.exists(directory_le007a):
                    os.makedirs(directory_le007a)
            except OSError:
                print ('Error: Creating directory. ' +  directory_le007a)



            model=Model(inputs=[input_cnn,input_rnn],outputs=y)
            model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

            print('Model : ',with_or_without+'_'+arousal_or_valence+'_'+data_file+'_'+str(curr_fold)+'_fold')
            print(model.summary())

            m_val_acc=ModelCheckpoint('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'max_acc_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.h5',monitor='val_accuracy',mode='max',verbose=1,save_best_only=True)
            m_val_loss=ModelCheckpoint('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'min_loss_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.h5',monitor='val_loss',mode='min',verbose=1,save_best_only=True)


            tb_log_dir='lightningedge007a_results\\'+with_or_without+'\\'+arousal_or_valence+'\\'+data_file+'\\'+'logs_'+with_or_without+'_'+arousal_or_valence+'_'+data_file
            #tb_log_dir='lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'logs_'+with_or_without+'_'+arousal_or_valence+'_'+data_file

            createFolder(tb_log_dir)


            #log_dir='lightningedge007a_results\\'+with_or_without+'\\'+arousal_or_valence+'\\'+data_file+'\\'+'logs_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'_'+str(curr_fold)+'_fold\\' #datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
            tensorboard_callback = callbacks.TensorBoard(log_dir=tb_log_dir)#, histogram_freq=1)

            plotpicture=plot_model(model, to_file='lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'model_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.png', show_shapes=True)

            
            
            gc.collect()
            
            

            history=model.fit([cnn_train,rnn_train],labels_train,batch_size=128,epochs=50,callbacks=[tensorboard_callback,m_val_acc,m_val_loss],validation_split=0.2)


            #Plot values
            plt.plot(history.history['accuracy'])
            plt.plot(history.history['val_accuracy'])
            plt.title('max_acc_'+with_or_without+'_'+arousal_or_valence+'_'+data_file)
            plt.ylabel('Accuracy')
            plt.xlabel('Epoch')
            plt.legend(['Train', 'Validation'], loc='upper right',bbox_to_anchor=(1.3,1))
            plt.savefig('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'max_acc_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.png',bbox_inches='tight')
            #plt.show()
            plt.close()


            # Plot training & validation loss values
            plt.plot(history.history['loss'])
            plt.plot(history.history['val_loss'])
            plt.title('min_loss_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'_'+str(curr_fold)+'_fold')
            plt.ylabel('Loss')
            plt.xlabel('Epoch')
            plt.legend(['Train', 'Validation'], loc='upper right',bbox_to_anchor=(1.3,1))
            plt.savefig('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'min_loss_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.png',bbox_inches='tight')
            #plt.show()
            plt.close()

            vam=load_model('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'max_acc_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.h5')
            vlm=load_model('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'min_loss_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.h5')
            # pred_labels=vam()
            vam_eval=vam.evaluate([cnn_test,rnn_test],labels_test)
            print('max acc: ',vam_eval)
            vlm_eval=vlm.evaluate([cnn_test,rnn_test],labels_test)
            print('min loss: ',vlm_eval)


            max_acc_acc_list.append(vam_eval[1])

            max_acc_loss_list.append(vam_eval[0])


            min_loss_acc_list.append(vlm_eval[1])

            min_loss_loss_list.append(vlm_eval[0])

            pickle.dump(max_acc_acc_list,open('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'max_acc_acc_list_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.pkl','wb'))

            pickle.dump(max_acc_loss_list,open('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'max_acc_loss_list_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.pkl','wb'))


            pickle.dump(min_loss_acc_list,open('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'min_loss_acc_list_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.pkl','wb'))

            pickle.dump(min_loss_loss_list,open('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'min_loss_loss_list_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.pkl','wb'))
            
            
            gc.collect()
# Out:
# ---------------------------------------------------
# yes liking s16
# ---------------------------------------------------
#
# loaded shape: (2400,)
# (2400, 128, 9, 9)
# (2400, 128, 32)
# (2400,)
# (2400, 2)
# (2400, 128, 9, 9)
# (2400, 128, 32)
# (2400, 2)
# cnn_datasets.shape,rnn_datasets.shape,labels.shape :  (2400, 128, 9, 9) (2400, 128, 32) (2400, 2)
# (2400, 9, 9, 128)
# cnn_datasets.shape :  (2400, 9, 9, 128)
# ========================Train / Test Shapes==============================
# (240, 9, 9, 128) (240, 128, 32) (2160, 9, 9, 128) (2160, 128, 32)
# ================================ DNN ============================================
# input_cnn:  (None, 9, 9, 128)
# elu1:  (None, 9, 9, 32)
# elu2:  (None, 9, 9, 64)
# elu3:  (None, 9, 9, 128)
# reshape1:  (None, 9, 9, None)
# elu4:  (None, 9, 9, 13)
# reshape2:  (None, 1053)
# input_rnn (None, 128, 32)
# rnn_in_flat (None, None, 32)
# rnn_fc_in (None, 128, 1024)
# lstm_in (None, None, 1024)
# lstm_cell (None, 32)
# output (None, 32)
# rnn_output (32,)
# lstm_fc_out (None, 1024)
# lstm_fc_drop (None, 1024)
# fuse_cnn_rnn  (None, 2077)
# (None, 2)
# y  Tensor("dense_3/Softmax:0", shape=(None, 2), dtype=float32)
# Model :  yes_liking_s16_0_fold
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 9, 9, 128)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 9, 9, 32)     65568       input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 9, 9, 32)     128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# elu_1 (ELU)                     (None, 9, 9, 32)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 9, 9, 64)     32832       elu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 9, 9, 64)     256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# elu_2 (ELU)                     (None, 9, 9, 64)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 9, 9, 128)    131200      elu_2[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 128, 32)      0
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 9, 9, 128)    512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 128, 32)      0           input_2[0][0]
# __________________________________________________________________________________________________
# elu_3 (ELU)                     (None, 9, 9, 128)    0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128, 1024)    33792       reshape_3[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 9, 9, 128)    0           elu_3[0][0]
# __________________________________________________________________________________________________
# elu_5 (ELU)                     (None, 128, 1024)    0           dense_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 9, 9, 13)     1677        reshape_1[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 128, 1024)    0           elu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 9, 9, 13)     52          conv2d_4[0][0]
# __________________________________________________________________________________________________
# rnn_1 (RNN)                     (None, 32)           143616      reshape_4[0][0]
# __________________________________________________________________________________________________
# elu_4 (ELU)                     (None, 9, 9, 13)     0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1024)         33792       rnn_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1053)         0           elu_4[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           dense_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2077)         0           reshape_2[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            4156        concatenate_1[0][0]
# ==================================================================================================
# Total params: 447,581
# Trainable params: 447,107
# Non-trainable params: 474
# __________________________________________________________________________________________________
# None
# Train on 1728 samples, validate on 432 samples
# Epoch 1/50
#  256/1728 [===>..........................] - ETA: 20s - loss: 0.7575 - accuracy: 0.6602
# C:\Users\ABHISHEK_VERMA\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (10.215414). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1728/1728 [==============================] - 27s 16ms/step - loss: 0.3303 - accuracy: 0.8623 - val_loss: 0.1315 - val_accuracy: 0.9606
#
# Epoch 00001: val_accuracy improved from -inf to 0.96065, saving model to lightningedge007a_results/yes/liking/s16/max_acc_yes_liking_s16.h5
#
# Epoch 00001: val_loss improved from inf to 0.13149, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 2/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0498 - accuracy: 0.9844 - val_loss: 0.0841 - val_accuracy: 0.9722
#
# Epoch 00002: val_accuracy improved from 0.96065 to 0.97222, saving model to lightningedge007a_results/yes/liking/s16/max_acc_yes_liking_s16.h5
#
# Epoch 00002: val_loss improved from 0.13149 to 0.08414, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 3/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0140 - accuracy: 0.9994 - val_loss: 0.0668 - val_accuracy: 0.9745
#
# Epoch 00003: val_accuracy improved from 0.97222 to 0.97454, saving model to lightningedge007a_results/yes/liking/s16/max_acc_yes_liking_s16.h5
#
# Epoch 00003: val_loss improved from 0.08414 to 0.06683, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 4/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0630 - val_accuracy: 0.9745
#
# Epoch 00004: val_accuracy did not improve from 0.97454
#
# Epoch 00004: val_loss improved from 0.06683 to 0.06303, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 5/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0543 - val_accuracy: 0.9769
#
# Epoch 00005: val_accuracy improved from 0.97454 to 0.97685, saving model to lightningedge007a_results/yes/liking/s16/max_acc_yes_liking_s16.h5
#
# Epoch 00005: val_loss improved from 0.06303 to 0.05432, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 6/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0494 - val_accuracy: 0.9792
#
# Epoch 00006: val_accuracy improved from 0.97685 to 0.97917, saving model to lightningedge007a_results/yes/liking/s16/max_acc_yes_liking_s16.h5
#
# Epoch 00006: val_loss improved from 0.05432 to 0.04936, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 7/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.7448e-04 - accuracy: 1.0000 - val_loss: 0.0478 - val_accuracy: 0.9792
#
# Epoch 00007: val_accuracy did not improve from 0.97917
#
# Epoch 00007: val_loss improved from 0.04936 to 0.04779, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 8/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 7.8851e-04 - accuracy: 1.0000 - val_loss: 0.0458 - val_accuracy: 0.9792
#
# Epoch 00008: val_accuracy did not improve from 0.97917
#
# Epoch 00008: val_loss improved from 0.04779 to 0.04579, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 9/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 6.7273e-04 - accuracy: 1.0000 - val_loss: 0.0443 - val_accuracy: 0.9792
#
# Epoch 00009: val_accuracy did not improve from 0.97917
#
# Epoch 00009: val_loss improved from 0.04579 to 0.04429, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 10/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.9189e-04 - accuracy: 1.0000 - val_loss: 0.0431 - val_accuracy: 0.9792
#
# Epoch 00010: val_accuracy did not improve from 0.97917
#
# Epoch 00010: val_loss improved from 0.04429 to 0.04312, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 11/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.2434e-04 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9792
#
# Epoch 00011: val_accuracy did not improve from 0.97917
#
# Epoch 00011: val_loss improved from 0.04312 to 0.04208, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 12/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.6248e-04 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9792
#
# Epoch 00012: val_accuracy did not improve from 0.97917
#
# Epoch 00012: val_loss improved from 0.04208 to 0.04140, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 13/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 4.1193e-04 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9792
#
# Epoch 00013: val_accuracy did not improve from 0.97917
#
# Epoch 00013: val_loss improved from 0.04140 to 0.04072, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 14/50
# 1728/1728 [==============================] - 4s 3ms/step - loss: 3.7479e-04 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9792
#
# Epoch 00014: val_accuracy did not improve from 0.97917
#
# Epoch 00014: val_loss improved from 0.04072 to 0.04003, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 15/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.4247e-04 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9792
#
# Epoch 00015: val_accuracy did not improve from 0.97917
#
# Epoch 00015: val_loss improved from 0.04003 to 0.03973, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 16/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.0828e-04 - accuracy: 1.0000 - val_loss: 0.0389 - val_accuracy: 0.9792
#
# Epoch 00016: val_accuracy did not improve from 0.97917
#
# Epoch 00016: val_loss improved from 0.03973 to 0.03893, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 17/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.8231e-04 - accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 0.9792
#
# Epoch 00017: val_accuracy did not improve from 0.97917
#
# Epoch 00017: val_loss improved from 0.03893 to 0.03875, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 18/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.5957e-04 - accuracy: 1.0000 - val_loss: 0.0382 - val_accuracy: 0.9792
#
# Epoch 00018: val_accuracy did not improve from 0.97917
#
# Epoch 00018: val_loss improved from 0.03875 to 0.03816, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 19/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.3781e-04 - accuracy: 1.0000 - val_loss: 0.0377 - val_accuracy: 0.9792
#
# Epoch 00019: val_accuracy did not improve from 0.97917
#
# Epoch 00019: val_loss improved from 0.03816 to 0.03771, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 20/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.1967e-04 - accuracy: 1.0000 - val_loss: 0.0377 - val_accuracy: 0.9792
#
# Epoch 00020: val_accuracy did not improve from 0.97917
#
# Epoch 00020: val_loss improved from 0.03771 to 0.03766, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 21/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.0554e-04 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9792
#
# Epoch 00021: val_accuracy did not improve from 0.97917
#
# Epoch 00021: val_loss improved from 0.03766 to 0.03711, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 22/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.9195e-04 - accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 0.9792
#
# Epoch 00022: val_accuracy did not improve from 0.97917
#
# Epoch 00022: val_loss improved from 0.03711 to 0.03686, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 23/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.7810e-04 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9792
#
# Epoch 00023: val_accuracy did not improve from 0.97917
#
# Epoch 00023: val_loss improved from 0.03686 to 0.03655, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 24/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.6889e-04 - accuracy: 1.0000 - val_loss: 0.0362 - val_accuracy: 0.9815
#
# Epoch 00024: val_accuracy improved from 0.97917 to 0.98148, saving model to lightningedge007a_results/yes/liking/s16/max_acc_yes_liking_s16.h5
#
# Epoch 00024: val_loss improved from 0.03655 to 0.03618, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 25/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.5786e-04 - accuracy: 1.0000 - val_loss: 0.0359 - val_accuracy: 0.9815
#
# Epoch 00025: val_accuracy did not improve from 0.98148
#
# Epoch 00025: val_loss improved from 0.03618 to 0.03588, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 26/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.4747e-04 - accuracy: 1.0000 - val_loss: 0.0356 - val_accuracy: 0.9815
#
# Epoch 00026: val_accuracy did not improve from 0.98148
#
# Epoch 00026: val_loss improved from 0.03588 to 0.03560, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 27/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.3824e-04 - accuracy: 1.0000 - val_loss: 0.0354 - val_accuracy: 0.9815
#
# Epoch 00027: val_accuracy did not improve from 0.98148
#
# Epoch 00027: val_loss improved from 0.03560 to 0.03539, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 28/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.3171e-04 - accuracy: 1.0000 - val_loss: 0.0353 - val_accuracy: 0.9815
#
# Epoch 00028: val_accuracy did not improve from 0.98148
#
# Epoch 00028: val_loss improved from 0.03539 to 0.03535, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 29/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.2406e-04 - accuracy: 1.0000 - val_loss: 0.0351 - val_accuracy: 0.9815
#
# Epoch 00029: val_accuracy did not improve from 0.98148
#
# Epoch 00029: val_loss improved from 0.03535 to 0.03507, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 30/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.1791e-04 - accuracy: 1.0000 - val_loss: 0.0349 - val_accuracy: 0.9815
#
# Epoch 00030: val_accuracy did not improve from 0.98148
#
# Epoch 00030: val_loss improved from 0.03507 to 0.03493, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 31/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.1050e-04 - accuracy: 1.0000 - val_loss: 0.0349 - val_accuracy: 0.9815
#
# Epoch 00031: val_accuracy did not improve from 0.98148
#
# Epoch 00031: val_loss improved from 0.03493 to 0.03488, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 32/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.0569e-04 - accuracy: 1.0000 - val_loss: 0.0347 - val_accuracy: 0.9815
#
# Epoch 00032: val_accuracy did not improve from 0.98148
#
# Epoch 00032: val_loss improved from 0.03488 to 0.03465, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 33/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.0115e-04 - accuracy: 1.0000 - val_loss: 0.0344 - val_accuracy: 0.9815
#
# Epoch 00033: val_accuracy did not improve from 0.98148
#
# Epoch 00033: val_loss improved from 0.03465 to 0.03443, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 34/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.4655e-05 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 0.9815
#
# Epoch 00034: val_accuracy did not improve from 0.98148
#
# Epoch 00034: val_loss improved from 0.03443 to 0.03435, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 35/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.1898e-05 - accuracy: 1.0000 - val_loss: 0.0342 - val_accuracy: 0.9815
#
# Epoch 00035: val_accuracy did not improve from 0.98148
#
# Epoch 00035: val_loss improved from 0.03435 to 0.03425, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 36/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 8.8477e-05 - accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 0.9815
#
# Epoch 00036: val_accuracy did not improve from 0.98148
#
# Epoch 00036: val_loss improved from 0.03425 to 0.03403, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 37/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 8.2797e-05 - accuracy: 1.0000 - val_loss: 0.0336 - val_accuracy: 0.9815
#
# Epoch 00037: val_accuracy did not improve from 0.98148
#
# Epoch 00037: val_loss improved from 0.03403 to 0.03361, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 38/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 8.0529e-05 - accuracy: 1.0000 - val_loss: 0.0336 - val_accuracy: 0.9815
#
# Epoch 00038: val_accuracy did not improve from 0.98148
#
# Epoch 00038: val_loss improved from 0.03361 to 0.03361, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 39/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 7.5427e-05 - accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 0.9815
#
# Epoch 00039: val_accuracy did not improve from 0.98148
#
# Epoch 00039: val_loss improved from 0.03361 to 0.03351, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 40/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 7.2891e-05 - accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 0.9815
#
# Epoch 00040: val_accuracy did not improve from 0.98148
#
# Epoch 00040: val_loss improved from 0.03351 to 0.03348, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 41/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.9244e-05 - accuracy: 1.0000 - val_loss: 0.0334 - val_accuracy: 0.9815
#
# Epoch 00041: val_accuracy did not improve from 0.98148
#
# Epoch 00041: val_loss improved from 0.03348 to 0.03335, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 42/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.7196e-05 - accuracy: 1.0000 - val_loss: 0.0334 - val_accuracy: 0.9815
#
# Epoch 00042: val_accuracy did not improve from 0.98148
#
# Epoch 00042: val_loss did not improve from 0.03335
# Epoch 43/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.4924e-05 - accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 0.9815
#
# Epoch 00043: val_accuracy did not improve from 0.98148
#
# Epoch 00043: val_loss improved from 0.03335 to 0.03322, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 44/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.1339e-05 - accuracy: 1.0000 - val_loss: 0.0330 - val_accuracy: 0.9815
#
# Epoch 00044: val_accuracy did not improve from 0.98148
#
# Epoch 00044: val_loss improved from 0.03322 to 0.03302, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 45/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.9797e-05 - accuracy: 1.0000 - val_loss: 0.0329 - val_accuracy: 0.9815
#
# Epoch 00045: val_accuracy did not improve from 0.98148
#
# Epoch 00045: val_loss improved from 0.03302 to 0.03288, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 46/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.7199e-05 - accuracy: 1.0000 - val_loss: 0.0327 - val_accuracy: 0.9815
#
# Epoch 00046: val_accuracy did not improve from 0.98148
#
# Epoch 00046: val_loss improved from 0.03288 to 0.03268, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 47/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.5264e-05 - accuracy: 1.0000 - val_loss: 0.0327 - val_accuracy: 0.9815
#
# Epoch 00047: val_accuracy did not improve from 0.98148
#
# Epoch 00047: val_loss did not improve from 0.03268
# Epoch 48/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.3128e-05 - accuracy: 1.0000 - val_loss: 0.0327 - val_accuracy: 0.9815
#
# Epoch 00048: val_accuracy did not improve from 0.98148
#
# Epoch 00048: val_loss did not improve from 0.03268
# Epoch 49/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.1327e-05 - accuracy: 1.0000 - val_loss: 0.0325 - val_accuracy: 0.9815
#
# Epoch 00049: val_accuracy did not improve from 0.98148
#
# Epoch 00049: val_loss improved from 0.03268 to 0.03252, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# Epoch 50/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.0378e-05 - accuracy: 1.0000 - val_loss: 0.0325 - val_accuracy: 0.9815
#
# Epoch 00050: val_accuracy did not improve from 0.98148
#
# Epoch 00050: val_loss improved from 0.03252 to 0.03246, saving model to lightningedge007a_results/yes/liking/s16/min_loss_yes_liking_s16.h5
# 240/240 [==============================] - 1s 4ms/step
# max acc:  [0.037078775993237896, 0.987500011920929]
# 240/240 [==============================] - 1s 4ms/step
# min loss:  [0.03570962904098754, 0.987500011920929]
# ---------------------------------------------------
# yes liking s17
# ---------------------------------------------------
#
# loaded shape: (2400,)
# (2400, 128, 9, 9)
# (2400, 128, 32)
# (2400,)
# (2400, 2)
# (2400, 128, 9, 9)
# (2400, 128, 32)
# (2400, 2)
# cnn_datasets.shape,rnn_datasets.shape,labels.shape :  (2400, 128, 9, 9) (2400, 128, 32) (2400, 2)
# (2400, 9, 9, 128)
# cnn_datasets.shape :  (2400, 9, 9, 128)
# ========================Train / Test Shapes==============================
# (240, 9, 9, 128) (240, 128, 32) (2160, 9, 9, 128) (2160, 128, 32)
# ================================ DNN ============================================
# input_cnn:  (None, 9, 9, 128)
# elu1:  (None, 9, 9, 32)
# elu2:  (None, 9, 9, 64)
# elu3:  (None, 9, 9, 128)
# reshape1:  (None, 9, 9, None)
# elu4:  (None, 9, 9, 13)
# reshape2:  (None, 1053)
# input_rnn (None, 128, 32)
# rnn_in_flat (None, None, 32)
# rnn_fc_in (None, 128, 1024)
# lstm_in (None, None, 1024)
# lstm_cell (None, 32)
# output (None, 32)
# rnn_output (32,)
# lstm_fc_out (None, 1024)
# lstm_fc_drop (None, 1024)
# fuse_cnn_rnn  (None, 2077)
# (None, 2)
# y  Tensor("dense_6/Softmax:0", shape=(None, 2), dtype=float32)
# Model :  yes_liking_s17_0_fold
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 9, 9, 128)    0
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 9, 9, 32)     65568       input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 9, 9, 32)     128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# elu_6 (ELU)                     (None, 9, 9, 32)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 9, 9, 64)     32832       elu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 9, 9, 64)     256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# elu_7 (ELU)                     (None, 9, 9, 64)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 9, 9, 128)    131200      elu_7[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 128, 32)      0
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 9, 9, 128)    512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 128, 32)      0           input_4[0][0]
# __________________________________________________________________________________________________
# elu_8 (ELU)                     (None, 9, 9, 128)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128, 1024)    33792       reshape_7[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 9, 9, 128)    0           elu_8[0][0]
# __________________________________________________________________________________________________
# elu_10 (ELU)                    (None, 128, 1024)    0           dense_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 9, 9, 13)     1677        reshape_5[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 128, 1024)    0           elu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 9, 9, 13)     52          conv2d_8[0][0]
# __________________________________________________________________________________________________
# rnn_2 (RNN)                     (None, 32)           143616      reshape_8[0][0]
# __________________________________________________________________________________________________
# elu_9 (ELU)                     (None, 9, 9, 13)     0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1024)         33792       rnn_2[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1053)         0           elu_9[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024)         0           dense_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 2077)         0           reshape_6[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 2)            4156        concatenate_2[0][0]
# ==================================================================================================
# Total params: 447,581
# Trainable params: 447,107
# Non-trainable params: 474
# __________________________________________________________________________________________________
# None
# Train on 1728 samples, validate on 432 samples
# Epoch 1/50
#  256/1728 [===>..........................] - ETA: 10s - loss: 1.1981 - accuracy: 0.5391
# C:\Users\ABHISHEK_VERMA\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (9.751745). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1728/1728 [==============================] - 24s 14ms/step - loss: 0.7192 - accuracy: 0.7280 - val_loss: 0.3547 - val_accuracy: 0.8333
#
# Epoch 00001: val_accuracy improved from -inf to 0.83333, saving model to lightningedge007a_results/yes/liking/s17/max_acc_yes_liking_s17.h5
#
# Epoch 00001: val_loss improved from inf to 0.35466, saving model to lightningedge007a_results/yes/liking/s17/min_loss_yes_liking_s17.h5
# Epoch 2/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.2519 - accuracy: 0.8935 - val_loss: 0.3069 - val_accuracy: 0.8588
#
# Epoch 00002: val_accuracy improved from 0.83333 to 0.85880, saving model to lightningedge007a_results/yes/liking/s17/max_acc_yes_liking_s17.h5
#
# Epoch 00002: val_loss improved from 0.35466 to 0.30694, saving model to lightningedge007a_results/yes/liking/s17/min_loss_yes_liking_s17.h5
# Epoch 3/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.1430 - accuracy: 0.9468 - val_loss: 0.2428 - val_accuracy: 0.9074
#
# Epoch 00003: val_accuracy improved from 0.85880 to 0.90741, saving model to lightningedge007a_results/yes/liking/s17/max_acc_yes_liking_s17.h5
#
# Epoch 00003: val_loss improved from 0.30694 to 0.24277, saving model to lightningedge007a_results/yes/liking/s17/min_loss_yes_liking_s17.h5
# Epoch 4/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0828 - accuracy: 0.9716 - val_loss: 0.1891 - val_accuracy: 0.9236
#
# Epoch 00004: val_accuracy improved from 0.90741 to 0.92361, saving model to lightningedge007a_results/yes/liking/s17/max_acc_yes_liking_s17.h5
#
# Epoch 00004: val_loss improved from 0.24277 to 0.18908, saving model to lightningedge007a_results/yes/liking/s17/min_loss_yes_liking_s17.h5
# Epoch 5/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0613 - accuracy: 0.9832 - val_loss: 0.1715 - val_accuracy: 0.9398
#
# Epoch 00005: val_accuracy improved from 0.92361 to 0.93981, saving model to lightningedge007a_results/yes/liking/s17/max_acc_yes_liking_s17.h5
#
# Epoch 00005: val_loss improved from 0.18908 to 0.17149, saving model to lightningedge007a_results/yes/liking/s17/min_loss_yes_liking_s17.h5
# Epoch 6/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0268 - accuracy: 0.9983 - val_loss: 0.1529 - val_accuracy: 0.9398
#
# Epoch 00006: val_accuracy did not improve from 0.93981
#
# Epoch 00006: val_loss improved from 0.17149 to 0.15288, saving model to lightningedge007a_results/yes/liking/s17/min_loss_yes_liking_s17.h5
# Epoch 7/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9491
#
# Epoch 00007: val_accuracy improved from 0.93981 to 0.94907, saving model to lightningedge007a_results/yes/liking/s17/max_acc_yes_liking_s17.h5
#
# Epoch 00007: val_loss improved from 0.15288 to 0.13404, saving model to lightningedge007a_results/yes/liking/s17/min_loss_yes_liking_s17.h5
# Epoch 8/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 0.9537
#
# Epoch 00008: val_accuracy improved from 0.94907 to 0.95370, saving model to lightningedge007a_results/yes/liking/s17/max_acc_yes_liking_s17.h5
#
# Epoch 00008: val_loss improved from 0.13404 to 0.12996, saving model to lightningedge007a_results/yes/liking/s17/min_loss_yes_liking_s17.h5
# Epoch 9/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.1230 - val_accuracy: 0.9560
#
# Epoch 00009: val_accuracy improved from 0.95370 to 0.95602, saving model to lightningedge007a_results/yes/liking/s17/max_acc_yes_liking_s17.h5
#
# Epoch 00009: val_loss improved from 0.12996 to 0.12296, saving model to lightningedge007a_results/yes/liking/s17/min_loss_yes_liking_s17.h5
# Epoch 10/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9537
#
# Epoch 00010: val_accuracy did not improve from 0.95602
#
# Epoch 00010: val_loss improved from 0.12296 to 0.11624, saving model to lightningedge007a_results/yes/liking/s17/min_loss_yes_liking_s17.h5
# Epoch 11/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1122 - val_accuracy: 0.9583
#
# Epoch 00011: val_accuracy improved from 0.95602 to 0.95833, saving model to lightningedge007a_results/yes/liking/s17/max_acc_yes_liking_s17.h5
#
# Epoch 00011: val_loss improved from 0.11624 to 0.11217, saving model to lightningedge007a_results/yes/liking/s17/min_loss_yes_liking_s17.h5
# Epoch 12/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1083 - val_accuracy: 0.9583
#
# Epoch 00012: val_accuracy did not improve from 0.95833
#
# Epoch 00012: val_loss improved from 0.11217 to 0.10831, saving model to lightningedge007a_results/yes/liking/s17/min_loss_yes_liking_s17.h5
# Epoch 13/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9583
#
# Epoch 00013: val_accuracy did not improve from 0.95833
#
# Epoch 00013: val_loss did not improve from 0.10831
# Epoch 14/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1065 - val_accuracy: 0.9606
#
# Epoch 00014: val_accuracy improved from 0.95833 to 0.96065, saving model to lightningedge007a_results/yes/liking/s17/max_acc_yes_liking_s17.h5
#
# Epoch 00014: val_loss improved from 0.10831 to 0.10652, saving model to lightningedge007a_results/yes/liking/s17/min_loss_yes_liking_s17.h5
# Epoch 15/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1067 - val_accuracy: 0.9560
#
# Epoch 00015: val_accuracy did not improve from 0.96065
#
# Epoch 00015: val_loss did not improve from 0.10652
# Epoch 16/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1062 - val_accuracy: 0.9606
#
# Epoch 00016: val_accuracy did not improve from 0.96065
#
# Epoch 00016: val_loss improved from 0.10652 to 0.10620, saving model to lightningedge007a_results/yes/liking/s17/min_loss_yes_liking_s17.h5
# Epoch 17/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.9630
#
# Epoch 00017: val_accuracy improved from 0.96065 to 0.96296, saving model to lightningedge007a_results/yes/liking/s17/max_acc_yes_liking_s17.h5
#
# Epoch 00017: val_loss improved from 0.10620 to 0.10350, saving model to lightningedge007a_results/yes/liking/s17/min_loss_yes_liking_s17.h5
# Epoch 18/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1058 - val_accuracy: 0.9606
#
# Epoch 00018: val_accuracy did not improve from 0.96296
#
# Epoch 00018: val_loss did not improve from 0.10350
# Epoch 19/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1041 - val_accuracy: 0.9630
#
# Epoch 00019: val_accuracy did not improve from 0.96296
#
# Epoch 00019: val_loss did not improve from 0.10350
# Epoch 20/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.7932e-04 - accuracy: 1.0000 - val_loss: 0.1062 - val_accuracy: 0.9630
#
# Epoch 00020: val_accuracy did not improve from 0.96296
#
# Epoch 00020: val_loss did not improve from 0.10350
# Epoch 21/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 8.8269e-04 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.9606
#
# Epoch 00021: val_accuracy did not improve from 0.96296
#
# Epoch 00021: val_loss improved from 0.10350 to 0.10345, saving model to lightningedge007a_results/yes/liking/s17/min_loss_yes_liking_s17.h5
# Epoch 22/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 7.9175e-04 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 0.9630
#
# Epoch 00022: val_accuracy did not improve from 0.96296
#
# Epoch 00022: val_loss improved from 0.10345 to 0.10345, saving model to lightningedge007a_results/yes/liking/s17/min_loss_yes_liking_s17.h5
# Epoch 23/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 7.2210e-04 - accuracy: 1.0000 - val_loss: 0.1039 - val_accuracy: 0.9606
#
# Epoch 00023: val_accuracy did not improve from 0.96296
#
# Epoch 00023: val_loss did not improve from 0.10345
# Epoch 24/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.6847e-04 - accuracy: 1.0000 - val_loss: 0.1027 - val_accuracy: 0.9630
#
# Epoch 00024: val_accuracy did not improve from 0.96296
#
# Epoch 00024: val_loss improved from 0.10345 to 0.10265, saving model to lightningedge007a_results/yes/liking/s17/min_loss_yes_liking_s17.h5
# Epoch 25/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.2168e-04 - accuracy: 1.0000 - val_loss: 0.1037 - val_accuracy: 0.9630
#
# Epoch 00025: val_accuracy did not improve from 0.96296
#
# Epoch 00025: val_loss did not improve from 0.10265
# Epoch 26/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.7074e-04 - accuracy: 1.0000 - val_loss: 0.1028 - val_accuracy: 0.9630
#
# Epoch 00026: val_accuracy did not improve from 0.96296
#
# Epoch 00026: val_loss did not improve from 0.10265
# Epoch 27/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.2987e-04 - accuracy: 1.0000 - val_loss: 0.1038 - val_accuracy: 0.9630
#
# Epoch 00027: val_accuracy did not improve from 0.96296
#
# Epoch 00027: val_loss did not improve from 0.10265
# Epoch 28/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.9998e-04 - accuracy: 1.0000 - val_loss: 0.1031 - val_accuracy: 0.9606
#
# Epoch 00028: val_accuracy did not improve from 0.96296
#
# Epoch 00028: val_loss did not improve from 0.10265
# Epoch 29/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.6463e-04 - accuracy: 1.0000 - val_loss: 0.1029 - val_accuracy: 0.9606
#
# Epoch 00029: val_accuracy did not improve from 0.96296
#
# Epoch 00029: val_loss did not improve from 0.10265
# Epoch 30/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.3572e-04 - accuracy: 1.0000 - val_loss: 0.1029 - val_accuracy: 0.9630
#
# Epoch 00030: val_accuracy did not improve from 0.96296
#
# Epoch 00030: val_loss did not improve from 0.10265
# Epoch 31/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.1482e-04 - accuracy: 1.0000 - val_loss: 0.1024 - val_accuracy: 0.9630
#
# Epoch 00031: val_accuracy did not improve from 0.96296
#
# Epoch 00031: val_loss improved from 0.10265 to 0.10242, saving model to lightningedge007a_results/yes/liking/s17/min_loss_yes_liking_s17.h5
# Epoch 32/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.9257e-04 - accuracy: 1.0000 - val_loss: 0.1031 - val_accuracy: 0.9606
#
# Epoch 00032: val_accuracy did not improve from 0.96296
#
# Epoch 00032: val_loss did not improve from 0.10242
# Epoch 33/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 3.6883e-04 - accuracy: 1.0000 - val_loss: 0.1032 - val_accuracy: 0.9630
#
# Epoch 00033: val_accuracy did not improve from 0.96296
#
# Epoch 00033: val_loss did not improve from 0.10242
# Epoch 34/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.4346e-04 - accuracy: 1.0000 - val_loss: 0.1026 - val_accuracy: 0.9630
#
# Epoch 00034: val_accuracy did not improve from 0.96296
#
# Epoch 00034: val_loss did not improve from 0.10242
# Epoch 35/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.2590e-04 - accuracy: 1.0000 - val_loss: 0.1028 - val_accuracy: 0.9630
#
# Epoch 00035: val_accuracy did not improve from 0.96296
#
# Epoch 00035: val_loss did not improve from 0.10242
# Epoch 36/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.1055e-04 - accuracy: 1.0000 - val_loss: 0.1027 - val_accuracy: 0.9630
#
# Epoch 00036: val_accuracy did not improve from 0.96296
#
# Epoch 00036: val_loss did not improve from 0.10242
# Epoch 37/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 2.9495e-04 - accuracy: 1.0000 - val_loss: 0.1037 - val_accuracy: 0.9630
#
# Epoch 00037: val_accuracy did not improve from 0.96296
#
# Epoch 00037: val_loss did not improve from 0.10242
# Epoch 38/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 2.7851e-04 - accuracy: 1.0000 - val_loss: 0.1027 - val_accuracy: 0.9630
#
# Epoch 00038: val_accuracy did not improve from 0.96296
#
# Epoch 00038: val_loss did not improve from 0.10242
# Epoch 39/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.6609e-04 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.9630
#
# Epoch 00039: val_accuracy did not improve from 0.96296
#
# Epoch 00039: val_loss did not improve from 0.10242
# Epoch 40/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.5205e-04 - accuracy: 1.0000 - val_loss: 0.1025 - val_accuracy: 0.9630
#
# Epoch 00040: val_accuracy did not improve from 0.96296
#
# Epoch 00040: val_loss did not improve from 0.10242
# Epoch 41/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.4222e-04 - accuracy: 1.0000 - val_loss: 0.1025 - val_accuracy: 0.9630
#
# Epoch 00041: val_accuracy did not improve from 0.96296
#
# Epoch 00041: val_loss did not improve from 0.10242
# Epoch 42/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.2994e-04 - accuracy: 1.0000 - val_loss: 0.1025 - val_accuracy: 0.9630
#
# Epoch 00042: val_accuracy did not improve from 0.96296
#
# Epoch 00042: val_loss did not improve from 0.10242
# Epoch 43/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.1797e-04 - accuracy: 1.0000 - val_loss: 0.1030 - val_accuracy: 0.9630
#
# Epoch 00043: val_accuracy did not improve from 0.96296
#
# Epoch 00043: val_loss did not improve from 0.10242
# Epoch 44/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.1054e-04 - accuracy: 1.0000 - val_loss: 0.1027 - val_accuracy: 0.9630
#
# Epoch 00044: val_accuracy did not improve from 0.96296
#
# Epoch 00044: val_loss did not improve from 0.10242
# Epoch 45/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.0183e-04 - accuracy: 1.0000 - val_loss: 0.1032 - val_accuracy: 0.9630
#
# Epoch 00045: val_accuracy did not improve from 0.96296
#
# Epoch 00045: val_loss did not improve from 0.10242
# Epoch 46/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.9451e-04 - accuracy: 1.0000 - val_loss: 0.1027 - val_accuracy: 0.9630
#
# Epoch 00046: val_accuracy did not improve from 0.96296
#
# Epoch 00046: val_loss did not improve from 0.10242
# Epoch 47/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.8893e-04 - accuracy: 1.0000 - val_loss: 0.1028 - val_accuracy: 0.9630
#
# Epoch 00047: val_accuracy did not improve from 0.96296
#
# Epoch 00047: val_loss did not improve from 0.10242
# Epoch 48/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.7940e-04 - accuracy: 1.0000 - val_loss: 0.1029 - val_accuracy: 0.9630
#
# Epoch 00048: val_accuracy did not improve from 0.96296
#
# Epoch 00048: val_loss did not improve from 0.10242
# Epoch 49/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.7114e-04 - accuracy: 1.0000 - val_loss: 0.1024 - val_accuracy: 0.9653
#
# Epoch 00049: val_accuracy improved from 0.96296 to 0.96528, saving model to lightningedge007a_results/yes/liking/s17/max_acc_yes_liking_s17.h5
#
# Epoch 00049: val_loss improved from 0.10242 to 0.10235, saving model to lightningedge007a_results/yes/liking/s17/min_loss_yes_liking_s17.h5
# Epoch 50/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.6564e-04 - accuracy: 1.0000 - val_loss: 0.1038 - val_accuracy: 0.9630
#
# Epoch 00050: val_accuracy did not improve from 0.96528
#
# Epoch 00050: val_loss did not improve from 0.10235
# 240/240 [==============================] - 1s 3ms/step
# max acc:  [0.14284166991710662, 0.9416666626930237]
# 240/240 [==============================] - 1s 4ms/step
# min loss:  [0.14284166991710662, 0.9416666626930237]
# ---------------------------------------------------
# yes liking s18
# ---------------------------------------------------
#
# loaded shape: (2400,)
# (2400, 128, 9, 9)
# (2400, 128, 32)
# (2400,)
# (2400, 2)
# (2400, 128, 9, 9)
# (2400, 128, 32)
# (2400, 2)
# ...
#
# Epoch 00016: val_accuracy improved from 0.95602 to 0.95833, saving model to lightningedge007a_results/yes/liking/s24/max_acc_yes_liking_s24.h5
#
# Epoch 00016: val_loss did not improve from 0.12949
# Epoch 17/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.7784e-04 - accuracy: 1.0000 - val_loss: 0.1370 - val_accuracy: 0.9560
#
# Epoch 00017: val_accuracy did not improve from 0.95833
#
# Epoch 00017: val_loss did not improve from 0.12949
# Epoch 18/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.0120e-04 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9537
#
# Epoch 00018: val_accuracy did not improve from 0.95833
#
# Epoch 00018: val_loss did not improve from 0.12949
# Epoch 19/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.4087e-04 - accuracy: 1.0000 - val_loss: 0.1341 - val_accuracy: 0.9560
#
# Epoch 00019: val_accuracy did not improve from 0.95833
#
# Epoch 00019: val_loss did not improve from 0.12949
# Epoch 20/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.9765e-04 - accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.9537
#
# Epoch 00020: val_accuracy did not improve from 0.95833
#
# Epoch 00020: val_loss did not improve from 0.12949
# Epoch 21/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.4838e-04 - accuracy: 1.0000 - val_loss: 0.1394 - val_accuracy: 0.9583
#
# Epoch 00021: val_accuracy did not improve from 0.95833
#
# Epoch 00021: val_loss did not improve from 0.12949
# Epoch 22/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.1906e-04 - accuracy: 1.0000 - val_loss: 0.1455 - val_accuracy: 0.9537
#
# Epoch 00022: val_accuracy did not improve from 0.95833
#
# Epoch 00022: val_loss did not improve from 0.12949
# Epoch 23/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.9517e-04 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9560
#
# Epoch 00023: val_accuracy did not improve from 0.95833
#
# Epoch 00023: val_loss did not improve from 0.12949
# Epoch 24/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.5855e-04 - accuracy: 1.0000 - val_loss: 0.1439 - val_accuracy: 0.9537
#
# Epoch 00024: val_accuracy did not improve from 0.95833
#
# Epoch 00024: val_loss did not improve from 0.12949
# Epoch 25/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.3109e-04 - accuracy: 1.0000 - val_loss: 0.1426 - val_accuracy: 0.9560
#
# Epoch 00025: val_accuracy did not improve from 0.95833
#
# Epoch 00025: val_loss did not improve from 0.12949
# Epoch 26/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.0826e-04 - accuracy: 1.0000 - val_loss: 0.1426 - val_accuracy: 0.9583
#
# Epoch 00026: val_accuracy did not improve from 0.95833
#
# Epoch 00026: val_loss did not improve from 0.12949
# Epoch 27/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.8575e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9537
#
# Epoch 00027: val_accuracy did not improve from 0.95833
#
# Epoch 00027: val_loss did not improve from 0.12949
# Epoch 28/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.7007e-04 - accuracy: 1.0000 - val_loss: 0.1425 - val_accuracy: 0.9560
#
# Epoch 00028: val_accuracy did not improve from 0.95833
#
# Epoch 00028: val_loss did not improve from 0.12949
# Epoch 29/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.6007e-04 - accuracy: 1.0000 - val_loss: 0.1478 - val_accuracy: 0.9560
#
# Epoch 00029: val_accuracy did not improve from 0.95833
#
# Epoch 00029: val_loss did not improve from 0.12949
# Epoch 30/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.3982e-04 - accuracy: 1.0000 - val_loss: 0.1461 - val_accuracy: 0.9560
#
# Epoch 00030: val_accuracy did not improve from 0.95833
#
# Epoch 00030: val_loss did not improve from 0.12949
# Epoch 31/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.2233e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9583
#
# Epoch 00031: val_accuracy did not improve from 0.95833
#
# Epoch 00031: val_loss did not improve from 0.12949
# Epoch 32/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.1236e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9606
#
# Epoch 00032: val_accuracy improved from 0.95833 to 0.96065, saving model to lightningedge007a_results/yes/liking/s24/max_acc_yes_liking_s24.h5
#
# Epoch 00032: val_loss did not improve from 0.12949
# Epoch 33/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.9844e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9583
#
# Epoch 00033: val_accuracy did not improve from 0.96065
#
# Epoch 00033: val_loss did not improve from 0.12949
# Epoch 34/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.8917e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9583
#
# Epoch 00034: val_accuracy did not improve from 0.96065
#
# Epoch 00034: val_loss did not improve from 0.12949
# Epoch 35/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.7761e-04 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9560
#
# Epoch 00035: val_accuracy did not improve from 0.96065
#
# Epoch 00035: val_loss did not improve from 0.12949
# Epoch 36/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 1.7428e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9583
#
# Epoch 00036: val_accuracy did not improve from 0.96065
#
# Epoch 00036: val_loss did not improve from 0.12949
# Epoch 37/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.6256e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9560
#
# Epoch 00037: val_accuracy did not improve from 0.96065
#
# Epoch 00037: val_loss did not improve from 0.12949
# Epoch 38/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.5512e-04 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9560
#
# Epoch 00038: val_accuracy did not improve from 0.96065
#
# Epoch 00038: val_loss did not improve from 0.12949
# Epoch 39/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.4556e-04 - accuracy: 1.0000 - val_loss: 0.1513 - val_accuracy: 0.9560
#
# Epoch 00039: val_accuracy did not improve from 0.96065
#
# Epoch 00039: val_loss did not improve from 0.12949
# Epoch 40/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.3961e-04 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9583
#
# Epoch 00040: val_accuracy did not improve from 0.96065
#
# Epoch 00040: val_loss did not improve from 0.12949
# Epoch 41/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.3347e-04 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9560
#
# Epoch 00041: val_accuracy did not improve from 0.96065
#
# Epoch 00041: val_loss did not improve from 0.12949
# Epoch 42/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.2744e-04 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9560
#
# Epoch 00042: val_accuracy did not improve from 0.96065
#
# Epoch 00042: val_loss did not improve from 0.12949
# Epoch 43/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.2321e-04 - accuracy: 1.0000 - val_loss: 0.1544 - val_accuracy: 0.9560
#
# Epoch 00043: val_accuracy did not improve from 0.96065
#
# Epoch 00043: val_loss did not improve from 0.12949
# Epoch 44/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.1638e-04 - accuracy: 1.0000 - val_loss: 0.1531 - val_accuracy: 0.9560
#
# Epoch 00044: val_accuracy did not improve from 0.96065
#
# Epoch 00044: val_loss did not improve from 0.12949
# Epoch 45/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.1271e-04 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 0.9560
#
# Epoch 00045: val_accuracy did not improve from 0.96065
#
# Epoch 00045: val_loss did not improve from 0.12949
# Epoch 46/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.0841e-04 - accuracy: 1.0000 - val_loss: 0.1522 - val_accuracy: 0.9560
#
# Epoch 00046: val_accuracy did not improve from 0.96065
#
# Epoch 00046: val_loss did not improve from 0.12949
# Epoch 47/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.0402e-04 - accuracy: 1.0000 - val_loss: 0.1550 - val_accuracy: 0.9560
#
# Epoch 00047: val_accuracy did not improve from 0.96065
#
# Epoch 00047: val_loss did not improve from 0.12949
# Epoch 48/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.9929e-05 - accuracy: 1.0000 - val_loss: 0.1537 - val_accuracy: 0.9583
#
# Epoch 00048: val_accuracy did not improve from 0.96065
#
# Epoch 00048: val_loss did not improve from 0.12949
# Epoch 49/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.5246e-05 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.9560
#
# Epoch 00049: val_accuracy did not improve from 0.96065
#
# Epoch 00049: val_loss did not improve from 0.12949
# Epoch 50/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.2007e-05 - accuracy: 1.0000 - val_loss: 0.1545 - val_accuracy: 0.9560
#
# Epoch 00050: val_accuracy did not improve from 0.96065
#
# Epoch 00050: val_loss did not improve from 0.12949
# 240/240 [==============================] - 1s 4ms/step
# max acc:  [0.0833192058528463, 0.9750000238418579]
# 240/240 [==============================] - 1s 3ms/step
# min loss:  [0.08225261718034745, 0.9666666388511658]
# ---------------------------------------------------
# yes liking s25
# ---------------------------------------------------
#
# loaded shape: (2400,)
# (2400, 128, 9, 9)
# (2400, 128, 32)
# (2400,)
# (2400, 2)
# (2400, 128, 9, 9)
# (2400, 128, 32)
# (2400, 2)
# cnn_datasets.shape,rnn_datasets.shape,labels.shape :  (2400, 128, 9, 9) (2400, 128, 32) (2400, 2)
# (2400, 9, 9, 128)
# cnn_datasets.shape :  (2400, 9, 9, 128)
# ========================Train / Test Shapes==============================
# (240, 9, 9, 128) (240, 128, 32) (2160, 9, 9, 128) (2160, 128, 32)
# ================================ DNN ============================================
# input_cnn:  (None, 9, 9, 128)
# elu1:  (None, 9, 9, 32)
# elu2:  (None, 9, 9, 64)
# elu3:  (None, 9, 9, 128)
# reshape1:  (None, 9, 9, None)
# elu4:  (None, 9, 9, 13)
# reshape2:  (None, 1053)
# input_rnn (None, 128, 32)
# rnn_in_flat (None, None, 32)
# rnn_fc_in (None, 128, 1024)
# lstm_in (None, None, 1024)
# lstm_cell (None, 32)
# output (None, 32)
# rnn_output (32,)
# lstm_fc_out (None, 1024)
# lstm_fc_drop (None, 1024)
# fuse_cnn_rnn  (None, 2077)
# (None, 2)
# y  Tensor("dense_30/Softmax:0", shape=(None, 2), dtype=float32)
# Model :  yes_liking_s25_0_fold
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_19 (InputLayer)           (None, 9, 9, 128)    0
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 9, 9, 32)     65568       input_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 9, 9, 32)     128         conv2d_37[0][0]
# __________________________________________________________________________________________________
# elu_46 (ELU)                    (None, 9, 9, 32)     0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 9, 9, 64)     32832       elu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 9, 9, 64)     256         conv2d_38[0][0]
# __________________________________________________________________________________________________
# elu_47 (ELU)                    (None, 9, 9, 64)     0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 9, 9, 128)    131200      elu_47[0][0]
# __________________________________________________________________________________________________
# input_20 (InputLayer)           (None, 128, 32)      0
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 9, 9, 128)    512         conv2d_39[0][0]
# __________________________________________________________________________________________________
# reshape_39 (Reshape)            (None, 128, 32)      0           input_20[0][0]
# __________________________________________________________________________________________________
# elu_48 (ELU)                    (None, 9, 9, 128)    0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 128, 1024)    33792       reshape_39[0][0]
# __________________________________________________________________________________________________
# reshape_37 (Reshape)            (None, 9, 9, 128)    0           elu_48[0][0]
# __________________________________________________________________________________________________
# elu_50 (ELU)                    (None, 128, 1024)    0           dense_28[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 9, 9, 13)     1677        reshape_37[0][0]
# __________________________________________________________________________________________________
# reshape_40 (Reshape)            (None, 128, 1024)    0           elu_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 9, 9, 13)     52          conv2d_40[0][0]
# __________________________________________________________________________________________________
# rnn_10 (RNN)                    (None, 32)           143616      reshape_40[0][0]
# __________________________________________________________________________________________________
# elu_49 (ELU)                    (None, 9, 9, 13)     0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 1024)         33792       rnn_10[0][0]
# __________________________________________________________________________________________________
# reshape_38 (Reshape)            (None, 1053)         0           elu_49[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 1024)         0           dense_29[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 2077)         0           reshape_38[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 2)            4156        concatenate_10[0][0]
# ==================================================================================================
# Total params: 447,581
# Trainable params: 447,107
# Non-trainable params: 474
# __________________________________________________________________________________________________
# None

# %%
data_files=data_files[24:]
data_files
# Out:
# ['s25', 's26', 's27', 's28', 's29', 's30', 's31', 's32']

# %%
data_files=data_files[:5]

# %%
data_files
# Out:
# ['s25', 's26', 's27', 's28', 's29']

# %%
np.random.seed(32)

window_size = 128

cnn_suffix ='.mat_win_128_cnn_dataset.pkl'
rnn_suffix ='.mat_win_128_rnn_dataset.pkl'
label_suffix ='.mat_win_128_labels.pkl'

for with_or_without in baseline_preprocessing:
    for arousal_or_valence in emotions:
        for data_file in data_files:
            
            gc.collect()
            
            print('---------------------------------------------------')
            print(with_or_without+' '+arousal_or_valence+' '+data_file)
            print('---------------------------------------------------\n')

            #data_file    ='s17'
            #arousal_or_valence = 'valence'
            #with_or_without = 'yes'

            dataset_dir = 'deap_shuffled_data/'+with_or_without+'_'+arousal_or_valence+'/'
            ###load training set
            try:
                with open(dataset_dir + data_file + cnn_suffix, "rb") as fp:
                    cnn_datasets = pickle.load(fp)
                with open(dataset_dir + data_file + rnn_suffix, "rb") as fp:
                    rnn_datasets = pickle.load(fp)
                with open(dataset_dir + data_file + label_suffix, "rb") as fp:
                    labels = pickle.load(fp)
                    labels = np.transpose(labels)
                    print("loaded shape:",labels.shape)
            except:
                continue
            lables_backup = labels

            print(cnn_datasets.shape)
            print(rnn_datasets.shape)
            print(labels.shape)

            #print("cnn_dataset shape before reshape:", np.shape(cnn_datasets))
            # cnn_datasets = cnn_datasets.reshape(len(cnn_datasets), window_size, 9,9, 1)
            #print("cnn_dataset shape after reshape:", np.shape(cnn_datasets))
            one_hot_labels = np.array(list(pd.get_dummies(labels)))

            labels = np.asarray(pd.get_dummies(labels), dtype=np.int8)

            print(labels.shape)
            # shuffle data
            index = np.array(range(0, len(labels)))
            np.random.shuffle(index)

            cnn_datasets   = cnn_datasets[index]
            rnn_datasets   = rnn_datasets[index]
            labels  = labels[index]

            print(cnn_datasets.shape)
            print(rnn_datasets.shape)
            print(labels.shape)

            #print("**********(" + time.asctime(time.localtime(time.time())) + ") Load and Split dataset End **********\n")
            #print("**********(" + time.asctime(time.localtime(time.time())) + ") Define parameters and functions Begin: **********\n")
            print('cnn_datasets.shape,rnn_datasets.shape,labels.shape : ',cnn_datasets.shape,rnn_datasets.shape,labels.shape)
            #important
            cnn_datasets=cnn_datasets.reshape(2400,9,9,-1)# imp
            print(cnn_datasets.shape)
            print('cnn_datasets.shape : ',cnn_datasets.shape)







            print('========================Train / Test Shapes==============================')



            fold=10
            curr_fold=0
            #for curr_fold in range(fold): # kernel dies
                
            #   print('curr_fold / fold : ',curr_fold,' / ',fold)


            max_acc_acc_list=[]

            max_acc_loss_list=[]


            min_loss_acc_list=[]

            min_loss_loss_list=[]

            fold_size = cnn_datasets.shape[0]//fold
            indexes_list = [i for i in range(len(cnn_datasets))]
            indexes = np.array(indexes_list)
            split_list = [i for i in range(curr_fold*fold_size,(curr_fold+1)*fold_size)]
            split = np.array(split_list)

            cnn_test = cnn_datasets[split] 
            labels_test = labels[split]
            rnn_test = rnn_datasets[split]

            split = np.array(list(set(indexes_list)^set(split_list)))

            cnn_train = cnn_datasets[split]
            rnn_train = rnn_datasets[split]
            labels_train = labels[split]

            # train_sample = labels_train.shape[0]
            # print("training examples:", train_sample)
            # test_sample = labels_test.shape[0]
            # print("test examples    :",test_sample)
            print(cnn_test.shape,rnn_test.shape,cnn_train.shape,rnn_train.shape)

            print('================================ DNN ============================================')

            input_cnn=Input(shape=(9,9,128))

            print('input_cnn: ',input_cnn.shape)

            conv1=Conv2D(32,
                          kernel_size=(4,4),
                          strides=(1,1),
                          padding='same',
                          input_shape=(9,9,128)
                         )(input_cnn)


            bn1=BatchNormalization()(conv1)

            elu1=ELU()(bn1)

            print('elu1: ',elu1.shape)
            #?,9,9,32
            conv2=Conv2D(64,
                          kernel_size=(4,4),
                          strides=(1,1),
                          padding='same'
                         )(elu1)

            bn2=BatchNormalization()(conv2)

            elu2=ELU()(bn2)

            print('elu2: ',elu2.shape)
            #?,9,9,64

            conv3=Conv2D(128,
                          kernel_size=(4,4),
                          strides=(1,1),
                          padding='same'
                         )(elu2)

            bn3=BatchNormalization()(conv3)

            elu3=ELU()(bn3)


            print('elu3: ',elu3.shape)
            #?,9,9,128

            # mc.add(Flatten())
            # mc.add(Lambda(lambda x:x,output_shape=(9,9,32*4*128)))
            # mc.add(Lambda(K.reshape((-1,9,9,32*4*128))))
            reshape1=Reshape((9,9,-1))(elu3)


            print('reshape1: ',reshape1.shape)
            #?,9,9,32*4*128

            conv4=Conv2D(13,#32*4*128,
                          kernel_size=(1,1),
                          strides=(1,1),
                          padding='same'
                         )(reshape1)

            bn4=BatchNormalization()(conv4)

            elu4=ELU()(bn4)


            print('elu4: ',elu4.shape)
            #?,9,9,13 #32*4*128

            # mc.add(Flatten())

            # mc.add(Lambda(lambda x:x,output_shape=([13*9*9])))
            # mc.add(Lambda(K.reshape((None,13*9*9))))
            reshape2=Reshape(([13*9*9]))(elu4)


            print('reshape2: ',reshape2.shape)




            cnn_out_fuse=reshape2


            # cube=K.reshape(e3,(-1,9,9,32*4*128))#(e3)


            # flat=K.reshape(e4,(-1,13*9*9))#(e4) #1053

            # rnn_in=K.placeholder(shape=(None,128,32))
            # rnn_in=tf.convert_to_tensor(rnn_datasets,dtype='float32')


            # rnn_in.get_shape().as_list()

            # rnn_in=K.placeholder(shape=(None,128,32))
            # rnn_in_flat=K.reshape(rnn_in,[-1,32])

            # print('rnn_in ',rnn_in.shape)

            input_rnn=Input(shape=(128,32))
            print('input_rnn',input_rnn.shape)

            rnn_in_flat=Reshape((-1,32))(input_rnn)
            print('rnn_in_flat',rnn_in_flat.shape)
            # rnn_in_flat = Lambda(lambda x:x[:,0])(input_rnn)

            # rnn_fc_in1 =Dense(32)(rnn_in_flat)
            rnn_fc_in1 =Dense(1024)(rnn_in_flat)
            rnn_fc_in=ELU()(rnn_fc_in1)
            print('rnn_fc_in',rnn_fc_in.shape)

            # rnn_fc_in =Dense(1024)(input_rnn)

            # lstm_in=Reshape((-1,128,1024))(rnn_fc_in)
            lstm_in=Reshape((-1,1024))(rnn_fc_in)
            print('lstm_in',lstm_in.shape)

            cells=[]

            for i in range(2):
                cell=LSTMCell(32,unit_forget_bias=True,dropout=0.5)#'forget_bias'=1.0,'state_is_tuple'=True
                cells.append(cell)
            #     print(cell.shape)

            # lstm_cell=StackedRNNCells(cells)
            lstm_cell=RNN(cells)(lstm_in)
            # print(lstm_cell.shape)
            # op,states=RNN(cells)(lstm_in)
            print('lstm_cell',lstm_cell.shape)
            # output=K.transpose_shape((1,0,2),lstm_cell)
            # output=Permute((1,0,2))(lstm_cell)
            # output.reshape()
            output=lstm_cell
            print('output',output.shape)
            rnn_output=output[-1]
            # rnn_output

            print('rnn_output',rnn_output.shape)
            # shape_rnn_out=rnn_output.get_shape().as_list()
            lstm_fc_out=Dense(1024)(output)#shape_rnn_out[1]

            print('lstm_fc_out',lstm_fc_out.shape)


            # lstm_fc_out_2=Dense(1053)(lstm_fc_out)#shape_rnn_out[1]



            lstm_fc_drop=Dropout(0.5)(lstm_fc_out)
            # lstm_fc_drop
            print('lstm_fc_drop',lstm_fc_drop.shape)

            # fuse_cnn_rnn=add([cnn_out_fuse,lstm_fc_drop])

            fuse_cnn_rnn=concatenate([cnn_out_fuse,lstm_fc_drop])
            print('fuse_cnn_rnn ',fuse_cnn_rnn.shape)
            y=Dense(2,activation='softmax')(fuse_cnn_rnn) ## ,activity_regularizer=regularizers.l2(0.5)
            print(y.shape)
            y_pred=K.argmax(y,1)
            # y_pred=K.argmax(K.softmax(y))
            # y_posi=K.softmax(y)
            print('y ',y)


            directory_le007a='./lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file
            try:
                if not os.path.exists(directory_le007a):
                    os.makedirs(directory_le007a)
            except OSError:
                print ('Error: Creating directory. ' +  directory_le007a)



            model=Model(inputs=[input_cnn,input_rnn],outputs=y)
            model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

            print('Model : ',with_or_without+'_'+arousal_or_valence+'_'+data_file+'_'+str(curr_fold)+'_fold')
            print(model.summary())

            m_val_acc=ModelCheckpoint('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'max_acc_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.h5',monitor='val_accuracy',mode='max',verbose=1,save_best_only=True)
            m_val_loss=ModelCheckpoint('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'min_loss_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.h5',monitor='val_loss',mode='min',verbose=1,save_best_only=True)


            tb_log_dir='lightningedge007a_results\\'+with_or_without+'\\'+arousal_or_valence+'\\'+data_file+'\\'+'logs_'+with_or_without+'_'+arousal_or_valence+'_'+data_file
            #tb_log_dir='lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'logs_'+with_or_without+'_'+arousal_or_valence+'_'+data_file

            createFolder(tb_log_dir)


            #log_dir='lightningedge007a_results\\'+with_or_without+'\\'+arousal_or_valence+'\\'+data_file+'\\'+'logs_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'_'+str(curr_fold)+'_fold\\' #datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
            tensorboard_callback = callbacks.TensorBoard(log_dir=tb_log_dir)#, histogram_freq=1)

            plotpicture=plot_model(model, to_file='lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'model_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.png', show_shapes=True)

            
            
            gc.collect()
            
            

            history=model.fit([cnn_train,rnn_train],labels_train,batch_size=128,epochs=50,callbacks=[tensorboard_callback,m_val_acc,m_val_loss],validation_split=0.2)


            #Plot values
            plt.plot(history.history['accuracy'])
            plt.plot(history.history['val_accuracy'])
            plt.title('max_acc_'+with_or_without+'_'+arousal_or_valence+'_'+data_file)
            plt.ylabel('Accuracy')
            plt.xlabel('Epoch')
            plt.legend(['Train', 'Validation'], loc='upper right',bbox_to_anchor=(1.3,1))
            plt.savefig('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'max_acc_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.png',bbox_inches='tight')
            #plt.show()
            plt.close()


            # Plot training & validation loss values
            plt.plot(history.history['loss'])
            plt.plot(history.history['val_loss'])
            plt.title('min_loss_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'_'+str(curr_fold)+'_fold')
            plt.ylabel('Loss')
            plt.xlabel('Epoch')
            plt.legend(['Train', 'Validation'], loc='upper right',bbox_to_anchor=(1.3,1))
            plt.savefig('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'min_loss_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.png',bbox_inches='tight')
            #plt.show()
            plt.close()

            vam=load_model('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'max_acc_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.h5')
            vlm=load_model('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'min_loss_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.h5')
            # pred_labels=vam()
            vam_eval=vam.evaluate([cnn_test,rnn_test],labels_test)
            print('max acc: ',vam_eval)
            vlm_eval=vlm.evaluate([cnn_test,rnn_test],labels_test)
            print('min loss: ',vlm_eval)


            max_acc_acc_list.append(vam_eval[1])

            max_acc_loss_list.append(vam_eval[0])


            min_loss_acc_list.append(vlm_eval[1])

            min_loss_loss_list.append(vlm_eval[0])

            pickle.dump(max_acc_acc_list,open('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'max_acc_acc_list_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.pkl','wb'))

            pickle.dump(max_acc_loss_list,open('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'max_acc_loss_list_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.pkl','wb'))


            pickle.dump(min_loss_acc_list,open('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'min_loss_acc_list_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.pkl','wb'))

            pickle.dump(min_loss_loss_list,open('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'min_loss_loss_list_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.pkl','wb'))
            
            
            gc.collect()
# Out:
# ---------------------------------------------------
# yes liking s25
# ---------------------------------------------------
#
# loaded shape: (2400,)
# (2400, 128, 9, 9)
# (2400, 128, 32)
# (2400,)
# (2400, 2)
# (2400, 128, 9, 9)
# (2400, 128, 32)
# (2400, 2)
# cnn_datasets.shape,rnn_datasets.shape,labels.shape :  (2400, 128, 9, 9) (2400, 128, 32) (2400, 2)
# (2400, 9, 9, 128)
# cnn_datasets.shape :  (2400, 9, 9, 128)
# ========================Train / Test Shapes==============================
# (240, 9, 9, 128) (240, 128, 32) (2160, 9, 9, 128) (2160, 128, 32)
# ================================ DNN ============================================
# input_cnn:  (None, 9, 9, 128)
# elu1:  (None, 9, 9, 32)
# elu2:  (None, 9, 9, 64)
# elu3:  (None, 9, 9, 128)
# reshape1:  (None, 9, 9, None)
# elu4:  (None, 9, 9, 13)
# reshape2:  (None, 1053)
# input_rnn (None, 128, 32)
# rnn_in_flat (None, None, 32)
# rnn_fc_in (None, 128, 1024)
# lstm_in (None, None, 1024)
# lstm_cell (None, 32)
# output (None, 32)
# rnn_output (32,)
# lstm_fc_out (None, 1024)
# lstm_fc_drop (None, 1024)
# fuse_cnn_rnn  (None, 2077)
# (None, 2)
# y  Tensor("dense_3/Softmax:0", shape=(None, 2), dtype=float32)
# Model :  yes_liking_s25_0_fold
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 9, 9, 128)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 9, 9, 32)     65568       input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 9, 9, 32)     128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# elu_1 (ELU)                     (None, 9, 9, 32)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 9, 9, 64)     32832       elu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 9, 9, 64)     256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# elu_2 (ELU)                     (None, 9, 9, 64)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 9, 9, 128)    131200      elu_2[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 128, 32)      0
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 9, 9, 128)    512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 128, 32)      0           input_2[0][0]
# __________________________________________________________________________________________________
# elu_3 (ELU)                     (None, 9, 9, 128)    0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128, 1024)    33792       reshape_3[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 9, 9, 128)    0           elu_3[0][0]
# __________________________________________________________________________________________________
# elu_5 (ELU)                     (None, 128, 1024)    0           dense_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 9, 9, 13)     1677        reshape_1[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 128, 1024)    0           elu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 9, 9, 13)     52          conv2d_4[0][0]
# __________________________________________________________________________________________________
# rnn_1 (RNN)                     (None, 32)           143616      reshape_4[0][0]
# __________________________________________________________________________________________________
# elu_4 (ELU)                     (None, 9, 9, 13)     0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1024)         33792       rnn_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1053)         0           elu_4[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           dense_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2077)         0           reshape_2[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            4156        concatenate_1[0][0]
# ==================================================================================================
# Total params: 447,581
# Trainable params: 447,107
# Non-trainable params: 474
# __________________________________________________________________________________________________
# None
# Train on 1728 samples, validate on 432 samples
# Epoch 1/50
#  256/1728 [===>..........................] - ETA: 1:12 - loss: 0.7727 - accuracy: 0.6172
# C:\Users\ABHISHEK_VERMA\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (28.610510). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1728/1728 [==============================] - 79s 46ms/step - loss: 0.4548 - accuracy: 0.8003 - val_loss: 0.2701 - val_accuracy: 0.8958
#
# Epoch 00001: val_accuracy improved from -inf to 0.89583, saving model to lightningedge007a_results/yes/liking/s25/max_acc_yes_liking_s25.h5
#
# Epoch 00001: val_loss improved from inf to 0.27007, saving model to lightningedge007a_results/yes/liking/s25/min_loss_yes_liking_s25.h5
# Epoch 2/50
# 1728/1728 [==============================] - 9s 5ms/step - loss: 0.1025 - accuracy: 0.9670 - val_loss: 0.1741 - val_accuracy: 0.9144
#
# Epoch 00002: val_accuracy improved from 0.89583 to 0.91435, saving model to lightningedge007a_results/yes/liking/s25/max_acc_yes_liking_s25.h5
#
# Epoch 00002: val_loss improved from 0.27007 to 0.17410, saving model to lightningedge007a_results/yes/liking/s25/min_loss_yes_liking_s25.h5
# Epoch 3/50
# 1728/1728 [==============================] - 9s 5ms/step - loss: 0.0435 - accuracy: 0.9907 - val_loss: 0.1541 - val_accuracy: 0.9421
#
# Epoch 00003: val_accuracy improved from 0.91435 to 0.94213, saving model to lightningedge007a_results/yes/liking/s25/max_acc_yes_liking_s25.h5
#
# Epoch 00003: val_loss improved from 0.17410 to 0.15409, saving model to lightningedge007a_results/yes/liking/s25/min_loss_yes_liking_s25.h5
# Epoch 4/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 0.0174 - accuracy: 0.9988 - val_loss: 0.1378 - val_accuracy: 0.9468
#
# Epoch 00004: val_accuracy improved from 0.94213 to 0.94676, saving model to lightningedge007a_results/yes/liking/s25/max_acc_yes_liking_s25.h5
#
# Epoch 00004: val_loss improved from 0.15409 to 0.13784, saving model to lightningedge007a_results/yes/liking/s25/min_loss_yes_liking_s25.h5
# Epoch 5/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0106 - accuracy: 0.9994 - val_loss: 0.1033 - val_accuracy: 0.9560
#
# Epoch 00005: val_accuracy improved from 0.94676 to 0.95602, saving model to lightningedge007a_results/yes/liking/s25/max_acc_yes_liking_s25.h5
#
# Epoch 00005: val_loss improved from 0.13784 to 0.10333, saving model to lightningedge007a_results/yes/liking/s25/min_loss_yes_liking_s25.h5
# Epoch 6/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.1029 - val_accuracy: 0.9560
#
# Epoch 00006: val_accuracy did not improve from 0.95602
#
# Epoch 00006: val_loss improved from 0.10333 to 0.10288, saving model to lightningedge007a_results/yes/liking/s25/min_loss_yes_liking_s25.h5
# Epoch 7/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1041 - val_accuracy: 0.9560
#
# Epoch 00007: val_accuracy did not improve from 0.95602
#
# Epoch 00007: val_loss did not improve from 0.10288
# Epoch 8/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 0.9606
#
# Epoch 00008: val_accuracy improved from 0.95602 to 0.96065, saving model to lightningedge007a_results/yes/liking/s25/max_acc_yes_liking_s25.h5
#
# Epoch 00008: val_loss improved from 0.10288 to 0.08745, saving model to lightningedge007a_results/yes/liking/s25/min_loss_yes_liking_s25.h5
# Epoch 9/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0985 - val_accuracy: 0.9560
#
# Epoch 00009: val_accuracy did not improve from 0.96065
#
# Epoch 00009: val_loss did not improve from 0.08745
# Epoch 10/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0912 - val_accuracy: 0.9583
#
# Epoch 00010: val_accuracy did not improve from 0.96065
#
# Epoch 00010: val_loss did not improve from 0.08745
# Epoch 11/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0917 - val_accuracy: 0.9583
#
# Epoch 00011: val_accuracy did not improve from 0.96065
#
# Epoch 00011: val_loss did not improve from 0.08745
# Epoch 12/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0912 - val_accuracy: 0.9583
#
# Epoch 00012: val_accuracy did not improve from 0.96065
#
# Epoch 00012: val_loss did not improve from 0.08745
# Epoch 13/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 8.7435e-04 - accuracy: 1.0000 - val_loss: 0.0887 - val_accuracy: 0.9583
#
# Epoch 00013: val_accuracy did not improve from 0.96065
#
# Epoch 00013: val_loss did not improve from 0.08745
# Epoch 14/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 7.7404e-04 - accuracy: 1.0000 - val_loss: 0.0899 - val_accuracy: 0.9583
#
# Epoch 00014: val_accuracy did not improve from 0.96065
#
# Epoch 00014: val_loss did not improve from 0.08745
# Epoch 15/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.8813e-04 - accuracy: 1.0000 - val_loss: 0.0889 - val_accuracy: 0.9606
#
# Epoch 00015: val_accuracy did not improve from 0.96065
#
# Epoch 00015: val_loss did not improve from 0.08745
# Epoch 16/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.2870e-04 - accuracy: 1.0000 - val_loss: 0.0892 - val_accuracy: 0.9606
#
# Epoch 00016: val_accuracy did not improve from 0.96065
#
# Epoch 00016: val_loss did not improve from 0.08745
# Epoch 17/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.6217e-04 - accuracy: 1.0000 - val_loss: 0.0883 - val_accuracy: 0.9606
#
# Epoch 00017: val_accuracy did not improve from 0.96065
#
# Epoch 00017: val_loss did not improve from 0.08745
# Epoch 18/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.0183e-04 - accuracy: 1.0000 - val_loss: 0.0902 - val_accuracy: 0.9606
#
# Epoch 00018: val_accuracy did not improve from 0.96065
#
# Epoch 00018: val_loss did not improve from 0.08745
# Epoch 19/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.6833e-04 - accuracy: 1.0000 - val_loss: 0.0894 - val_accuracy: 0.9606
#
# Epoch 00019: val_accuracy did not improve from 0.96065
#
# Epoch 00019: val_loss did not improve from 0.08745
# Epoch 20/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.3198e-04 - accuracy: 1.0000 - val_loss: 0.0899 - val_accuracy: 0.9606
#
# Epoch 00020: val_accuracy did not improve from 0.96065
#
# Epoch 00020: val_loss did not improve from 0.08745
# Epoch 21/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.9609e-04 - accuracy: 1.0000 - val_loss: 0.0891 - val_accuracy: 0.9606
#
# Epoch 00021: val_accuracy did not improve from 0.96065
#
# Epoch 00021: val_loss did not improve from 0.08745
# Epoch 22/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.6474e-04 - accuracy: 1.0000 - val_loss: 0.0912 - val_accuracy: 0.9606
#
# Epoch 00022: val_accuracy did not improve from 0.96065
#
# Epoch 00022: val_loss did not improve from 0.08745
# Epoch 23/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.3306e-04 - accuracy: 1.0000 - val_loss: 0.0911 - val_accuracy: 0.9606
#
# Epoch 00023: val_accuracy did not improve from 0.96065
#
# Epoch 00023: val_loss did not improve from 0.08745
# Epoch 24/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.1346e-04 - accuracy: 1.0000 - val_loss: 0.0906 - val_accuracy: 0.9606
#
# Epoch 00024: val_accuracy did not improve from 0.96065
#
# Epoch 00024: val_loss did not improve from 0.08745
# Epoch 25/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.9115e-04 - accuracy: 1.0000 - val_loss: 0.0907 - val_accuracy: 0.9630
#
# Epoch 00025: val_accuracy improved from 0.96065 to 0.96296, saving model to lightningedge007a_results/yes/liking/s25/max_acc_yes_liking_s25.h5
#
# Epoch 00025: val_loss did not improve from 0.08745
# Epoch 26/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.6858e-04 - accuracy: 1.0000 - val_loss: 0.0902 - val_accuracy: 0.9630
#
# Epoch 00026: val_accuracy did not improve from 0.96296
#
# Epoch 00026: val_loss did not improve from 0.08745
# Epoch 27/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.5215e-04 - accuracy: 1.0000 - val_loss: 0.0911 - val_accuracy: 0.9653
#
# Epoch 00027: val_accuracy improved from 0.96296 to 0.96528, saving model to lightningedge007a_results/yes/liking/s25/max_acc_yes_liking_s25.h5
#
# Epoch 00027: val_loss did not improve from 0.08745
# Epoch 28/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.3917e-04 - accuracy: 1.0000 - val_loss: 0.0909 - val_accuracy: 0.9653
#
# Epoch 00028: val_accuracy did not improve from 0.96528
#
# Epoch 00028: val_loss did not improve from 0.08745
# Epoch 29/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.2455e-04 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 0.9630
#
# Epoch 00029: val_accuracy did not improve from 0.96528
#
# Epoch 00029: val_loss did not improve from 0.08745
# Epoch 30/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.1231e-04 - accuracy: 1.0000 - val_loss: 0.0903 - val_accuracy: 0.9653
#
# Epoch 00030: val_accuracy did not improve from 0.96528
#
# Epoch 00030: val_loss did not improve from 0.08745
# Epoch 31/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.9861e-04 - accuracy: 1.0000 - val_loss: 0.0919 - val_accuracy: 0.9653
#
# Epoch 00031: val_accuracy did not improve from 0.96528
#
# Epoch 00031: val_loss did not improve from 0.08745
# Epoch 32/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.9038e-04 - accuracy: 1.0000 - val_loss: 0.0918 - val_accuracy: 0.9653
#
# Epoch 00032: val_accuracy did not improve from 0.96528
#
# Epoch 00032: val_loss did not improve from 0.08745
# Epoch 33/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.7947e-04 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 0.9653
#
# Epoch 00033: val_accuracy did not improve from 0.96528
#
# Epoch 00033: val_loss did not improve from 0.08745
# Epoch 34/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.7075e-04 - accuracy: 1.0000 - val_loss: 0.0909 - val_accuracy: 0.9653
#
# Epoch 00034: val_accuracy did not improve from 0.96528
#
# Epoch 00034: val_loss did not improve from 0.08745
# Epoch 35/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.5913e-04 - accuracy: 1.0000 - val_loss: 0.0925 - val_accuracy: 0.9653
#
# Epoch 00035: val_accuracy did not improve from 0.96528
#
# Epoch 00035: val_loss did not improve from 0.08745
# Epoch 36/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.5342e-04 - accuracy: 1.0000 - val_loss: 0.0923 - val_accuracy: 0.9653
#
# Epoch 00036: val_accuracy did not improve from 0.96528
#
# Epoch 00036: val_loss did not improve from 0.08745
# Epoch 37/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.4510e-04 - accuracy: 1.0000 - val_loss: 0.0925 - val_accuracy: 0.9653
#
# Epoch 00037: val_accuracy did not improve from 0.96528
#
# Epoch 00037: val_loss did not improve from 0.08745
# Epoch 38/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.4001e-04 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9653
#
# Epoch 00038: val_accuracy did not improve from 0.96528
#
# Epoch 00038: val_loss did not improve from 0.08745
# Epoch 39/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.3288e-04 - accuracy: 1.0000 - val_loss: 0.0924 - val_accuracy: 0.9653
#
# Epoch 00039: val_accuracy did not improve from 0.96528
#
# Epoch 00039: val_loss did not improve from 0.08745
# Epoch 40/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.2629e-04 - accuracy: 1.0000 - val_loss: 0.0921 - val_accuracy: 0.9653
#
# Epoch 00040: val_accuracy did not improve from 0.96528
#
# Epoch 00040: val_loss did not improve from 0.08745
# Epoch 41/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 1.2294e-04 - accuracy: 1.0000 - val_loss: 0.0912 - val_accuracy: 0.9653
#
# Epoch 00041: val_accuracy did not improve from 0.96528
#
# Epoch 00041: val_loss did not improve from 0.08745
# Epoch 42/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.1663e-04 - accuracy: 1.0000 - val_loss: 0.0925 - val_accuracy: 0.9653
#
# Epoch 00042: val_accuracy did not improve from 0.96528
#
# Epoch 00042: val_loss did not improve from 0.08745
# Epoch 43/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.1109e-04 - accuracy: 1.0000 - val_loss: 0.0925 - val_accuracy: 0.9653
#
# Epoch 00043: val_accuracy did not improve from 0.96528
#
# Epoch 00043: val_loss did not improve from 0.08745
# Epoch 44/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.0641e-04 - accuracy: 1.0000 - val_loss: 0.0921 - val_accuracy: 0.9653
#
# Epoch 00044: val_accuracy did not improve from 0.96528
#
# Epoch 00044: val_loss did not improve from 0.08745
# Epoch 45/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.0295e-04 - accuracy: 1.0000 - val_loss: 0.0926 - val_accuracy: 0.9653
#
# Epoch 00045: val_accuracy did not improve from 0.96528
#
# Epoch 00045: val_loss did not improve from 0.08745
# Epoch 46/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.9433e-05 - accuracy: 1.0000 - val_loss: 0.0927 - val_accuracy: 0.9653
#
# Epoch 00046: val_accuracy did not improve from 0.96528
#
# Epoch 00046: val_loss did not improve from 0.08745
# Epoch 47/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.4261e-05 - accuracy: 1.0000 - val_loss: 0.0930 - val_accuracy: 0.9653
#
# Epoch 00047: val_accuracy did not improve from 0.96528
#
# Epoch 00047: val_loss did not improve from 0.08745
# Epoch 48/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.0392e-05 - accuracy: 1.0000 - val_loss: 0.0933 - val_accuracy: 0.9653
#
# Epoch 00048: val_accuracy did not improve from 0.96528
#
# Epoch 00048: val_loss did not improve from 0.08745
# Epoch 49/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 8.6476e-05 - accuracy: 1.0000 - val_loss: 0.0926 - val_accuracy: 0.9653
#
# Epoch 00049: val_accuracy did not improve from 0.96528
#
# Epoch 00049: val_loss did not improve from 0.08745
# Epoch 50/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 8.3450e-05 - accuracy: 1.0000 - val_loss: 0.0939 - val_accuracy: 0.9653
#
# Epoch 00050: val_accuracy did not improve from 0.96528
#
# Epoch 00050: val_loss did not improve from 0.08745
# 240/240 [==============================] - 1s 5ms/step
# max acc:  [0.059820718333746, 0.9750000238418579]
# 240/240 [==============================] - 1s 4ms/step
# min loss:  [0.08105129357427358, 0.9666666388511658]
# ---------------------------------------------------
# yes liking s26
# ---------------------------------------------------
#
# loaded shape: (2400,)
# (2400, 128, 9, 9)
# (2400, 128, 32)
# (2400,)
# (2400, 2)
# (2400, 128, 9, 9)
# (2400, 128, 32)
# (2400, 2)
# cnn_datasets.shape,rnn_datasets.shape,labels.shape :  (2400, 128, 9, 9) (2400, 128, 32) (2400, 2)
# (2400, 9, 9, 128)
# cnn_datasets.shape :  (2400, 9, 9, 128)
# ========================Train / Test Shapes==============================
# (240, 9, 9, 128) (240, 128, 32) (2160, 9, 9, 128) (2160, 128, 32)
# ================================ DNN ============================================
# input_cnn:  (None, 9, 9, 128)
# elu1:  (None, 9, 9, 32)
# elu2:  (None, 9, 9, 64)
# elu3:  (None, 9, 9, 128)
# reshape1:  (None, 9, 9, None)
# elu4:  (None, 9, 9, 13)
# reshape2:  (None, 1053)
# input_rnn (None, 128, 32)
# rnn_in_flat (None, None, 32)
# rnn_fc_in (None, 128, 1024)
# lstm_in (None, None, 1024)
# lstm_cell (None, 32)
# output (None, 32)
# rnn_output (32,)
# lstm_fc_out (None, 1024)
# lstm_fc_drop (None, 1024)
# fuse_cnn_rnn  (None, 2077)
# (None, 2)
# y  Tensor("dense_6/Softmax:0", shape=(None, 2), dtype=float32)
# Model :  yes_liking_s26_0_fold
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 9, 9, 128)    0
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 9, 9, 32)     65568       input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 9, 9, 32)     128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# elu_6 (ELU)                     (None, 9, 9, 32)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 9, 9, 64)     32832       elu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 9, 9, 64)     256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# elu_7 (ELU)                     (None, 9, 9, 64)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 9, 9, 128)    131200      elu_7[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 128, 32)      0
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 9, 9, 128)    512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 128, 32)      0           input_4[0][0]
# __________________________________________________________________________________________________
# elu_8 (ELU)                     (None, 9, 9, 128)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128, 1024)    33792       reshape_7[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 9, 9, 128)    0           elu_8[0][0]
# __________________________________________________________________________________________________
# elu_10 (ELU)                    (None, 128, 1024)    0           dense_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 9, 9, 13)     1677        reshape_5[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 128, 1024)    0           elu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 9, 9, 13)     52          conv2d_8[0][0]
# __________________________________________________________________________________________________
# rnn_2 (RNN)                     (None, 32)           143616      reshape_8[0][0]
# __________________________________________________________________________________________________
# elu_9 (ELU)                     (None, 9, 9, 13)     0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1024)         33792       rnn_2[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1053)         0           elu_9[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024)         0           dense_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 2077)         0           reshape_6[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 2)            4156        concatenate_2[0][0]
# ==================================================================================================
# Total params: 447,581
# Trainable params: 447,107
# Non-trainable params: 474
# __________________________________________________________________________________________________
# None
# Train on 1728 samples, validate on 432 samples
# Epoch 1/50
#  384/1728 [=====>........................] - ETA: 1:16 - loss: 0.9196 - accuracy: 0.7188
# C:\Users\ABHISHEK_VERMA\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (9.852962). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1728/1728 [==============================] - 24s 14ms/step - loss: 0.4698 - accuracy: 0.8472 - val_loss: 0.2482 - val_accuracy: 0.8889
#
# Epoch 00001: val_accuracy improved from -inf to 0.88889, saving model to lightningedge007a_results/yes/liking/s26/max_acc_yes_liking_s26.h5
#
# Epoch 00001: val_loss improved from inf to 0.24822, saving model to lightningedge007a_results/yes/liking/s26/min_loss_yes_liking_s26.h5
# Epoch 2/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.1018 - accuracy: 0.9595 - val_loss: 0.1293 - val_accuracy: 0.9514
#
# Epoch 00002: val_accuracy improved from 0.88889 to 0.95139, saving model to lightningedge007a_results/yes/liking/s26/max_acc_yes_liking_s26.h5
#
# Epoch 00002: val_loss improved from 0.24822 to 0.12928, saving model to lightningedge007a_results/yes/liking/s26/min_loss_yes_liking_s26.h5
# Epoch 3/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0527 - accuracy: 0.9815 - val_loss: 0.1232 - val_accuracy: 0.9514
#
# Epoch 00003: val_accuracy did not improve from 0.95139
#
# Epoch 00003: val_loss improved from 0.12928 to 0.12325, saving model to lightningedge007a_results/yes/liking/s26/min_loss_yes_liking_s26.h5
# Epoch 4/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0232 - accuracy: 0.9942 - val_loss: 0.1015 - val_accuracy: 0.9653
#
# Epoch 00004: val_accuracy improved from 0.95139 to 0.96528, saving model to lightningedge007a_results/yes/liking/s26/max_acc_yes_liking_s26.h5
#
# Epoch 00004: val_loss improved from 0.12325 to 0.10146, saving model to lightningedge007a_results/yes/liking/s26/min_loss_yes_liking_s26.h5
# Epoch 5/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0125 - accuracy: 0.9994 - val_loss: 0.0934 - val_accuracy: 0.9653
#
# Epoch 00005: val_accuracy did not improve from 0.96528
#
# Epoch 00005: val_loss improved from 0.10146 to 0.09342, saving model to lightningedge007a_results/yes/liking/s26/min_loss_yes_liking_s26.h5
# Epoch 6/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0075 - accuracy: 0.9994 - val_loss: 0.0861 - val_accuracy: 0.9699
#
# Epoch 00006: val_accuracy improved from 0.96528 to 0.96991, saving model to lightningedge007a_results/yes/liking/s26/max_acc_yes_liking_s26.h5
#
# Epoch 00006: val_loss improved from 0.09342 to 0.08607, saving model to lightningedge007a_results/yes/liking/s26/min_loss_yes_liking_s26.h5
# Epoch 7/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0781 - val_accuracy: 0.9722
#
# Epoch 00007: val_accuracy improved from 0.96991 to 0.97222, saving model to lightningedge007a_results/yes/liking/s26/max_acc_yes_liking_s26.h5
#
# Epoch 00007: val_loss improved from 0.08607 to 0.07806, saving model to lightningedge007a_results/yes/liking/s26/min_loss_yes_liking_s26.h5
# Epoch 8/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9699
#
# Epoch 00008: val_accuracy did not improve from 0.97222
#
# Epoch 00008: val_loss improved from 0.07806 to 0.07463, saving model to lightningedge007a_results/yes/liking/s26/min_loss_yes_liking_s26.h5
# Epoch 9/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9699
#
# Epoch 00009: val_accuracy did not improve from 0.97222
#
# Epoch 00009: val_loss improved from 0.07463 to 0.07418, saving model to lightningedge007a_results/yes/liking/s26/min_loss_yes_liking_s26.h5
# Epoch 10/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0723 - val_accuracy: 0.9676
#
# Epoch 00010: val_accuracy did not improve from 0.97222
#
# Epoch 00010: val_loss improved from 0.07418 to 0.07227, saving model to lightningedge007a_results/yes/liking/s26/min_loss_yes_liking_s26.h5
# Epoch 11/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0714 - val_accuracy: 0.9676
#
# Epoch 00011: val_accuracy did not improve from 0.97222
#
# Epoch 00011: val_loss improved from 0.07227 to 0.07138, saving model to lightningedge007a_results/yes/liking/s26/min_loss_yes_liking_s26.h5
# Epoch 12/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0716 - val_accuracy: 0.9676
#
# Epoch 00012: val_accuracy did not improve from 0.97222
#
# Epoch 00012: val_loss did not improve from 0.07138
# Epoch 13/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0705 - val_accuracy: 0.9676
#
# Epoch 00013: val_accuracy did not improve from 0.97222
#
# Epoch 00013: val_loss improved from 0.07138 to 0.07046, saving model to lightningedge007a_results/yes/liking/s26/min_loss_yes_liking_s26.h5
# Epoch 14/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0711 - val_accuracy: 0.9676
#
# Epoch 00014: val_accuracy did not improve from 0.97222
#
# Epoch 00014: val_loss did not improve from 0.07046
# Epoch 15/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 8.9665e-04 - accuracy: 1.0000 - val_loss: 0.0717 - val_accuracy: 0.9653
#
# Epoch 00015: val_accuracy did not improve from 0.97222
#
# Epoch 00015: val_loss did not improve from 0.07046
# Epoch 16/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 7.8977e-04 - accuracy: 1.0000 - val_loss: 0.0713 - val_accuracy: 0.9676
#
# Epoch 00016: val_accuracy did not improve from 0.97222
#
# Epoch 00016: val_loss did not improve from 0.07046
# Epoch 17/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 7.0071e-04 - accuracy: 1.0000 - val_loss: 0.0723 - val_accuracy: 0.9676
#
# Epoch 00017: val_accuracy did not improve from 0.97222
#
# Epoch 00017: val_loss did not improve from 0.07046
# Epoch 18/50
# 1728/1728 [==============================] - 1s 364us/step - loss: 6.3956e-04 - accuracy: 1.0000 - val_loss: 0.0711 - val_accuracy: 0.9653
#
# Epoch 00018: val_accuracy did not improve from 0.97222
#
# Epoch 00018: val_loss did not improve from 0.07046
# Epoch 19/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.7050e-04 - accuracy: 1.0000 - val_loss: 0.0728 - val_accuracy: 0.9676
#
# Epoch 00019: val_accuracy did not improve from 0.97222
#
# Epoch 00019: val_loss did not improve from 0.07046
# Epoch 20/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.3429e-04 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 0.9676
#
# Epoch 00020: val_accuracy did not improve from 0.97222
#
# Epoch 00020: val_loss did not improve from 0.07046
# Epoch 21/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.7589e-04 - accuracy: 1.0000 - val_loss: 0.0728 - val_accuracy: 0.9676
#
# Epoch 00021: val_accuracy did not improve from 0.97222
#
# Epoch 00021: val_loss did not improve from 0.07046
# Epoch 22/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.3404e-04 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9676
#
# Epoch 00022: val_accuracy did not improve from 0.97222
#
# Epoch 00022: val_loss did not improve from 0.07046
# Epoch 23/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.9592e-04 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9676
#
# Epoch 00023: val_accuracy did not improve from 0.97222
#
# Epoch 00023: val_loss did not improve from 0.07046
# Epoch 24/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.7065e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9676
#
# Epoch 00024: val_accuracy did not improve from 0.97222
#
# Epoch 00024: val_loss did not improve from 0.07046
# Epoch 25/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.4025e-04 - accuracy: 1.0000 - val_loss: 0.0747 - val_accuracy: 0.9676
#
# Epoch 00025: val_accuracy did not improve from 0.97222
#
# Epoch 00025: val_loss did not improve from 0.07046
# Epoch 26/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 3.1978e-04 - accuracy: 1.0000 - val_loss: 0.0745 - val_accuracy: 0.9676
#
# Epoch 00026: val_accuracy did not improve from 0.97222
#
# Epoch 00026: val_loss did not improve from 0.07046
# Epoch 27/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 2.9531e-04 - accuracy: 1.0000 - val_loss: 0.0755 - val_accuracy: 0.9676
#
# Epoch 00027: val_accuracy did not improve from 0.97222
#
# Epoch 00027: val_loss did not improve from 0.07046
# Epoch 28/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.7241e-04 - accuracy: 1.0000 - val_loss: 0.0761 - val_accuracy: 0.9676
#
# Epoch 00028: val_accuracy did not improve from 0.97222
#
# Epoch 00028: val_loss did not improve from 0.07046
# Epoch 29/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.6096e-04 - accuracy: 1.0000 - val_loss: 0.0768 - val_accuracy: 0.9676
#
# Epoch 00029: val_accuracy did not improve from 0.97222
#
# Epoch 00029: val_loss did not improve from 0.07046
# Epoch 30/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.4608e-04 - accuracy: 1.0000 - val_loss: 0.0771 - val_accuracy: 0.9676
#
# Epoch 00030: val_accuracy did not improve from 0.97222
#
# Epoch 00030: val_loss did not improve from 0.07046
# Epoch 31/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.2571e-04 - accuracy: 1.0000 - val_loss: 0.0775 - val_accuracy: 0.9676
#
# Epoch 00031: val_accuracy did not improve from 0.97222
#
# Epoch 00031: val_loss did not improve from 0.07046
# Epoch 32/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.1667e-04 - accuracy: 1.0000 - val_loss: 0.0779 - val_accuracy: 0.9676
#
# Epoch 00032: val_accuracy did not improve from 0.97222
#
# Epoch 00032: val_loss did not improve from 0.07046
# Epoch 33/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.0385e-04 - accuracy: 1.0000 - val_loss: 0.0773 - val_accuracy: 0.9699
#
# Epoch 00033: val_accuracy did not improve from 0.97222
#
# Epoch 00033: val_loss did not improve from 0.07046
# Epoch 34/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.9270e-04 - accuracy: 1.0000 - val_loss: 0.0775 - val_accuracy: 0.9676
#
# Epoch 00034: val_accuracy did not improve from 0.97222
#
# Epoch 00034: val_loss did not improve from 0.07046
# Epoch 35/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.8310e-04 - accuracy: 1.0000 - val_loss: 0.0779 - val_accuracy: 0.9676
#
# Epoch 00035: val_accuracy did not improve from 0.97222
#
# Epoch 00035: val_loss did not improve from 0.07046
# Epoch 36/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.7016e-04 - accuracy: 1.0000 - val_loss: 0.0787 - val_accuracy: 0.9676
#
# Epoch 00036: val_accuracy did not improve from 0.97222
#
# Epoch 00036: val_loss did not improve from 0.07046
# Epoch 37/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.6298e-04 - accuracy: 1.0000 - val_loss: 0.0785 - val_accuracy: 0.9676
#
# Epoch 00037: val_accuracy did not improve from 0.97222
#
# Epoch 00037: val_loss did not improve from 0.07046
# Epoch 38/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.5421e-04 - accuracy: 1.0000 - val_loss: 0.0786 - val_accuracy: 0.9676
#
# Epoch 00038: val_accuracy did not improve from 0.97222
#
# Epoch 00038: val_loss did not improve from 0.07046
# Epoch 39/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.4718e-04 - accuracy: 1.0000 - val_loss: 0.0785 - val_accuracy: 0.9676
#
# Epoch 00039: val_accuracy did not improve from 0.97222
#
# Epoch 00039: val_loss did not improve from 0.07046
# Epoch 40/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.3966e-04 - accuracy: 1.0000 - val_loss: 0.0789 - val_accuracy: 0.9676
#
# Epoch 00040: val_accuracy did not improve from 0.97222
#
# Epoch 00040: val_loss did not improve from 0.07046
# Epoch 41/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.3185e-04 - accuracy: 1.0000 - val_loss: 0.0785 - val_accuracy: 0.9676
#
# Epoch 00041: val_accuracy did not improve from 0.97222
#
# Epoch 00041: val_loss did not improve from 0.07046
# Epoch 42/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.2378e-04 - accuracy: 1.0000 - val_loss: 0.0791 - val_accuracy: 0.9676
#
# Epoch 00042: val_accuracy did not improve from 0.97222
#
# Epoch 00042: val_loss did not improve from 0.07046
# Epoch 43/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.2168e-04 - accuracy: 1.0000 - val_loss: 0.0799 - val_accuracy: 0.9676
#
# Epoch 00043: val_accuracy did not improve from 0.97222
#
# Epoch 00043: val_loss did not improve from 0.07046
# Epoch 44/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.2203e-04 - accuracy: 1.0000 - val_loss: 0.0797 - val_accuracy: 0.9676
#
# Epoch 00044: val_accuracy did not improve from 0.97222
#
# Epoch 00044: val_loss did not improve from 0.07046
# Epoch 45/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.1525e-04 - accuracy: 1.0000 - val_loss: 0.0799 - val_accuracy: 0.9676
#
# Epoch 00045: val_accuracy did not improve from 0.97222
#
# Epoch 00045: val_loss did not improve from 0.07046
# Epoch 46/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.0877e-04 - accuracy: 1.0000 - val_loss: 0.0803 - val_accuracy: 0.9676
#
# Epoch 00046: val_accuracy did not improve from 0.97222
#
# Epoch 00046: val_loss did not improve from 0.07046
# Epoch 47/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.0391e-04 - accuracy: 1.0000 - val_loss: 0.0801 - val_accuracy: 0.9676
#
# Epoch 00047: val_accuracy did not improve from 0.97222
#
# Epoch 00047: val_loss did not improve from 0.07046
# Epoch 48/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.9623e-05 - accuracy: 1.0000 - val_loss: 0.0806 - val_accuracy: 0.9676
#
# Epoch 00048: val_accuracy did not improve from 0.97222
#
# Epoch 00048: val_loss did not improve from 0.07046
# Epoch 49/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.5860e-05 - accuracy: 1.0000 - val_loss: 0.0805 - val_accuracy: 0.9676
#
# Epoch 00049: val_accuracy did not improve from 0.97222
#
# Epoch 00049: val_loss did not improve from 0.07046
# Epoch 50/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.3580e-05 - accuracy: 1.0000 - val_loss: 0.0809 - val_accuracy: 0.9676
#
# Epoch 00050: val_accuracy did not improve from 0.97222
#
# Epoch 00050: val_loss did not improve from 0.07046
# 240/240 [==============================] - 1s 4ms/step
# max acc:  [0.08838460693756739, 0.9708333611488342]
# 240/240 [==============================] - 1s 4ms/step
# min loss:  [0.08799317044516404, 0.9750000238418579]
# ---------------------------------------------------
# yes liking s27
# ---------------------------------------------------
#
# loaded shape: (2400,)
# (2400, 128, 9, 9)
# (2400, 128, 32)
# (2400,)
# (2400, 2)
# (2400, 128, 9, 9)
# (2400, 128, 32)
# (2400, 2)
# cnn_datasets.shape,rnn_datasets.shape,labels.shape :  (2400, 128, 9, 9) (2400, 128, 32) (2400, 2)
# (2400, 9, 9, 128)
# cnn_datasets.shape :  (2400, 9, 9, 128)
# ========================Train / Test Shapes==============================
# (240, 9, 9, 128) (240, 128, 32) (2160, 9, 9, 128) (2160, 128, 32)
# ================================ DNN ============================================
# input_cnn:  (None, 9, 9, 128)
# elu1:  (None, 9, 9, 32)
# elu2:  (None, 9, 9, 64)
# elu3:  (None, 9, 9, 128)
# reshape1:  (None, 9, 9, None)
# elu4:  (None, 9, 9, 13)
# reshape2:  (None, 1053)
# input_rnn (None, 128, 32)
# rnn_in_flat (None, None, 32)
# rnn_fc_in (None, 128, 1024)
# lstm_in (None, None, 1024)
# lstm_cell (None, 32)
# output (None, 32)
# rnn_output (32,)
# lstm_fc_out (None, 1024)
# lstm_fc_drop (None, 1024)
# fuse_cnn_rnn  (None, 2077)
# (None, 2)
# y  Tensor("dense_9/Softmax:0", shape=(None, 2), dtype=float32)
# Model :  yes_liking_s27_0_fold
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 9, 9, 128)    0
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 9, 9, 32)     65568       input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 9, 9, 32)     128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# elu_11 (ELU)                    (None, 9, 9, 32)     0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 9, 9, 64)     32832       elu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 9, 9, 64)     256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# elu_12 (ELU)                    (None, 9, 9, 64)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 9, 9, 128)    131200      elu_12[0][0]
# __________________________________________________________________________________________________
# input_6 (InputLayer)            (None, 128, 32)      0
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 9, 9, 128)    512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 128, 32)      0           input_6[0][0]
# __________________________________________________________________________________________________
# elu_13 (ELU)                    (None, 9, 9, 128)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 128, 1024)    33792       reshape_11[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 9, 9, 128)    0           elu_13[0][0]
# __________________________________________________________________________________________________
# elu_15 (ELU)                    (None, 128, 1024)    0           dense_7[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 9, 9, 13)     1677        reshape_9[0][0]
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, 128, 1024)    0           elu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 9, 9, 13)     52          conv2d_12[0][0]
# __________________________________________________________________________________________________
# ...
#
# Epoch 00002: val_loss improved from 0.23278 to 0.12523, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 3/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0191 - accuracy: 0.9983 - val_loss: 0.0849 - val_accuracy: 0.9699
#
# Epoch 00003: val_accuracy improved from 0.96528 to 0.96991, saving model to lightningedge007a_results/yes/liking/s29/max_acc_yes_liking_s29.h5
#
# Epoch 00003: val_loss improved from 0.12523 to 0.08485, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 4/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0730 - val_accuracy: 0.9769
#
# Epoch 00004: val_accuracy improved from 0.96991 to 0.97685, saving model to lightningedge007a_results/yes/liking/s29/max_acc_yes_liking_s29.h5
#
# Epoch 00004: val_loss improved from 0.08485 to 0.07299, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 5/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0600 - val_accuracy: 0.9815
#
# Epoch 00005: val_accuracy improved from 0.97685 to 0.98148, saving model to lightningedge007a_results/yes/liking/s29/max_acc_yes_liking_s29.h5
#
# Epoch 00005: val_loss improved from 0.07299 to 0.05999, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 6/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0558 - val_accuracy: 0.9838
#
# Epoch 00006: val_accuracy improved from 0.98148 to 0.98380, saving model to lightningedge007a_results/yes/liking/s29/max_acc_yes_liking_s29.h5
#
# Epoch 00006: val_loss improved from 0.05999 to 0.05583, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 7/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0506 - val_accuracy: 0.9838
#
# Epoch 00007: val_accuracy did not improve from 0.98380
#
# Epoch 00007: val_loss improved from 0.05583 to 0.05062, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 8/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0473 - val_accuracy: 0.9838
#
# Epoch 00008: val_accuracy did not improve from 0.98380
#
# Epoch 00008: val_loss improved from 0.05062 to 0.04732, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 9/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0458 - val_accuracy: 0.9838
#
# Epoch 00009: val_accuracy did not improve from 0.98380
#
# Epoch 00009: val_loss improved from 0.04732 to 0.04578, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 10/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.4738e-04 - accuracy: 1.0000 - val_loss: 0.0438 - val_accuracy: 0.9838
#
# Epoch 00010: val_accuracy did not improve from 0.98380
#
# Epoch 00010: val_loss improved from 0.04578 to 0.04383, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 11/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 8.2555e-04 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 0.9838
#
# Epoch 00011: val_accuracy did not improve from 0.98380
#
# Epoch 00011: val_loss improved from 0.04383 to 0.04204, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 12/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 7.2594e-04 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9838
#
# Epoch 00012: val_accuracy did not improve from 0.98380
#
# Epoch 00012: val_loss improved from 0.04204 to 0.04091, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 13/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.4088e-04 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9838
#
# Epoch 00013: val_accuracy did not improve from 0.98380
#
# Epoch 00013: val_loss improved from 0.04091 to 0.04012, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 14/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 5.7394e-04 - accuracy: 1.0000 - val_loss: 0.0388 - val_accuracy: 0.9838
#
# Epoch 00014: val_accuracy did not improve from 0.98380
#
# Epoch 00014: val_loss improved from 0.04012 to 0.03879, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 15/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.1980e-04 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 0.9838
#
# Epoch 00015: val_accuracy did not improve from 0.98380
#
# Epoch 00015: val_loss improved from 0.03879 to 0.03798, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 16/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.6193e-04 - accuracy: 1.0000 - val_loss: 0.0379 - val_accuracy: 0.9838
#
# Epoch 00016: val_accuracy did not improve from 0.98380
#
# Epoch 00016: val_loss improved from 0.03798 to 0.03788, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 17/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.2749e-04 - accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 0.9838
#
# Epoch 00017: val_accuracy did not improve from 0.98380
#
# Epoch 00017: val_loss improved from 0.03788 to 0.03688, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 18/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.9015e-04 - accuracy: 1.0000 - val_loss: 0.0364 - val_accuracy: 0.9838
#
# Epoch 00018: val_accuracy did not improve from 0.98380
#
# Epoch 00018: val_loss improved from 0.03688 to 0.03637, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 19/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.6385e-04 - accuracy: 1.0000 - val_loss: 0.0365 - val_accuracy: 0.9838
#
# Epoch 00019: val_accuracy did not improve from 0.98380
#
# Epoch 00019: val_loss did not improve from 0.03637
# Epoch 20/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 3.2865e-04 - accuracy: 1.0000 - val_loss: 0.0352 - val_accuracy: 0.9861
#
# Epoch 00020: val_accuracy improved from 0.98380 to 0.98611, saving model to lightningedge007a_results/yes/liking/s29/max_acc_yes_liking_s29.h5
#
# Epoch 00020: val_loss improved from 0.03637 to 0.03520, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 21/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.0396e-04 - accuracy: 1.0000 - val_loss: 0.0352 - val_accuracy: 0.9861
#
# Epoch 00021: val_accuracy did not improve from 0.98611
#
# Epoch 00021: val_loss did not improve from 0.03520
# Epoch 22/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.8044e-04 - accuracy: 1.0000 - val_loss: 0.0350 - val_accuracy: 0.9861
#
# Epoch 00022: val_accuracy did not improve from 0.98611
#
# Epoch 00022: val_loss improved from 0.03520 to 0.03498, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 23/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.6251e-04 - accuracy: 1.0000 - val_loss: 0.0349 - val_accuracy: 0.9861
#
# Epoch 00023: val_accuracy did not improve from 0.98611
#
# Epoch 00023: val_loss improved from 0.03498 to 0.03492, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 24/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.4610e-04 - accuracy: 1.0000 - val_loss: 0.0345 - val_accuracy: 0.9861
#
# Epoch 00024: val_accuracy did not improve from 0.98611
#
# Epoch 00024: val_loss improved from 0.03492 to 0.03448, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 25/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.2561e-04 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 0.9861
#
# Epoch 00025: val_accuracy did not improve from 0.98611
#
# Epoch 00025: val_loss improved from 0.03448 to 0.03432, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 26/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 2.1240e-04 - accuracy: 1.0000 - val_loss: 0.0345 - val_accuracy: 0.9861
#
# Epoch 00026: val_accuracy did not improve from 0.98611
#
# Epoch 00026: val_loss did not improve from 0.03432
# Epoch 27/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.9970e-04 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 0.9861
#
# Epoch 00027: val_accuracy did not improve from 0.98611
#
# Epoch 00027: val_loss improved from 0.03432 to 0.03430, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 28/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.8783e-04 - accuracy: 1.0000 - val_loss: 0.0342 - val_accuracy: 0.9861
#
# Epoch 00028: val_accuracy did not improve from 0.98611
#
# Epoch 00028: val_loss improved from 0.03430 to 0.03422, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 29/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.7344e-04 - accuracy: 1.0000 - val_loss: 0.0337 - val_accuracy: 0.9861
#
# Epoch 00029: val_accuracy did not improve from 0.98611
#
# Epoch 00029: val_loss improved from 0.03422 to 0.03375, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 30/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 1.6740e-04 - accuracy: 1.0000 - val_loss: 0.0338 - val_accuracy: 0.9861
#
# Epoch 00030: val_accuracy did not improve from 0.98611
#
# Epoch 00030: val_loss did not improve from 0.03375
# Epoch 31/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.5713e-04 - accuracy: 1.0000 - val_loss: 0.0339 - val_accuracy: 0.9861
#
# Epoch 00031: val_accuracy did not improve from 0.98611
#
# Epoch 00031: val_loss did not improve from 0.03375
# Epoch 32/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.4853e-04 - accuracy: 1.0000 - val_loss: 0.0336 - val_accuracy: 0.9861
#
# Epoch 00032: val_accuracy did not improve from 0.98611
#
# Epoch 00032: val_loss improved from 0.03375 to 0.03361, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 33/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.4156e-04 - accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 0.9861
#
# Epoch 00033: val_accuracy did not improve from 0.98611
#
# Epoch 00033: val_loss improved from 0.03361 to 0.03348, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 34/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.3493e-04 - accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 0.9861
#
# Epoch 00034: val_accuracy did not improve from 0.98611
#
# Epoch 00034: val_loss did not improve from 0.03348
# Epoch 35/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.3028e-04 - accuracy: 1.0000 - val_loss: 0.0336 - val_accuracy: 0.9861
#
# Epoch 00035: val_accuracy did not improve from 0.98611
#
# Epoch 00035: val_loss did not improve from 0.03348
# Epoch 36/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.2193e-04 - accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 0.9861
#
# Epoch 00036: val_accuracy did not improve from 0.98611
#
# Epoch 00036: val_loss improved from 0.03348 to 0.03347, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 37/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.1618e-04 - accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 0.9861
#
# Epoch 00037: val_accuracy did not improve from 0.98611
#
# Epoch 00037: val_loss did not improve from 0.03347
# Epoch 38/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.1184e-04 - accuracy: 1.0000 - val_loss: 0.0334 - val_accuracy: 0.9861
#
# Epoch 00038: val_accuracy did not improve from 0.98611
#
# Epoch 00038: val_loss improved from 0.03347 to 0.03338, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 39/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.0597e-04 - accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 0.9861
#
# Epoch 00039: val_accuracy did not improve from 0.98611
#
# Epoch 00039: val_loss did not improve from 0.03338
# Epoch 40/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.0089e-04 - accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 0.9861
#
# Epoch 00040: val_accuracy did not improve from 0.98611
#
# Epoch 00040: val_loss improved from 0.03338 to 0.03318, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 41/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.6217e-05 - accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 0.9861
#
# Epoch 00041: val_accuracy did not improve from 0.98611
#
# Epoch 00041: val_loss did not improve from 0.03318
# Epoch 42/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.4252e-05 - accuracy: 1.0000 - val_loss: 0.0331 - val_accuracy: 0.9861
#
# Epoch 00042: val_accuracy did not improve from 0.98611
#
# Epoch 00042: val_loss improved from 0.03318 to 0.03311, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 43/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 8.8830e-05 - accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 0.9861
#
# Epoch 00043: val_accuracy did not improve from 0.98611
#
# Epoch 00043: val_loss did not improve from 0.03311
# Epoch 44/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 8.5492e-05 - accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 0.9861
#
# Epoch 00044: val_accuracy did not improve from 0.98611
#
# Epoch 00044: val_loss did not improve from 0.03311
# Epoch 45/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 8.2733e-05 - accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 0.9861
#
# Epoch 00045: val_accuracy did not improve from 0.98611
#
# Epoch 00045: val_loss did not improve from 0.03311
# Epoch 46/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 7.9764e-05 - accuracy: 1.0000 - val_loss: 0.0330 - val_accuracy: 0.9861
#
# Epoch 00046: val_accuracy did not improve from 0.98611
#
# Epoch 00046: val_loss improved from 0.03311 to 0.03300, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 47/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 7.6648e-05 - accuracy: 1.0000 - val_loss: 0.0330 - val_accuracy: 0.9861
#
# Epoch 00047: val_accuracy did not improve from 0.98611
#
# Epoch 00047: val_loss did not improve from 0.03300
# Epoch 48/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 7.4514e-05 - accuracy: 1.0000 - val_loss: 0.0331 - val_accuracy: 0.9861
#
# Epoch 00048: val_accuracy did not improve from 0.98611
#
# Epoch 00048: val_loss did not improve from 0.03300
# Epoch 49/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 7.0179e-05 - accuracy: 1.0000 - val_loss: 0.0328 - val_accuracy: 0.9861
#
# Epoch 00049: val_accuracy did not improve from 0.98611
#
# Epoch 00049: val_loss improved from 0.03300 to 0.03280, saving model to lightningedge007a_results/yes/liking/s29/min_loss_yes_liking_s29.h5
# Epoch 50/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.8342e-05 - accuracy: 1.0000 - val_loss: 0.0330 - val_accuracy: 0.9861
#
# Epoch 00050: val_accuracy did not improve from 0.98611
#
# Epoch 00050: val_loss did not improve from 0.03280
# 240/240 [==============================] - 1s 4ms/step
# max acc:  [0.012371254401902359, 0.9958333373069763]
# 240/240 [==============================] - 1s 4ms/step
# min loss:  [0.009275887797897061, 0.9958333373069763]

# %%
data_files=data_files[29:]
data_files
# Out:
# ['s30', 's31', 's32']

# %%
np.random.seed(32)

window_size = 128

cnn_suffix ='.mat_win_128_cnn_dataset.pkl'
rnn_suffix ='.mat_win_128_rnn_dataset.pkl'
label_suffix ='.mat_win_128_labels.pkl'

for with_or_without in baseline_preprocessing:
    for arousal_or_valence in emotions:
        for data_file in data_files:
            
            gc.collect()
            
            print('---------------------------------------------------')
            print(with_or_without+' '+arousal_or_valence+' '+data_file)
            print('---------------------------------------------------\n')

            #data_file    ='s17'
            #arousal_or_valence = 'valence'
            #with_or_without = 'yes'

            dataset_dir = 'deap_shuffled_data/'+with_or_without+'_'+arousal_or_valence+'/'
            ###load training set
            try:
                with open(dataset_dir + data_file + cnn_suffix, "rb") as fp:
                    cnn_datasets = pickle.load(fp)
                with open(dataset_dir + data_file + rnn_suffix, "rb") as fp:
                    rnn_datasets = pickle.load(fp)
                with open(dataset_dir + data_file + label_suffix, "rb") as fp:
                    labels = pickle.load(fp)
                    labels = np.transpose(labels)
                    print("loaded shape:",labels.shape)
            except:
                continue
            lables_backup = labels

            print(cnn_datasets.shape)
            print(rnn_datasets.shape)
            print(labels.shape)

            #print("cnn_dataset shape before reshape:", np.shape(cnn_datasets))
            # cnn_datasets = cnn_datasets.reshape(len(cnn_datasets), window_size, 9,9, 1)
            #print("cnn_dataset shape after reshape:", np.shape(cnn_datasets))
            one_hot_labels = np.array(list(pd.get_dummies(labels)))

            labels = np.asarray(pd.get_dummies(labels), dtype=np.int8)

            print(labels.shape)
            # shuffle data
            index = np.array(range(0, len(labels)))
            np.random.shuffle(index)

            cnn_datasets   = cnn_datasets[index]
            rnn_datasets   = rnn_datasets[index]
            labels  = labels[index]

            print(cnn_datasets.shape)
            print(rnn_datasets.shape)
            print(labels.shape)

            #print("**********(" + time.asctime(time.localtime(time.time())) + ") Load and Split dataset End **********\n")
            #print("**********(" + time.asctime(time.localtime(time.time())) + ") Define parameters and functions Begin: **********\n")
            print('cnn_datasets.shape,rnn_datasets.shape,labels.shape : ',cnn_datasets.shape,rnn_datasets.shape,labels.shape)
            #important
            cnn_datasets=cnn_datasets.reshape(2400,9,9,-1)# imp
            print(cnn_datasets.shape)
            print('cnn_datasets.shape : ',cnn_datasets.shape)







            print('========================Train / Test Shapes==============================')



            fold=10
            curr_fold=0
            #for curr_fold in range(fold): # kernel dies
                
            #   print('curr_fold / fold : ',curr_fold,' / ',fold)


            max_acc_acc_list=[]

            max_acc_loss_list=[]


            min_loss_acc_list=[]

            min_loss_loss_list=[]

            fold_size = cnn_datasets.shape[0]//fold
            indexes_list = [i for i in range(len(cnn_datasets))]
            indexes = np.array(indexes_list)
            split_list = [i for i in range(curr_fold*fold_size,(curr_fold+1)*fold_size)]
            split = np.array(split_list)

            cnn_test = cnn_datasets[split] 
            labels_test = labels[split]
            rnn_test = rnn_datasets[split]

            split = np.array(list(set(indexes_list)^set(split_list)))

            cnn_train = cnn_datasets[split]
            rnn_train = rnn_datasets[split]
            labels_train = labels[split]

            # train_sample = labels_train.shape[0]
            # print("training examples:", train_sample)
            # test_sample = labels_test.shape[0]
            # print("test examples    :",test_sample)
            print(cnn_test.shape,rnn_test.shape,cnn_train.shape,rnn_train.shape)

            print('================================ DNN ============================================')

            input_cnn=Input(shape=(9,9,128))

            print('input_cnn: ',input_cnn.shape)

            conv1=Conv2D(32,
                          kernel_size=(4,4),
                          strides=(1,1),
                          padding='same',
                          input_shape=(9,9,128)
                         )(input_cnn)


            bn1=BatchNormalization()(conv1)

            elu1=ELU()(bn1)

            print('elu1: ',elu1.shape)
            #?,9,9,32
            conv2=Conv2D(64,
                          kernel_size=(4,4),
                          strides=(1,1),
                          padding='same'
                         )(elu1)

            bn2=BatchNormalization()(conv2)

            elu2=ELU()(bn2)

            print('elu2: ',elu2.shape)
            #?,9,9,64

            conv3=Conv2D(128,
                          kernel_size=(4,4),
                          strides=(1,1),
                          padding='same'
                         )(elu2)

            bn3=BatchNormalization()(conv3)

            elu3=ELU()(bn3)


            print('elu3: ',elu3.shape)
            #?,9,9,128

            # mc.add(Flatten())
            # mc.add(Lambda(lambda x:x,output_shape=(9,9,32*4*128)))
            # mc.add(Lambda(K.reshape((-1,9,9,32*4*128))))
            reshape1=Reshape((9,9,-1))(elu3)


            print('reshape1: ',reshape1.shape)
            #?,9,9,32*4*128

            conv4=Conv2D(13,#32*4*128,
                          kernel_size=(1,1),
                          strides=(1,1),
                          padding='same'
                         )(reshape1)

            bn4=BatchNormalization()(conv4)

            elu4=ELU()(bn4)


            print('elu4: ',elu4.shape)
            #?,9,9,13 #32*4*128

            # mc.add(Flatten())

            # mc.add(Lambda(lambda x:x,output_shape=([13*9*9])))
            # mc.add(Lambda(K.reshape((None,13*9*9))))
            reshape2=Reshape(([13*9*9]))(elu4)


            print('reshape2: ',reshape2.shape)




            cnn_out_fuse=reshape2


            # cube=K.reshape(e3,(-1,9,9,32*4*128))#(e3)


            # flat=K.reshape(e4,(-1,13*9*9))#(e4) #1053

            # rnn_in=K.placeholder(shape=(None,128,32))
            # rnn_in=tf.convert_to_tensor(rnn_datasets,dtype='float32')


            # rnn_in.get_shape().as_list()

            # rnn_in=K.placeholder(shape=(None,128,32))
            # rnn_in_flat=K.reshape(rnn_in,[-1,32])

            # print('rnn_in ',rnn_in.shape)

            input_rnn=Input(shape=(128,32))
            print('input_rnn',input_rnn.shape)

            rnn_in_flat=Reshape((-1,32))(input_rnn)
            print('rnn_in_flat',rnn_in_flat.shape)
            # rnn_in_flat = Lambda(lambda x:x[:,0])(input_rnn)

            # rnn_fc_in1 =Dense(32)(rnn_in_flat)
            rnn_fc_in1 =Dense(1024)(rnn_in_flat)
            rnn_fc_in=ELU()(rnn_fc_in1)
            print('rnn_fc_in',rnn_fc_in.shape)

            # rnn_fc_in =Dense(1024)(input_rnn)

            # lstm_in=Reshape((-1,128,1024))(rnn_fc_in)
            lstm_in=Reshape((-1,1024))(rnn_fc_in)
            print('lstm_in',lstm_in.shape)

            cells=[]

            for i in range(2):
                cell=LSTMCell(32,unit_forget_bias=True,dropout=0.5)#'forget_bias'=1.0,'state_is_tuple'=True
                cells.append(cell)
            #     print(cell.shape)

            # lstm_cell=StackedRNNCells(cells)
            lstm_cell=RNN(cells)(lstm_in)
            # print(lstm_cell.shape)
            # op,states=RNN(cells)(lstm_in)
            print('lstm_cell',lstm_cell.shape)
            # output=K.transpose_shape((1,0,2),lstm_cell)
            # output=Permute((1,0,2))(lstm_cell)
            # output.reshape()
            output=lstm_cell
            print('output',output.shape)
            rnn_output=output[-1]
            # rnn_output

            print('rnn_output',rnn_output.shape)
            # shape_rnn_out=rnn_output.get_shape().as_list()
            lstm_fc_out=Dense(1024)(output)#shape_rnn_out[1]

            print('lstm_fc_out',lstm_fc_out.shape)


            # lstm_fc_out_2=Dense(1053)(lstm_fc_out)#shape_rnn_out[1]



            lstm_fc_drop=Dropout(0.5)(lstm_fc_out)
            # lstm_fc_drop
            print('lstm_fc_drop',lstm_fc_drop.shape)

            # fuse_cnn_rnn=add([cnn_out_fuse,lstm_fc_drop])

            fuse_cnn_rnn=concatenate([cnn_out_fuse,lstm_fc_drop])
            print('fuse_cnn_rnn ',fuse_cnn_rnn.shape)
            y=Dense(2,activation='softmax')(fuse_cnn_rnn) ## ,activity_regularizer=regularizers.l2(0.5)
            print(y.shape)
            y_pred=K.argmax(y,1)
            # y_pred=K.argmax(K.softmax(y))
            # y_posi=K.softmax(y)
            print('y ',y)


            directory_le007a='./lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file
            try:
                if not os.path.exists(directory_le007a):
                    os.makedirs(directory_le007a)
            except OSError:
                print ('Error: Creating directory. ' +  directory_le007a)



            model=Model(inputs=[input_cnn,input_rnn],outputs=y)
            model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

            print('Model : ',with_or_without+'_'+arousal_or_valence+'_'+data_file+'_'+str(curr_fold)+'_fold')
            print(model.summary())

            m_val_acc=ModelCheckpoint('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'max_acc_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.h5',monitor='val_accuracy',mode='max',verbose=1,save_best_only=True)
            m_val_loss=ModelCheckpoint('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'min_loss_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.h5',monitor='val_loss',mode='min',verbose=1,save_best_only=True)


            tb_log_dir='lightningedge007a_results\\'+with_or_without+'\\'+arousal_or_valence+'\\'+data_file+'\\'+'logs_'+with_or_without+'_'+arousal_or_valence+'_'+data_file
            #tb_log_dir='lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'logs_'+with_or_without+'_'+arousal_or_valence+'_'+data_file

            createFolder(tb_log_dir)


            #log_dir='lightningedge007a_results\\'+with_or_without+'\\'+arousal_or_valence+'\\'+data_file+'\\'+'logs_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'_'+str(curr_fold)+'_fold\\' #datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
            tensorboard_callback = callbacks.TensorBoard(log_dir=tb_log_dir)#, histogram_freq=1)

            plotpicture=plot_model(model, to_file='lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'model_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.png', show_shapes=True)

            
            
            gc.collect()
            
            

            history=model.fit([cnn_train,rnn_train],labels_train,batch_size=128,epochs=50,callbacks=[tensorboard_callback,m_val_acc,m_val_loss],validation_split=0.2)


            #Plot values
            plt.plot(history.history['accuracy'])
            plt.plot(history.history['val_accuracy'])
            plt.title('max_acc_'+with_or_without+'_'+arousal_or_valence+'_'+data_file)
            plt.ylabel('Accuracy')
            plt.xlabel('Epoch')
            plt.legend(['Train', 'Validation'], loc='upper right',bbox_to_anchor=(1.3,1))
            plt.savefig('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'max_acc_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.png',bbox_inches='tight')
            #plt.show()
            plt.close()


            # Plot training & validation loss values
            plt.plot(history.history['loss'])
            plt.plot(history.history['val_loss'])
            plt.title('min_loss_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'_'+str(curr_fold)+'_fold')
            plt.ylabel('Loss')
            plt.xlabel('Epoch')
            plt.legend(['Train', 'Validation'], loc='upper right',bbox_to_anchor=(1.3,1))
            plt.savefig('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'min_loss_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.png',bbox_inches='tight')
            #plt.show()
            plt.close()

            vam=load_model('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'max_acc_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.h5')
            vlm=load_model('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'min_loss_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.h5')
            # pred_labels=vam()
            vam_eval=vam.evaluate([cnn_test,rnn_test],labels_test)
            print('max acc: ',vam_eval)
            vlm_eval=vlm.evaluate([cnn_test,rnn_test],labels_test)
            print('min loss: ',vlm_eval)


            max_acc_acc_list.append(vam_eval[1])

            max_acc_loss_list.append(vam_eval[0])


            min_loss_acc_list.append(vlm_eval[1])

            min_loss_loss_list.append(vlm_eval[0])

            pickle.dump(max_acc_acc_list,open('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'max_acc_acc_list_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.pkl','wb'))

            pickle.dump(max_acc_loss_list,open('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'max_acc_loss_list_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.pkl','wb'))


            pickle.dump(min_loss_acc_list,open('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'min_loss_acc_list_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.pkl','wb'))

            pickle.dump(min_loss_loss_list,open('lightningedge007a_results/'+with_or_without+'/'+arousal_or_valence+'/'+data_file+'/'+'min_loss_loss_list_'+with_or_without+'_'+arousal_or_valence+'_'+data_file+'.pkl','wb'))
            
            
            gc.collect()
# Out:
# ---------------------------------------------------
# yes liking s30
# ---------------------------------------------------
#
# loaded shape: (2400,)
# (2400, 128, 9, 9)
# (2400, 128, 32)
# (2400,)
# (2400, 2)
# (2400, 128, 9, 9)
# (2400, 128, 32)
# (2400, 2)
# cnn_datasets.shape,rnn_datasets.shape,labels.shape :  (2400, 128, 9, 9) (2400, 128, 32) (2400, 2)
# (2400, 9, 9, 128)
# cnn_datasets.shape :  (2400, 9, 9, 128)
# ========================Train / Test Shapes==============================
# (240, 9, 9, 128) (240, 128, 32) (2160, 9, 9, 128) (2160, 128, 32)
# ================================ DNN ============================================
# input_cnn:  (None, 9, 9, 128)
# elu1:  (None, 9, 9, 32)
# elu2:  (None, 9, 9, 64)
# elu3:  (None, 9, 9, 128)
# reshape1:  (None, 9, 9, None)
# elu4:  (None, 9, 9, 13)
# reshape2:  (None, 1053)
# input_rnn (None, 128, 32)
# rnn_in_flat (None, None, 32)
# rnn_fc_in (None, 128, 1024)
# lstm_in (None, None, 1024)
# lstm_cell (None, 32)
# output (None, 32)
# rnn_output (32,)
# lstm_fc_out (None, 1024)
# lstm_fc_drop (None, 1024)
# fuse_cnn_rnn  (None, 2077)
# (None, 2)
# y  Tensor("dense_3/Softmax:0", shape=(None, 2), dtype=float32)
# Model :  yes_liking_s30_0_fold
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 9, 9, 128)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 9, 9, 32)     65568       input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 9, 9, 32)     128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# elu_1 (ELU)                     (None, 9, 9, 32)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 9, 9, 64)     32832       elu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 9, 9, 64)     256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# elu_2 (ELU)                     (None, 9, 9, 64)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 9, 9, 128)    131200      elu_2[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 128, 32)      0
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 9, 9, 128)    512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 128, 32)      0           input_2[0][0]
# __________________________________________________________________________________________________
# elu_3 (ELU)                     (None, 9, 9, 128)    0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128, 1024)    33792       reshape_3[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 9, 9, 128)    0           elu_3[0][0]
# __________________________________________________________________________________________________
# elu_5 (ELU)                     (None, 128, 1024)    0           dense_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 9, 9, 13)     1677        reshape_1[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 128, 1024)    0           elu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 9, 9, 13)     52          conv2d_4[0][0]
# __________________________________________________________________________________________________
# rnn_1 (RNN)                     (None, 32)           143616      reshape_4[0][0]
# __________________________________________________________________________________________________
# elu_4 (ELU)                     (None, 9, 9, 13)     0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1024)         33792       rnn_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1053)         0           elu_4[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           dense_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2077)         0           reshape_2[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            4156        concatenate_1[0][0]
# ==================================================================================================
# Total params: 447,581
# Trainable params: 447,107
# Non-trainable params: 474
# __________________________________________________________________________________________________
# None
# Train on 1728 samples, validate on 432 samples
# Epoch 1/50
#  256/1728 [===>..........................] - ETA: 19s - loss: 0.8682 - accuracy: 0.5664
# C:\Users\ABHISHEK_VERMA\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (10.262465). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1728/1728 [==============================] - 27s 15ms/step - loss: 0.3131 - accuracy: 0.8611 - val_loss: 0.1808 - val_accuracy: 0.9468
#
# Epoch 00001: val_accuracy improved from -inf to 0.94676, saving model to lightningedge007a_results/yes/liking/s30/max_acc_yes_liking_s30.h5
#
# Epoch 00001: val_loss improved from inf to 0.18076, saving model to lightningedge007a_results/yes/liking/s30/min_loss_yes_liking_s30.h5
# Epoch 2/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0509 - accuracy: 0.9803 - val_loss: 0.1398 - val_accuracy: 0.9537
#
# Epoch 00002: val_accuracy improved from 0.94676 to 0.95370, saving model to lightningedge007a_results/yes/liking/s30/max_acc_yes_liking_s30.h5
#
# Epoch 00002: val_loss improved from 0.18076 to 0.13982, saving model to lightningedge007a_results/yes/liking/s30/min_loss_yes_liking_s30.h5
# Epoch 3/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0170 - accuracy: 0.9959 - val_loss: 0.1207 - val_accuracy: 0.9745
#
# Epoch 00003: val_accuracy improved from 0.95370 to 0.97454, saving model to lightningedge007a_results/yes/liking/s30/max_acc_yes_liking_s30.h5
#
# Epoch 00003: val_loss improved from 0.13982 to 0.12069, saving model to lightningedge007a_results/yes/liking/s30/min_loss_yes_liking_s30.h5
# Epoch 4/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.1027 - val_accuracy: 0.9745
#
# Epoch 00004: val_accuracy did not improve from 0.97454
#
# Epoch 00004: val_loss improved from 0.12069 to 0.10274, saving model to lightningedge007a_results/yes/liking/s30/min_loss_yes_liking_s30.h5
# Epoch 5/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0980 - val_accuracy: 0.9769
#
# Epoch 00005: val_accuracy improved from 0.97454 to 0.97685, saving model to lightningedge007a_results/yes/liking/s30/max_acc_yes_liking_s30.h5
#
# Epoch 00005: val_loss improved from 0.10274 to 0.09801, saving model to lightningedge007a_results/yes/liking/s30/min_loss_yes_liking_s30.h5
# Epoch 6/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0981 - val_accuracy: 0.9722
#
# Epoch 00006: val_accuracy did not improve from 0.97685
#
# Epoch 00006: val_loss did not improve from 0.09801
# Epoch 7/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0973 - val_accuracy: 0.9745
#
# Epoch 00007: val_accuracy did not improve from 0.97685
#
# Epoch 00007: val_loss improved from 0.09801 to 0.09734, saving model to lightningedge007a_results/yes/liking/s30/min_loss_yes_liking_s30.h5
# Epoch 8/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0977 - val_accuracy: 0.9745
#
# Epoch 00008: val_accuracy did not improve from 0.97685
#
# Epoch 00008: val_loss did not improve from 0.09734
# Epoch 9/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.5734e-04 - accuracy: 1.0000 - val_loss: 0.0982 - val_accuracy: 0.9745
#
# Epoch 00009: val_accuracy did not improve from 0.97685
#
# Epoch 00009: val_loss did not improve from 0.09734
# Epoch 10/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 8.3291e-04 - accuracy: 1.0000 - val_loss: 0.0987 - val_accuracy: 0.9769
#
# Epoch 00010: val_accuracy did not improve from 0.97685
#
# Epoch 00010: val_loss did not improve from 0.09734
# Epoch 11/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 7.2081e-04 - accuracy: 1.0000 - val_loss: 0.1009 - val_accuracy: 0.9745
#
# Epoch 00011: val_accuracy did not improve from 0.97685
#
# Epoch 00011: val_loss did not improve from 0.09734
# Epoch 12/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 6.1382e-04 - accuracy: 1.0000 - val_loss: 0.1021 - val_accuracy: 0.9769
#
# Epoch 00012: val_accuracy did not improve from 0.97685
#
# Epoch 00012: val_loss did not improve from 0.09734
# Epoch 13/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.4496e-04 - accuracy: 1.0000 - val_loss: 0.1025 - val_accuracy: 0.9769
#
# Epoch 00013: val_accuracy did not improve from 0.97685
#
# Epoch 00013: val_loss did not improve from 0.09734
# Epoch 14/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.9078e-04 - accuracy: 1.0000 - val_loss: 0.1045 - val_accuracy: 0.9769
#
# Epoch 00014: val_accuracy did not improve from 0.97685
#
# Epoch 00014: val_loss did not improve from 0.09734
# Epoch 15/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.4279e-04 - accuracy: 1.0000 - val_loss: 0.1060 - val_accuracy: 0.9769
#
# Epoch 00015: val_accuracy did not improve from 0.97685
#
# Epoch 00015: val_loss did not improve from 0.09734
# Epoch 16/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.9786e-04 - accuracy: 1.0000 - val_loss: 0.1081 - val_accuracy: 0.9769
#
# Epoch 00016: val_accuracy did not improve from 0.97685
#
# Epoch 00016: val_loss did not improve from 0.09734
# Epoch 17/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.5546e-04 - accuracy: 1.0000 - val_loss: 0.1085 - val_accuracy: 0.9769
#
# Epoch 00017: val_accuracy did not improve from 0.97685
#
# Epoch 00017: val_loss did not improve from 0.09734
# Epoch 18/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.2203e-04 - accuracy: 1.0000 - val_loss: 0.1103 - val_accuracy: 0.9769
#
# Epoch 00018: val_accuracy did not improve from 0.97685
#
# Epoch 00018: val_loss did not improve from 0.09734
# Epoch 19/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.9301e-04 - accuracy: 1.0000 - val_loss: 0.1123 - val_accuracy: 0.9769
#
# Epoch 00019: val_accuracy did not improve from 0.97685
#
# Epoch 00019: val_loss did not improve from 0.09734
# Epoch 20/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.7682e-04 - accuracy: 1.0000 - val_loss: 0.1134 - val_accuracy: 0.9769
#
# Epoch 00020: val_accuracy did not improve from 0.97685
#
# Epoch 00020: val_loss did not improve from 0.09734
# Epoch 21/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.5002e-04 - accuracy: 1.0000 - val_loss: 0.1135 - val_accuracy: 0.9769
#
# Epoch 00021: val_accuracy did not improve from 0.97685
#
# Epoch 00021: val_loss did not improve from 0.09734
# Epoch 22/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.3430e-04 - accuracy: 1.0000 - val_loss: 0.1146 - val_accuracy: 0.9769
#
# Epoch 00022: val_accuracy did not improve from 0.97685
#
# Epoch 00022: val_loss did not improve from 0.09734
# Epoch 23/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.1536e-04 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9769
#
# Epoch 00023: val_accuracy did not improve from 0.97685
#
# Epoch 00023: val_loss did not improve from 0.09734
# Epoch 24/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.0348e-04 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9769
#
# Epoch 00024: val_accuracy did not improve from 0.97685
#
# Epoch 00024: val_loss did not improve from 0.09734
# Epoch 25/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.8906e-04 - accuracy: 1.0000 - val_loss: 0.1177 - val_accuracy: 0.9769
#
# Epoch 00025: val_accuracy did not improve from 0.97685
#
# Epoch 00025: val_loss did not improve from 0.09734
# Epoch 26/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.7960e-04 - accuracy: 1.0000 - val_loss: 0.1179 - val_accuracy: 0.9769
#
# Epoch 00026: val_accuracy did not improve from 0.97685
#
# Epoch 00026: val_loss did not improve from 0.09734
# Epoch 27/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 1.6346e-04 - accuracy: 1.0000 - val_loss: 0.1189 - val_accuracy: 0.9769
#
# Epoch 00027: val_accuracy did not improve from 0.97685
#
# Epoch 00027: val_loss did not improve from 0.09734
# Epoch 28/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.5669e-04 - accuracy: 1.0000 - val_loss: 0.1198 - val_accuracy: 0.9769
#
# Epoch 00028: val_accuracy did not improve from 0.97685
#
# Epoch 00028: val_loss did not improve from 0.09734
# Epoch 29/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.4616e-04 - accuracy: 1.0000 - val_loss: 0.1208 - val_accuracy: 0.9769
#
# Epoch 00029: val_accuracy did not improve from 0.97685
#
# Epoch 00029: val_loss did not improve from 0.09734
# Epoch 30/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.3674e-04 - accuracy: 1.0000 - val_loss: 0.1214 - val_accuracy: 0.9769
#
# Epoch 00030: val_accuracy did not improve from 0.97685
#
# Epoch 00030: val_loss did not improve from 0.09734
# Epoch 31/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.2944e-04 - accuracy: 1.0000 - val_loss: 0.1222 - val_accuracy: 0.9769
#
# Epoch 00031: val_accuracy did not improve from 0.97685
#
# Epoch 00031: val_loss did not improve from 0.09734
# Epoch 32/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.1965e-04 - accuracy: 1.0000 - val_loss: 0.1232 - val_accuracy: 0.9769
#
# Epoch 00032: val_accuracy did not improve from 0.97685
#
# Epoch 00032: val_loss did not improve from 0.09734
# Epoch 33/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.1703e-04 - accuracy: 1.0000 - val_loss: 0.1228 - val_accuracy: 0.9769
#
# Epoch 00033: val_accuracy did not improve from 0.97685
#
# Epoch 00033: val_loss did not improve from 0.09734
# Epoch 34/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.0837e-04 - accuracy: 1.0000 - val_loss: 0.1226 - val_accuracy: 0.9769
#
# Epoch 00034: val_accuracy did not improve from 0.97685
#
# Epoch 00034: val_loss did not improve from 0.09734
# Epoch 35/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.0355e-04 - accuracy: 1.0000 - val_loss: 0.1230 - val_accuracy: 0.9769
#
# Epoch 00035: val_accuracy did not improve from 0.97685
#
# Epoch 00035: val_loss did not improve from 0.09734
# Epoch 36/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.0027e-04 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9769
#
# Epoch 00036: val_accuracy did not improve from 0.97685
#
# Epoch 00036: val_loss did not improve from 0.09734
# Epoch 37/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.5483e-05 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9769
#
# Epoch 00037: val_accuracy did not improve from 0.97685
#
# Epoch 00037: val_loss did not improve from 0.09734
# Epoch 38/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.1920e-05 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9769
#
# Epoch 00038: val_accuracy did not improve from 0.97685
#
# Epoch 00038: val_loss did not improve from 0.09734
# Epoch 39/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 8.6153e-05 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9769
#
# Epoch 00039: val_accuracy did not improve from 0.97685
#
# Epoch 00039: val_loss did not improve from 0.09734
# Epoch 40/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 8.2225e-05 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9769
#
# Epoch 00040: val_accuracy did not improve from 0.97685
#
# Epoch 00040: val_loss did not improve from 0.09734
# Epoch 41/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 8.1695e-05 - accuracy: 1.0000 - val_loss: 0.1258 - val_accuracy: 0.9769
#
# Epoch 00041: val_accuracy did not improve from 0.97685
#
# Epoch 00041: val_loss did not improve from 0.09734
# Epoch 42/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 7.7409e-05 - accuracy: 1.0000 - val_loss: 0.1264 - val_accuracy: 0.9769
#
# Epoch 00042: val_accuracy did not improve from 0.97685
#
# Epoch 00042: val_loss did not improve from 0.09734
# Epoch 43/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 7.2032e-05 - accuracy: 1.0000 - val_loss: 0.1265 - val_accuracy: 0.9769
#
# Epoch 00043: val_accuracy did not improve from 0.97685
#
# Epoch 00043: val_loss did not improve from 0.09734
# Epoch 44/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.8983e-05 - accuracy: 1.0000 - val_loss: 0.1271 - val_accuracy: 0.9769
#
# Epoch 00044: val_accuracy did not improve from 0.97685
#
# Epoch 00044: val_loss did not improve from 0.09734
# Epoch 45/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.5210e-05 - accuracy: 1.0000 - val_loss: 0.1274 - val_accuracy: 0.9769
#
# Epoch 00045: val_accuracy did not improve from 0.97685
#
# Epoch 00045: val_loss did not improve from 0.09734
# Epoch 46/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.4978e-05 - accuracy: 1.0000 - val_loss: 0.1277 - val_accuracy: 0.9769
#
# Epoch 00046: val_accuracy did not improve from 0.97685
#
# Epoch 00046: val_loss did not improve from 0.09734
# Epoch 47/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.2385e-05 - accuracy: 1.0000 - val_loss: 0.1277 - val_accuracy: 0.9769
#
# Epoch 00047: val_accuracy did not improve from 0.97685
#
# Epoch 00047: val_loss did not improve from 0.09734
# Epoch 48/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.8860e-05 - accuracy: 1.0000 - val_loss: 0.1287 - val_accuracy: 0.9769
#
# Epoch 00048: val_accuracy did not improve from 0.97685
#
# Epoch 00048: val_loss did not improve from 0.09734
# Epoch 49/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.7287e-05 - accuracy: 1.0000 - val_loss: 0.1287 - val_accuracy: 0.9769
#
# Epoch 00049: val_accuracy did not improve from 0.97685
#
# Epoch 00049: val_loss did not improve from 0.09734
# Epoch 50/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.4726e-05 - accuracy: 1.0000 - val_loss: 0.1293 - val_accuracy: 0.9769
#
# Epoch 00050: val_accuracy did not improve from 0.97685
#
# Epoch 00050: val_loss did not improve from 0.09734
# 240/240 [==============================] - 1s 4ms/step
# max acc:  [0.05792577862739563, 0.987500011920929]
# 240/240 [==============================] - 1s 4ms/step
# min loss:  [0.051636899014314015, 0.9916666746139526]
# ---------------------------------------------------
# yes liking s31
# ---------------------------------------------------
#
# loaded shape: (2400,)
# (2400, 128, 9, 9)
# (2400, 128, 32)
# (2400,)
# (2400, 2)
# (2400, 128, 9, 9)
# (2400, 128, 32)
# (2400, 2)
# cnn_datasets.shape,rnn_datasets.shape,labels.shape :  (2400, 128, 9, 9) (2400, 128, 32) (2400, 2)
# (2400, 9, 9, 128)
# cnn_datasets.shape :  (2400, 9, 9, 128)
# ========================Train / Test Shapes==============================
# (240, 9, 9, 128) (240, 128, 32) (2160, 9, 9, 128) (2160, 128, 32)
# ================================ DNN ============================================
# input_cnn:  (None, 9, 9, 128)
# elu1:  (None, 9, 9, 32)
# elu2:  (None, 9, 9, 64)
# elu3:  (None, 9, 9, 128)
# reshape1:  (None, 9, 9, None)
# elu4:  (None, 9, 9, 13)
# reshape2:  (None, 1053)
# input_rnn (None, 128, 32)
# rnn_in_flat (None, None, 32)
# rnn_fc_in (None, 128, 1024)
# lstm_in (None, None, 1024)
# lstm_cell (None, 32)
# output (None, 32)
# rnn_output (32,)
# lstm_fc_out (None, 1024)
# lstm_fc_drop (None, 1024)
# fuse_cnn_rnn  (None, 2077)
# (None, 2)
# y  Tensor("dense_6/Softmax:0", shape=(None, 2), dtype=float32)
# Model :  yes_liking_s31_0_fold
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 9, 9, 128)    0
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 9, 9, 32)     65568       input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 9, 9, 32)     128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# elu_6 (ELU)                     (None, 9, 9, 32)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 9, 9, 64)     32832       elu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 9, 9, 64)     256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# elu_7 (ELU)                     (None, 9, 9, 64)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 9, 9, 128)    131200      elu_7[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 128, 32)      0
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 9, 9, 128)    512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 128, 32)      0           input_4[0][0]
# __________________________________________________________________________________________________
# elu_8 (ELU)                     (None, 9, 9, 128)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128, 1024)    33792       reshape_7[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 9, 9, 128)    0           elu_8[0][0]
# __________________________________________________________________________________________________
# elu_10 (ELU)                    (None, 128, 1024)    0           dense_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 9, 9, 13)     1677        reshape_5[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 128, 1024)    0           elu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 9, 9, 13)     52          conv2d_8[0][0]
# __________________________________________________________________________________________________
# rnn_2 (RNN)                     (None, 32)           143616      reshape_8[0][0]
# __________________________________________________________________________________________________
# elu_9 (ELU)                     (None, 9, 9, 13)     0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1024)         33792       rnn_2[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1053)         0           elu_9[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024)         0           dense_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 2077)         0           reshape_6[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 2)            4156        concatenate_2[0][0]
# ==================================================================================================
# Total params: 447,581
# Trainable params: 447,107
# Non-trainable params: 474
# __________________________________________________________________________________________________
# None
# Train on 1728 samples, validate on 432 samples
# Epoch 1/50
#  256/1728 [===>..........................] - ETA: 10s - loss: 0.6299 - accuracy: 0.6914
# C:\Users\ABHISHEK_VERMA\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (10.662632). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1728/1728 [==============================] - 26s 15ms/step - loss: 0.2931 - accuracy: 0.8773 - val_loss: 0.1761 - val_accuracy: 0.9398
#
# Epoch 00001: val_accuracy improved from -inf to 0.93981, saving model to lightningedge007a_results/yes/liking/s31/max_acc_yes_liking_s31.h5
#
# Epoch 00001: val_loss improved from inf to 0.17613, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 2/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0452 - accuracy: 0.9867 - val_loss: 0.0921 - val_accuracy: 0.9722
#
# Epoch 00002: val_accuracy improved from 0.93981 to 0.97222, saving model to lightningedge007a_results/yes/liking/s31/max_acc_yes_liking_s31.h5
#
# Epoch 00002: val_loss improved from 0.17613 to 0.09210, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 3/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0151 - accuracy: 0.9971 - val_loss: 0.0512 - val_accuracy: 0.9884
#
# Epoch 00003: val_accuracy improved from 0.97222 to 0.98843, saving model to lightningedge007a_results/yes/liking/s31/max_acc_yes_liking_s31.h5
#
# Epoch 00003: val_loss improved from 0.09210 to 0.05122, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 4/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0051 - accuracy: 0.9994 - val_loss: 0.0452 - val_accuracy: 0.9861
#
# Epoch 00004: val_accuracy did not improve from 0.98843
#
# Epoch 00004: val_loss improved from 0.05122 to 0.04520, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 5/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0443 - val_accuracy: 0.9815
#
# Epoch 00005: val_accuracy did not improve from 0.98843
#
# Epoch 00005: val_loss improved from 0.04520 to 0.04433, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 6/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9861
#
# Epoch 00006: val_accuracy did not improve from 0.98843
#
# Epoch 00006: val_loss improved from 0.04433 to 0.03973, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 7/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 8.1039e-04 - accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 0.9931
#
# Epoch 00007: val_accuracy improved from 0.98843 to 0.99306, saving model to lightningedge007a_results/yes/liking/s31/max_acc_yes_liking_s31.h5
#
# Epoch 00007: val_loss improved from 0.03973 to 0.03354, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 8/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.7163e-04 - accuracy: 1.0000 - val_loss: 0.0317 - val_accuracy: 0.9931
#
# Epoch 00008: val_accuracy did not improve from 0.99306
#
# Epoch 00008: val_loss improved from 0.03354 to 0.03167, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 9/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.6005e-04 - accuracy: 1.0000 - val_loss: 0.0300 - val_accuracy: 0.9931
#
# Epoch 00009: val_accuracy did not improve from 0.99306
#
# Epoch 00009: val_loss improved from 0.03167 to 0.03003, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 10/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.9954e-04 - accuracy: 1.0000 - val_loss: 0.0273 - val_accuracy: 0.9931
#
# Epoch 00010: val_accuracy did not improve from 0.99306
#
# Epoch 00010: val_loss improved from 0.03003 to 0.02731, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 11/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.4454e-04 - accuracy: 1.0000 - val_loss: 0.0269 - val_accuracy: 0.9931
#
# Epoch 00011: val_accuracy did not improve from 0.99306
#
# Epoch 00011: val_loss improved from 0.02731 to 0.02692, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 12/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.8742e-04 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9931
#
# Epoch 00012: val_accuracy did not improve from 0.99306
#
# Epoch 00012: val_loss improved from 0.02692 to 0.02560, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 13/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.5101e-04 - accuracy: 1.0000 - val_loss: 0.0246 - val_accuracy: 0.9931
#
# Epoch 00013: val_accuracy did not improve from 0.99306
#
# Epoch 00013: val_loss improved from 0.02560 to 0.02460, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 14/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.1351e-04 - accuracy: 1.0000 - val_loss: 0.0245 - val_accuracy: 0.9931
#
# Epoch 00014: val_accuracy did not improve from 0.99306
#
# Epoch 00014: val_loss improved from 0.02460 to 0.02447, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 15/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.8959e-04 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9931
#
# Epoch 00015: val_accuracy did not improve from 0.99306
#
# Epoch 00015: val_loss improved from 0.02447 to 0.02363, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 16/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.6416e-04 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 0.9931
#
# Epoch 00016: val_accuracy did not improve from 0.99306
#
# Epoch 00016: val_loss improved from 0.02363 to 0.02298, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 17/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.4280e-04 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 0.9931
#
# Epoch 00017: val_accuracy did not improve from 0.99306
#
# Epoch 00017: val_loss improved from 0.02298 to 0.02246, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 18/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.2359e-04 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 0.9931
#
# Epoch 00018: val_accuracy did not improve from 0.99306
#
# Epoch 00018: val_loss did not improve from 0.02246
# Epoch 19/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.0787e-04 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 0.9931
#
# Epoch 00019: val_accuracy did not improve from 0.99306
#
# Epoch 00019: val_loss did not improve from 0.02246
# Epoch 20/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.8914e-04 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9931
#
# Epoch 00020: val_accuracy did not improve from 0.99306
#
# Epoch 00020: val_loss improved from 0.02246 to 0.02175, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 21/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.7536e-04 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 0.9931
#
# Epoch 00021: val_accuracy did not improve from 0.99306
#
# Epoch 00021: val_loss improved from 0.02175 to 0.02149, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 22/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.6448e-04 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9931
#
# Epoch 00022: val_accuracy did not improve from 0.99306
#
# Epoch 00022: val_loss improved from 0.02149 to 0.02134, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 23/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.5614e-04 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9931
#
# Epoch 00023: val_accuracy did not improve from 0.99306
#
# Epoch 00023: val_loss improved from 0.02134 to 0.02109, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 24/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.4687e-04 - accuracy: 1.0000 - val_loss: 0.0214 - val_accuracy: 0.9931
# Epoch 00024: val_accuracy did not improve from 0.99306
#
# Epoch 00024: val_loss did not improve from 0.02109
# Epoch 25/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.3611e-04 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9931
#
# Epoch 00025: val_accuracy did not improve from 0.99306
#
# Epoch 00025: val_loss improved from 0.02109 to 0.02079, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 26/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.2625e-04 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9931
#
# Epoch 00026: val_accuracy did not improve from 0.99306
#
# Epoch 00026: val_loss did not improve from 0.02079
# Epoch 27/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.2042e-04 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9931
#
# Epoch 00027: val_accuracy did not improve from 0.99306
#
# Epoch 00027: val_loss did not improve from 0.02079
# Epoch 28/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.1212e-04 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9931
#
# Epoch 00028: val_accuracy did not improve from 0.99306
#
# Epoch 00028: val_loss did not improve from 0.02079
# Epoch 29/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.0811e-04 - accuracy: 1.0000 - val_loss: 0.0209 - val_accuracy: 0.9931
#
# Epoch 00029: val_accuracy did not improve from 0.99306
#
# Epoch 00029: val_loss did not improve from 0.02079
# Epoch 30/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.0163e-04 - accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 0.9931
#
# Epoch 00030: val_accuracy did not improve from 0.99306
#
# Epoch 00030: val_loss did not improve from 0.02079
# Epoch 31/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.6610e-05 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9931
#
# Epoch 00031: val_accuracy did not improve from 0.99306
#
# Epoch 00031: val_loss did not improve from 0.02079
# Epoch 32/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.3106e-05 - accuracy: 1.0000 - val_loss: 0.0209 - val_accuracy: 0.9931
#
# Epoch 00032: val_accuracy did not improve from 0.99306
#
# Epoch 00032: val_loss did not improve from 0.02079
# Epoch 33/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 8.6687e-05 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9931
#
# Epoch 00033: val_accuracy did not improve from 0.99306
#
# Epoch 00033: val_loss improved from 0.02079 to 0.02058, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 34/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 8.3768e-05 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9931
#
# Epoch 00034: val_accuracy did not improve from 0.99306
#
# Epoch 00034: val_loss did not improve from 0.02058
# Epoch 35/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 7.8767e-05 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9931
#
# Epoch 00035: val_accuracy did not improve from 0.99306
#
# Epoch 00035: val_loss did not improve from 0.02058
# Epoch 36/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 7.5334e-05 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9931
#
# Epoch 00036: val_accuracy did not improve from 0.99306
#
# Epoch 00036: val_loss did not improve from 0.02058
# Epoch 37/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 7.2861e-05 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9931
#
# Epoch 00037: val_accuracy did not improve from 0.99306
#
# Epoch 00037: val_loss did not improve from 0.02058
# Epoch 38/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.9483e-05 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9931
#
# Epoch 00038: val_accuracy did not improve from 0.99306
#
# Epoch 00038: val_loss did not improve from 0.02058
# Epoch 39/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.6675e-05 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9931
#
# Epoch 00039: val_accuracy did not improve from 0.99306
#
# Epoch 00039: val_loss improved from 0.02058 to 0.02056, saving model to lightningedge007a_results/yes/liking/s31/min_loss_yes_liking_s31.h5
# Epoch 40/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.4027e-05 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9931
#
# Epoch 00040: val_accuracy did not improve from 0.99306
#
# Epoch 00040: val_loss did not improve from 0.02056
# Epoch 41/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.0725e-05 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9931
#
# Epoch 00041: val_accuracy did not improve from 0.99306
#
# Epoch 00041: val_loss did not improve from 0.02056
# Epoch 42/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.8847e-05 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9931
#
# Epoch 00042: val_accuracy did not improve from 0.99306
#
# Epoch 00042: val_loss did not improve from 0.02056
# Epoch 43/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.6857e-05 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9931
#
# Epoch 00043: val_accuracy did not improve from 0.99306
#
# Epoch 00043: val_loss did not improve from 0.02056
# Epoch 44/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.4287e-05 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9931
#
# Epoch 00044: val_accuracy did not improve from 0.99306
#
# Epoch 00044: val_loss did not improve from 0.02056
# Epoch 45/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.2133e-05 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9931
#
# Epoch 00045: val_accuracy did not improve from 0.99306
#
# Epoch 00045: val_loss did not improve from 0.02056
# Epoch 46/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.0606e-05 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9931
#
# Epoch 00046: val_accuracy did not improve from 0.99306
#
# Epoch 00046: val_loss did not improve from 0.02056
# Epoch 47/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.8451e-05 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9931
#
# Epoch 00047: val_accuracy did not improve from 0.99306
#
# Epoch 00047: val_loss did not improve from 0.02056
# Epoch 48/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.6258e-05 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9931
#
# Epoch 00048: val_accuracy did not improve from 0.99306
#
# Epoch 00048: val_loss did not improve from 0.02056
# Epoch 49/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.5061e-05 - accuracy: 1.0000 - val_loss: 0.0209 - val_accuracy: 0.9931
#
# Epoch 00049: val_accuracy did not improve from 0.99306
#
# Epoch 00049: val_loss did not improve from 0.02056
# Epoch 50/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.3107e-05 - accuracy: 1.0000 - val_loss: 0.0209 - val_accuracy: 0.9931
#
# Epoch 00050: val_accuracy did not improve from 0.99306
#
# Epoch 00050: val_loss did not improve from 0.02056
# 240/240 [==============================] - 1s 4ms/step
# max acc:  [0.04309663139283657, 0.987500011920929]
# 240/240 [==============================] - 1s 5ms/step
# min loss:  [0.036660222134863335, 0.987500011920929]
# ---------------------------------------------------
# yes liking s32
# ---------------------------------------------------
#
# loaded shape: (2400,)
# (2400, 128, 9, 9)
# (2400, 128, 32)
# (2400,)
# (2400, 2)
# (2400, 128, 9, 9)
# (2400, 128, 32)
# (2400, 2)
# cnn_datasets.shape,rnn_datasets.shape,labels.shape :  (2400, 128, 9, 9) (2400, 128, 32) (2400, 2)
# (2400, 9, 9, 128)
# cnn_datasets.shape :  (2400, 9, 9, 128)
# ========================Train / Test Shapes==============================
# (240, 9, 9, 128) (240, 128, 32) (2160, 9, 9, 128) (2160, 128, 32)
# ================================ DNN ============================================
# input_cnn:  (None, 9, 9, 128)
# elu1:  (None, 9, 9, 32)
# elu2:  (None, 9, 9, 64)
# elu3:  (None, 9, 9, 128)
# reshape1:  (None, 9, 9, None)
# elu4:  (None, 9, 9, 13)
# reshape2:  (None, 1053)
# input_rnn (None, 128, 32)
# rnn_in_flat (None, None, 32)
# rnn_fc_in (None, 128, 1024)
# lstm_in (None, None, 1024)
# lstm_cell (None, 32)
# output (None, 32)
# rnn_output (32,)
# lstm_fc_out (None, 1024)
# lstm_fc_drop (None, 1024)
# fuse_cnn_rnn  (None, 2077)
# (None, 2)
# y  Tensor("dense_9/Softmax:0", shape=(None, 2), dtype=float32)
# Model :  yes_liking_s32_0_fold
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 9, 9, 128)    0
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 9, 9, 32)     65568       input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 9, 9, 32)     128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# elu_11 (ELU)                    (None, 9, 9, 32)     0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 9, 9, 64)     32832       elu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 9, 9, 64)     256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# elu_12 (ELU)                    (None, 9, 9, 64)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 9, 9, 128)    131200      elu_12[0][0]
# __________________________________________________________________________________________________
# input_6 (InputLayer)            (None, 128, 32)      0
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 9, 9, 128)    512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 128, 32)      0           input_6[0][0]
# __________________________________________________________________________________________________
# elu_13 (ELU)                    (None, 9, 9, 128)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 128, 1024)    33792       reshape_11[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 9, 9, 128)    0           elu_13[0][0]
# __________________________________________________________________________________________________
# elu_15 (ELU)                    (None, 128, 1024)    0           dense_7[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 2077)         0           reshape_10[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 2)            4156        concatenate_3[0][0]
# ==================================================================================================
# Total params: 447,581
# Trainable params: 447,107
# Non-trainable params: 474
# __________________________________________________________________________________________________
# None
# Train on 1728 samples, validate on 432 samples
# Epoch 1/50
#  256/1728 [===>..........................] - ETA: 10s - loss: 1.0633 - accuracy: 0.5273
# C:\Users\ABHISHEK_VERMA\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (10.761387). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 1728/1728 [==============================] - 27s 15ms/step - loss: 0.5282 - accuracy: 0.7940 - val_loss: 0.3718 - val_accuracy: 0.8333
#
# Epoch 00001: val_accuracy improved from -inf to 0.83333, saving model to lightningedge007a_results/yes/liking/s32/max_acc_yes_liking_s32.h5
#
# Epoch 00001: val_loss improved from inf to 0.37176, saving model to lightningedge007a_results/yes/liking/s32/min_loss_yes_liking_s32.h5
# Epoch 2/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.1764 - accuracy: 0.9392 - val_loss: 0.2387 - val_accuracy: 0.9028
#
# Epoch 00002: val_accuracy improved from 0.83333 to 0.90278, saving model to lightningedge007a_results/yes/liking/s32/max_acc_yes_liking_s32.h5
#
# Epoch 00002: val_loss improved from 0.37176 to 0.23870, saving model to lightningedge007a_results/yes/liking/s32/min_loss_yes_liking_s32.h5
# Epoch 3/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0652 - accuracy: 0.9792 - val_loss: 0.1891 - val_accuracy: 0.9259
#
# Epoch 00003: val_accuracy improved from 0.90278 to 0.92593, saving model to lightningedge007a_results/yes/liking/s32/max_acc_yes_liking_s32.h5
#
# Epoch 00003: val_loss improved from 0.23870 to 0.18911, saving model to lightningedge007a_results/yes/liking/s32/min_loss_yes_liking_s32.h5
# Epoch 4/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 0.0316 - accuracy: 0.9959 - val_loss: 0.1531 - val_accuracy: 0.9444
#
# Epoch 00004: val_accuracy improved from 0.92593 to 0.94444, saving model to lightningedge007a_results/yes/liking/s32/max_acc_yes_liking_s32.h5
#
# Epoch 00004: val_loss improved from 0.18911 to 0.15307, saving model to lightningedge007a_results/yes/liking/s32/min_loss_yes_liking_s32.h5
# Epoch 5/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0155 - accuracy: 0.9988 - val_loss: 0.1323 - val_accuracy: 0.9560
#
# Epoch 00005: val_accuracy improved from 0.94444 to 0.95602, saving model to lightningedge007a_results/yes/liking/s32/max_acc_yes_liking_s32.h5
#
# Epoch 00005: val_loss improved from 0.15307 to 0.13228, saving model to lightningedge007a_results/yes/liking/s32/min_loss_yes_liking_s32.h5
# Epoch 6/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.1279 - val_accuracy: 0.9444
#
# Epoch 00006: val_accuracy did not improve from 0.95602
#
# Epoch 00006: val_loss improved from 0.13228 to 0.12793, saving model to lightningedge007a_results/yes/liking/s32/min_loss_yes_liking_s32.h5
# Epoch 7/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.1198 - val_accuracy: 0.9537
#
# Epoch 00007: val_accuracy did not improve from 0.95602
#
# Epoch 00007: val_loss improved from 0.12793 to 0.11980, saving model to lightningedge007a_results/yes/liking/s32/min_loss_yes_liking_s32.h5
# Epoch 8/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1170 - val_accuracy: 0.9606
#
# Epoch 00008: val_accuracy improved from 0.95602 to 0.96065, saving model to lightningedge007a_results/yes/liking/s32/max_acc_yes_liking_s32.h5
#
# Epoch 00008: val_loss improved from 0.11980 to 0.11702, saving model to lightningedge007a_results/yes/liking/s32/min_loss_yes_liking_s32.h5
# Epoch 9/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1141 - val_accuracy: 0.9583
#
# Epoch 00009: val_accuracy did not improve from 0.96065
#
# Epoch 00009: val_loss improved from 0.11702 to 0.11414, saving model to lightningedge007a_results/yes/liking/s32/min_loss_yes_liking_s32.h5
# Epoch 10/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1105 - val_accuracy: 0.9606
#
# Epoch 00010: val_accuracy did not improve from 0.96065
#
# Epoch 00010: val_loss improved from 0.11414 to 0.11048, saving model to lightningedge007a_results/yes/liking/s32/min_loss_yes_liking_s32.h5
# Epoch 11/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 0.9606
#
# Epoch 00011: val_accuracy did not improve from 0.96065
#
# Epoch 00011: val_loss improved from 0.11048 to 0.10988, saving model to lightningedge007a_results/yes/liking/s32/min_loss_yes_liking_s32.h5
# Epoch 12/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1075 - val_accuracy: 0.9606
#
# Epoch 00012: val_accuracy did not improve from 0.96065
#
# Epoch 00012: val_loss improved from 0.10988 to 0.10747, saving model to lightningedge007a_results/yes/liking/s32/min_loss_yes_liking_s32.h5
# Epoch 13/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1081 - val_accuracy: 0.9606
#
# Epoch 00013: val_accuracy did not improve from 0.96065
#
# Epoch 00013: val_loss did not improve from 0.10747
# Epoch 14/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1071 - val_accuracy: 0.9630
#
# Epoch 00014: val_accuracy improved from 0.96065 to 0.96296, saving model to lightningedge007a_results/yes/liking/s32/max_acc_yes_liking_s32.h5
#
# Epoch 00014: val_loss improved from 0.10747 to 0.10705, saving model to lightningedge007a_results/yes/liking/s32/min_loss_yes_liking_s32.h5
# Epoch 15/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1082 - val_accuracy: 0.9606
#
# Epoch 00015: val_accuracy did not improve from 0.96296
#
# Epoch 00015: val_loss did not improve from 0.10705
# Epoch 16/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 9.2613e-04 - accuracy: 1.0000 - val_loss: 0.1081 - val_accuracy: 0.9583
#
# Epoch 00016: val_accuracy did not improve from 0.96296
#
# Epoch 00016: val_loss did not improve from 0.10705
# Epoch 17/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 8.3206e-04 - accuracy: 1.0000 - val_loss: 0.1096 - val_accuracy: 0.9583
#
# Epoch 00017: val_accuracy did not improve from 0.96296
#
# Epoch 00017: val_loss did not improve from 0.10705
# Epoch 18/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 7.6084e-04 - accuracy: 1.0000 - val_loss: 0.1086 - val_accuracy: 0.9583
#
# Epoch 00018: val_accuracy did not improve from 0.96296
#
# Epoch 00018: val_loss did not improve from 0.10705
# Epoch 19/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.8977e-04 - accuracy: 1.0000 - val_loss: 0.1078 - val_accuracy: 0.9583
#
# Epoch 00019: val_accuracy did not improve from 0.96296
#
# Epoch 00019: val_loss did not improve from 0.10705
# Epoch 20/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 6.2545e-04 - accuracy: 1.0000 - val_loss: 0.1092 - val_accuracy: 0.9583
#
# Epoch 00020: val_accuracy did not improve from 0.96296
#
# Epoch 00020: val_loss did not improve from 0.10705
# Epoch 21/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.7556e-04 - accuracy: 1.0000 - val_loss: 0.1096 - val_accuracy: 0.9537
#
# Epoch 00021: val_accuracy did not improve from 0.96296
#
# Epoch 00021: val_loss did not improve from 0.10705
# Epoch 22/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 5.2339e-04 - accuracy: 1.0000 - val_loss: 0.1093 - val_accuracy: 0.9606
#
# Epoch 00022: val_accuracy did not improve from 0.96296
#
# Epoch 00022: val_loss did not improve from 0.10705
# Epoch 23/50
# 1728/1728 [==============================] - 4s 2ms/step - loss: 4.8709e-04 - accuracy: 1.0000 - val_loss: 0.1094 - val_accuracy: 0.9537
#
# Epoch 00023: val_accuracy did not improve from 0.96296
#
# Epoch 00023: val_loss did not improve from 0.10705
# Epoch 24/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.5121e-04 - accuracy: 1.0000 - val_loss: 0.1103 - val_accuracy: 0.9583
#
# Epoch 00024: val_accuracy did not improve from 0.96296
#
# Epoch 00024: val_loss did not improve from 0.10705
# Epoch 25/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 4.1365e-04 - accuracy: 1.0000 - val_loss: 0.1113 - val_accuracy: 0.9583
#
# Epoch 00025: val_accuracy did not improve from 0.96296
#
# Epoch 00025: val_loss did not improve from 0.10705
# Epoch 26/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.8882e-04 - accuracy: 1.0000 - val_loss: 0.1122 - val_accuracy: 0.9583
#
# Epoch 00026: val_accuracy did not improve from 0.96296
#
# Epoch 00026: val_loss did not improve from 0.10705
# Epoch 27/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.6146e-04 - accuracy: 1.0000 - val_loss: 0.1110 - val_accuracy: 0.9606
#
# Epoch 00027: val_accuracy did not improve from 0.96296
#
# Epoch 00027: val_loss did not improve from 0.10705
# Epoch 28/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.4122e-04 - accuracy: 1.0000 - val_loss: 0.1103 - val_accuracy: 0.9606
#
# Epoch 00028: val_accuracy did not improve from 0.96296
#
# Epoch 00028: val_loss did not improve from 0.10705
# Epoch 29/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 3.1673e-04 - accuracy: 1.0000 - val_loss: 0.1125 - val_accuracy: 0.9560
#
# Epoch 00029: val_accuracy did not improve from 0.96296
#
# Epoch 00029: val_loss did not improve from 0.10705
# Epoch 30/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.9855e-04 - accuracy: 1.0000 - val_loss: 0.1127 - val_accuracy: 0.9537
#
# Epoch 00030: val_accuracy did not improve from 0.96296
#
# Epoch 00030: val_loss did not improve from 0.10705
# Epoch 31/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.8108e-04 - accuracy: 1.0000 - val_loss: 0.1131 - val_accuracy: 0.9606
#
# Epoch 00031: val_accuracy did not improve from 0.96296
#
# Epoch 00031: val_loss did not improve from 0.10705
# Epoch 32/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.6416e-04 - accuracy: 1.0000 - val_loss: 0.1124 - val_accuracy: 0.9583
#
# Epoch 00032: val_accuracy did not improve from 0.96296
#
# Epoch 00032: val_loss did not improve from 0.10705
# Epoch 33/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.5427e-04 - accuracy: 1.0000 - val_loss: 0.1136 - val_accuracy: 0.9583
#
# Epoch 00033: val_accuracy did not improve from 0.96296
#
# Epoch 00033: val_loss did not improve from 0.10705
# Epoch 34/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.3706e-04 - accuracy: 1.0000 - val_loss: 0.1148 - val_accuracy: 0.9583
#
# Epoch 00034: val_accuracy did not improve from 0.96296
#
# Epoch 00034: val_loss did not improve from 0.10705
# Epoch 35/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.2464e-04 - accuracy: 1.0000 - val_loss: 0.1133 - val_accuracy: 0.9583
#
# Epoch 00035: val_accuracy did not improve from 0.96296
#
# Epoch 00035: val_loss did not improve from 0.10705
# Epoch 36/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.1481e-04 - accuracy: 1.0000 - val_loss: 0.1136 - val_accuracy: 0.9606
#
# Epoch 00036: val_accuracy did not improve from 0.96296
#
# Epoch 00036: val_loss did not improve from 0.10705
# Epoch 37/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 2.0181e-04 - accuracy: 1.0000 - val_loss: 0.1139 - val_accuracy: 0.9583
#
# Epoch 00037: val_accuracy did not improve from 0.96296
#
# Epoch 00037: val_loss did not improve from 0.10705
# Epoch 38/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.9340e-04 - accuracy: 1.0000 - val_loss: 0.1144 - val_accuracy: 0.9583
#
# Epoch 00038: val_accuracy did not improve from 0.96296
#
# Epoch 00038: val_loss did not improve from 0.10705
# Epoch 39/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.8289e-04 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 0.9583
#
# Epoch 00039: val_accuracy did not improve from 0.96296
#
# Epoch 00039: val_loss did not improve from 0.10705
# Epoch 40/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.7590e-04 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9583
#
# Epoch 00040: val_accuracy did not improve from 0.96296
#
# Epoch 00040: val_loss did not improve from 0.10705
# Epoch 41/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.6774e-04 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 0.9583
#
# Epoch 00041: val_accuracy did not improve from 0.96296
#
# Epoch 00041: val_loss did not improve from 0.10705
# Epoch 42/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.6002e-04 - accuracy: 1.0000 - val_loss: 0.1146 - val_accuracy: 0.9583
#
# Epoch 00042: val_accuracy did not improve from 0.96296
#
# Epoch 00042: val_loss did not improve from 0.10705
# Epoch 43/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.5275e-04 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9583
#
# Epoch 00043: val_accuracy did not improve from 0.96296
#
# Epoch 00043: val_loss did not improve from 0.10705
# Epoch 44/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.4780e-04 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9583
#
# Epoch 00044: val_accuracy did not improve from 0.96296
#
# Epoch 00044: val_loss did not improve from 0.10705
# Epoch 45/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.3894e-04 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9583
#
# Epoch 00045: val_accuracy did not improve from 0.96296
#
# Epoch 00045: val_loss did not improve from 0.10705
# Epoch 46/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.3621e-04 - accuracy: 1.0000 - val_loss: 0.1164 - val_accuracy: 0.9560
#
# Epoch 00046: val_accuracy did not improve from 0.96296
#
# Epoch 00046: val_loss did not improve from 0.10705
# Epoch 47/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.3180e-04 - accuracy: 1.0000 - val_loss: 0.1166 - val_accuracy: 0.9583
#
# Epoch 00047: val_accuracy did not improve from 0.96296
#
# Epoch 00047: val_loss did not improve from 0.10705
# Epoch 48/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.2524e-04 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9583
#
# Epoch 00048: val_accuracy did not improve from 0.96296
#
# Epoch 00048: val_loss did not improve from 0.10705
# Epoch 49/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.1975e-04 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9583
#
# Epoch 00049: val_accuracy did not improve from 0.96296
#
# Epoch 00049: val_loss did not improve from 0.10705
# Epoch 50/50
# 1728/1728 [==============================] - 3s 2ms/step - loss: 1.1712e-04 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9583
#
# Epoch 00050: val_accuracy did not improve from 0.96296
#
# Epoch 00050: val_loss did not improve from 0.10705
# 240/240 [==============================] - 1s 4ms/step
# max acc:  [0.06748919064799945, 0.9750000238418579]
# 240/240 [==============================] - 1s 4ms/step
# min loss:  [0.06748919064799945, 0.9750000238418579]
