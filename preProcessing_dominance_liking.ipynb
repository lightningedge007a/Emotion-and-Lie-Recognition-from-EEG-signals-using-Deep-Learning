# %%
import numpy as np
import os
import time
import scipy.io as sio
import pandas as pd
import time
import pickle

np.random.seed(0)

def windows(data, size):
    start = 0
    while ((start+size) < data.shape[0]):
        yield int(start), int(start + size)
        start += size
        
def data_1Dto2D(data, Y=9, X=9):
    data_2D = np.zeros([Y, X])
    data_2D[0] = (0,0,0,data[0],0,data[16],0,0,0)
    data_2D[1] = (0,0,0,data[1],0,data[17],0,0,0)
    data_2D[2] = (data[3],0,data[2],0,data[18],0,data[19],0,data[20])
    data_2D[3] = (0,data[4],0,data[5],0,data[22],0,data[21],0)
    data_2D[4] = (data[7],0,data[6],0,data[23],0,data[24],0,data[25])
    data_2D[5] = (0,data[8],0,data[9],0,data[27],0,data[26],0)
    data_2D[6] = (data[11],0,data[10],0,data[15],0,data[28],0,data[29])
    data_2D[7] = (0,0,0,data[12],0,data[30],0,0,0)
    data_2D[8] = (0,0,0,data[13],data[14],data[31],0,0,0)
    # return shape:9*9
    return data_2D


def dataset_1Dto2D(dataset_1D):
    dataset_2D = np.zeros([dataset_1D.shape[0],9,9])
    for i in range(dataset_1D.shape[0]):
        dataset_2D[i] = data_1Dto2D(dataset_1D[i])
    # return shape: m*9*9
    return dataset_2D

def apply_mixup(dataset_file,window_size,label,yes_or_not): # initial empty label arrays
    
    print("Processing",dataset_file,'----------------')
    
#     file=dataset_dir+record_list[0]
#     label='valence'
    data_file_in = sio.loadmat(dataset_file)
#     print(data_file_in['data'].shape)
#     print(data_file_in['data'].transpose(0,2,1).shape)
    data_in = data_file_in["data"].transpose(0,2,1)
    if label=="dominance":
        label=2
    elif label=="liking":
        label=3
    label_in= data_file_in["labels"][:,label]>5
#     print(label_in.shape,label_in[1])
    # label_in
    label_inter	= np.empty([0]) # initial empty data arrays
    data_inter_cnn	= np.empty([0,window_size, 9, 9])
    data_inter_rnn	= np.empty([0, window_size, 32])
    trials = data_in.shape[0]
#     print(data_inter_cnn.shape,data_inter_rnn.shape,trials)
    # Data pre-processing
    # for trial in range(0,trials):
    # data_inter_cnn[0]
    # print(data_in)
#     yes_or_not='yes'
    for trial in range(0,trials):#trials
        if yes_or_not=="yes":
            base_signal = (data_in[trial,0:128,0:32]+data_in[trial,128:256,0:32]+data_in[trial,256:384,0:32])/3
    #         print(base_signal.shape)
    #         base_signal/=3
    #         print('+++++',base_signal.shape)

        else:
            base_signal = 0
        data = data_in[trial,384:8064,0:32]
    #     print(data.shape)
        # compute the deviation between baseline signals and experimental signals
        for i in range(0,60):
            data[i*128:(i+1)*128,0:32]=data[i*128:(i+1)*128,0:32]-base_signal
        label_index = trial
    #     print(data.shape)
#         label_index = trial
        #read data and label
    #     data = norm_dataset(data)

        norm_dataset_1D = np.zeros([data.shape[0], 32])
        for i in range(data.shape[0]):
    #         norm_dataset_1D[i] = feature_normalize(data[i])
            data_i=data[i]
            mean = data_i[data_i.nonzero()].mean()
            sigma = data_i[data_i. nonzero ()].std()
            data_normalized = data_i
            data_normalized[data_normalized.nonzero()] = (data_normalized[data_normalized.nonzero()] - mean)/sigma

            norm_dataset_1D[i]=data_normalized

        # 8064 - 7680 = 384 = 128*3 (for 3 secs & 128 hertz each)
    #     print('=======')
    #     print(norm_dataset_1D.shape)


    #     data, label = segment_signal_without_transition(data, label_in,label_index,window_size)


        for (start, end) in windows(data, window_size):
            # print(data.shape)
            if((len(data[start:end]) == window_size)):
                if(start == 0):
                    segments = data[start:end]
                    segments = np.vstack([segments, data[start:end]])

                    labels = np.array(label_in[label_index])
                    labels = np.append(labels, np.array(label_in[label_index]))
                else:
                    segments = np.vstack([segments, data[start:end]])
                    labels = np.append(labels, np.array(label_in[label_index])) # labels = np.append(labels, stats.mode(label[start:end])[0][0])
    #     return segments, labels
        data,label=segments,labels

    #     print(trial,'trial ',data.shape,label.shape)

        # cnn data process
    #     print('++++++++')
        data_cnn    = dataset_1Dto2D(data)
    #     print(data_cnn.shape)
        data_cnn    = data_cnn.reshape(int(data_cnn.shape[0]/window_size), window_size, 9, 9)
    #     print(data_cnn.shape)
        # rnn data process
        data_rnn    = data.reshape(int(data.shape[0]/window_size), window_size, 32)
    #     print(data_rnn.shape)
        # append new data and label
        data_inter_cnn  = np.vstack([data_inter_cnn, data_cnn])
        data_inter_rnn  = np.vstack([data_inter_rnn, data_rnn])
        label_inter = np.append(label_inter, label)
    #     print(data_inter_cnn.shape)
    #     print(data_inter_rnn.shape)
    #     print(label_inter.shape)

    # shuffle data
    index = np.array(range(0, len(label_inter)))
    np.random.shuffle(index)
    shuffled_data_cnn= data_inter_cnn[index]
    shuffled_data_rnn= data_inter_rnn[index]
    shuffled_label= label_inter[index]
#     print(shuffled_data_cnn.shape) # what is 120 for 120,128,9,9
#     print(shuffled_data_rnn.shape)
#     print(shuffled_label.shape)
#     print(len(record_list))
    return shuffled_data_cnn ,shuffled_data_rnn,shuffled_label,record_list

# %%
label_classes_list=['dominance','liking']
suffixes_list=['no','yes']

# %%
begin=time.time()
for label_class in label_classes_list:
    for suffix in suffixes_list:
        print('----------------------------------------------------------------')
        print('label_class = ',label_class,'suffix = ',suffix)
        begin1 = time.time()
        # print("time begin:",time.localtime())
        dataset_dir='deap_matlab_files/'
#         label_class='arousal'
#         suffix='yes'
        window_size=128
        record_list=[i for i in os.listdir(dataset_dir) if 
                     os.path.isfile(os.path.join(dataset_dir,i))]
        # record_list
        output_dir=   "./deap_shuffled_data/"
        output_dir = output_dir+suffix+"_"+label_class+"/"
        if os.path.isdir(output_dir)==False:
                os.makedirs(output_dir)

        for i in record_list:
            begin2=time.time()
            
            file = os.path.join(dataset_dir,i)
            shuffled_cnn_data,shuffled_rnn_data,shuffled_label,record = apply_mixup(file, window_size,label_class,suffix)
            output_data_cnn = output_dir+i+"_win_"+str(window_size)+"_cnn_dataset.pkl"
            output_data_rnn = output_dir+i+"_win_"+str(window_size)+"_rnn_dataset.pkl"
            output_label= output_dir+i+"_win_"+str(window_size)+"_labels.pkl"

            with open(output_data_cnn, "wb") as fp:
                pickle.dump( shuffled_cnn_data,fp, protocol=4)
            with open( output_data_rnn, "wb") as fp:
                pickle.dump(shuffled_rnn_data, fp, protocol=4)
            with open(output_label, "wb") as fp:
                pickle.dump(shuffled_label, fp)
                
            end2=time.time()
            print('record ',i,' time -> ',(end2-begin2))
        
        end1 = time.time()
        #     print("end time:",time.localtime())
        # https://stackoverflow.com/questions/23582489/python-pickle-protocol-choice
        print('combination time -> ',(end1-begin1))
        print('----------------------------------------------------------------')

end=time.time()
print('total time -> ',(end-begin))
# Out:
# ----------------------------------------------------------------
# label_class =  dominance suffix =  no
# Processing deap_matlab_files/s01.mat ----------------
# record  s01.mat  time ->  17.27570676803589
# Processing deap_matlab_files/s02.mat ----------------
# record  s02.mat  time ->  19.540966033935547
# Processing deap_matlab_files/s03.mat ----------------
# record  s03.mat  time ->  17.779021978378296
# Processing deap_matlab_files/s04.mat ----------------
# record  s04.mat  time ->  18.194594860076904
# Processing deap_matlab_files/s05.mat ----------------
# record  s05.mat  time ->  18.003814697265625
# Processing deap_matlab_files/s06.mat ----------------
# record  s06.mat  time ->  17.718780279159546
# Processing deap_matlab_files/s07.mat ----------------
# record  s07.mat  time ->  18.02548313140869
# Processing deap_matlab_files/s08.mat ----------------
# record  s08.mat  time ->  18.561907291412354
# Processing deap_matlab_files/s09.mat ----------------
# record  s09.mat  time ->  18.135215520858765
# Processing deap_matlab_files/s10.mat ----------------
# record  s10.mat  time ->  17.634613513946533
# Processing deap_matlab_files/s11.mat ----------------
# record  s11.mat  time ->  17.919719457626343
# Processing deap_matlab_files/s12.mat ----------------
# record  s12.mat  time ->  17.760475635528564
# Processing deap_matlab_files/s13.mat ----------------
# record  s13.mat  time ->  17.686177015304565
# Processing deap_matlab_files/s14.mat ----------------
# record  s14.mat  time ->  17.76470971107483
# Processing deap_matlab_files/s15.mat ----------------
# record  s15.mat  time ->  18.276325464248657
# Processing deap_matlab_files/s16.mat ----------------
# record  s16.mat  time ->  18.13590717315674
# Processing deap_matlab_files/s17.mat ----------------
# record  s17.mat  time ->  17.48016858100891
# Processing deap_matlab_files/s18.mat ----------------
# record  s18.mat  time ->  18.265788793563843
# Processing deap_matlab_files/s19.mat ----------------
# record  s19.mat  time ->  17.935396194458008
# Processing deap_matlab_files/s20.mat ----------------
# record  s20.mat  time ->  18.86601972579956
# Processing deap_matlab_files/s21.mat ----------------
# record  s21.mat  time ->  18.237455129623413
# Processing deap_matlab_files/s22.mat ----------------
# record  s22.mat  time ->  18.66818904876709
# Processing deap_matlab_files/s23.mat ----------------
# record  s23.mat  time ->  18.714565753936768
# Processing deap_matlab_files/s24.mat ----------------
# record  s24.mat  time ->  19.21018695831299
# Processing deap_matlab_files/s25.mat ----------------
# record  s25.mat  time ->  18.1427321434021
# Processing deap_matlab_files/s26.mat ----------------
# record  s26.mat  time ->  18.698352336883545
# Processing deap_matlab_files/s27.mat ----------------
# record  s27.mat  time ->  19.1395161151886
# Processing deap_matlab_files/s28.mat ----------------
# record  s28.mat  time ->  19.08624505996704
# Processing deap_matlab_files/s29.mat ----------------
# record  s29.mat  time ->  18.31850028038025
# Processing deap_matlab_files/s30.mat ----------------
# record  s30.mat  time ->  19.031631469726562
# Processing deap_matlab_files/s31.mat ----------------
# record  s31.mat  time ->  17.915732860565186
# Processing deap_matlab_files/s32.mat ----------------
# record  s32.mat  time ->  18.434043407440186
# combination time ->  584.5828986167908
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# label_class =  dominance suffix =  yes
# Processing deap_matlab_files/s01.mat ----------------
# record  s01.mat  time ->  18.75976538658142
# Processing deap_matlab_files/s02.mat ----------------
# record  s02.mat  time ->  19.43228793144226
# Processing deap_matlab_files/s03.mat ----------------
# record  s03.mat  time ->  19.03837275505066
# Processing deap_matlab_files/s04.mat ----------------
# record  s04.mat  time ->  19.416030645370483
# Processing deap_matlab_files/s05.mat ----------------
# record  s05.mat  time ->  18.811811447143555
# Processing deap_matlab_files/s06.mat ----------------
# record  s06.mat  time ->  18.48703932762146
# Processing deap_matlab_files/s07.mat ----------------
# record  s07.mat  time ->  18.541550159454346
# Processing deap_matlab_files/s08.mat ----------------
# record  s08.mat  time ->  18.796372175216675
# Processing deap_matlab_files/s09.mat ----------------
# record  s09.mat  time ->  17.720515489578247
# Processing deap_matlab_files/s10.mat ----------------
# record  s10.mat  time ->  18.27619957923889
# Processing deap_matlab_files/s11.mat ----------------
# record  s11.mat  time ->  19.12967872619629
# Processing deap_matlab_files/s12.mat ----------------
# record  s12.mat  time ->  18.511566400527954
# Processing deap_matlab_files/s13.mat ----------------
# record  s13.mat  time ->  19.044785261154175
# Processing deap_matlab_files/s14.mat ----------------
# record  s14.mat  time ->  18.773715257644653
# Processing deap_matlab_files/s15.mat ----------------
# record  s15.mat  time ->  20.700883150100708
# Processing deap_matlab_files/s16.mat ----------------
# record  s16.mat  time ->  20.04334592819214
# Processing deap_matlab_files/s17.mat ----------------
# record  s17.mat  time ->  18.13539719581604
# Processing deap_matlab_files/s18.mat ----------------
# record  s18.mat  time ->  18.139124155044556
# Processing deap_matlab_files/s19.mat ----------------
# record  s19.mat  time ->  20.089961051940918
# Processing deap_matlab_files/s20.mat ----------------
# record  s20.mat  time ->  17.72129249572754
# Processing deap_matlab_files/s21.mat ----------------
# record  s21.mat  time ->  17.66189432144165
# Processing deap_matlab_files/s22.mat ----------------
# record  s22.mat  time ->  19.235771656036377
# Processing deap_matlab_files/s23.mat ----------------
# record  s23.mat  time ->  18.706390142440796
# Processing deap_matlab_files/s24.mat ----------------
# record  s24.mat  time ->  17.948991537094116
# Processing deap_matlab_files/s25.mat ----------------
# record  s25.mat  time ->  17.958603620529175
# Processing deap_matlab_files/s26.mat ----------------
# record  s26.mat  time ->  18.862557411193848
# Processing deap_matlab_files/s27.mat ----------------
# record  s27.mat  time ->  17.806504487991333
# Processing deap_matlab_files/s28.mat ----------------
# record  s28.mat  time ->  19.83383059501648
# Processing deap_matlab_files/s29.mat ----------------
# record  s29.mat  time ->  19.438587188720703
# Processing deap_matlab_files/s30.mat ----------------
# record  s30.mat  time ->  19.219432830810547
# Processing deap_matlab_files/s31.mat ----------------
# record  s31.mat  time ->  17.885461568832397
# Processing deap_matlab_files/s32.mat ----------------
# record  s32.mat  time ->  18.94199252128601
# combination time ->  601.081684589386
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# label_class =  liking suffix =  no
# Processing deap_matlab_files/s01.mat ----------------
# record  s01.mat  time ->  19.006452560424805
# Processing deap_matlab_files/s02.mat ----------------
# record  s02.mat  time ->  19.05565333366394
# Processing deap_matlab_files/s03.mat ----------------
# record  s03.mat  time ->  19.04750084877014
# Processing deap_matlab_files/s04.mat ----------------
# record  s04.mat  time ->  19.179476737976074
# Processing deap_matlab_files/s05.mat ----------------
# record  s05.mat  time ->  20.81026315689087
# Processing deap_matlab_files/s06.mat ----------------
# record  s06.mat  time ->  19.648813247680664
# Processing deap_matlab_files/s07.mat ----------------
# record  s07.mat  time ->  19.54428195953369
# Processing deap_matlab_files/s08.mat ----------------
# record  s08.mat  time ->  18.83978509902954
# Processing deap_matlab_files/s09.mat ----------------
# record  s09.mat  time ->  19.51877212524414
# Processing deap_matlab_files/s10.mat ----------------
# record  s10.mat  time ->  19.660810947418213
# Processing deap_matlab_files/s11.mat ----------------
# record  s11.mat  time ->  19.683727025985718
# Processing deap_matlab_files/s12.mat ----------------
# record  s12.mat  time ->  20.395756483078003
# Processing deap_matlab_files/s13.mat ----------------
# record  s13.mat  time ->  19.39010763168335
# Processing deap_matlab_files/s14.mat ----------------
# record  s14.mat  time ->  18.91035485267639
# Processing deap_matlab_files/s15.mat ----------------
# record  s15.mat  time ->  19.199453115463257
# Processing deap_matlab_files/s16.mat ----------------
# record  s16.mat  time ->  20.098697185516357
# Processing deap_matlab_files/s17.mat ----------------
# record  s17.mat  time ->  19.43308138847351
# Processing deap_matlab_files/s18.mat ----------------
# record  s18.mat  time ->  19.9070827960968
# Processing deap_matlab_files/s19.mat ----------------
# record  s19.mat  time ->  20.158733129501343
# Processing deap_matlab_files/s20.mat ----------------
# record  s20.mat  time ->  18.480988025665283
# Processing deap_matlab_files/s21.mat ----------------
# record  s21.mat  time ->  19.976195573806763
# Processing deap_matlab_files/s22.mat ----------------
# record  s22.mat  time ->  19.323421239852905
# Processing deap_matlab_files/s23.mat ----------------
# record  s23.mat  time ->  19.263190031051636
# Processing deap_matlab_files/s24.mat ----------------
# record  s24.mat  time ->  19.241286516189575
# Processing deap_matlab_files/s25.mat ----------------
# record  s25.mat  time ->  18.467745065689087
# Processing deap_matlab_files/s26.mat ----------------
# record  s26.mat  time ->  19.37373995780945
# Processing deap_matlab_files/s27.mat ----------------
# record  s27.mat  time ->  19.36478328704834
# Processing deap_matlab_files/s28.mat ----------------
# record  s28.mat  time ->  18.210224628448486
# Processing deap_matlab_files/s29.mat ----------------
# record  s29.mat  time ->  18.848572254180908
# Processing deap_matlab_files/s30.mat ----------------
# record  s30.mat  time ->  18.717355728149414
# Processing deap_matlab_files/s31.mat ----------------
# record  s31.mat  time ->  18.533679962158203
# Processing deap_matlab_files/s32.mat ----------------
# record  s32.mat  time ->  17.869391441345215
# combination time ->  617.1753416061401
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# label_class =  liking suffix =  yes
# Processing deap_matlab_files/s01.mat ----------------
# record  s01.mat  time ->  18.336506366729736
# Processing deap_matlab_files/s02.mat ----------------
# record  s02.mat  time ->  19.113208532333374
# Processing deap_matlab_files/s03.mat ----------------
# record  s03.mat  time ->  19.156031608581543
# Processing deap_matlab_files/s04.mat ----------------
# record  s04.mat  time ->  18.962573051452637
# Processing deap_matlab_files/s05.mat ----------------
# record  s05.mat  time ->  18.435629844665527
# Processing deap_matlab_files/s06.mat ----------------
# record  s06.mat  time ->  18.317006826400757
# Processing deap_matlab_files/s07.mat ----------------
# record  s07.mat  time ->  18.40628409385681
# Processing deap_matlab_files/s08.mat ----------------
# record  s08.mat  time ->  19.738340854644775
# Processing deap_matlab_files/s09.mat ----------------
# record  s09.mat  time ->  18.993247509002686
# Processing deap_matlab_files/s10.mat ----------------
# record  s10.mat  time ->  19.16535449028015
# Processing deap_matlab_files/s11.mat ----------------
# record  s11.mat  time ->  19.127654790878296
# Processing deap_matlab_files/s12.mat ----------------
# record  s12.mat  time ->  20.570107460021973
# Processing deap_matlab_files/s13.mat ----------------
# record  s13.mat  time ->  20.41676616668701
# Processing deap_matlab_files/s14.mat ----------------
# record  s14.mat  time ->  20.155492067337036
# Processing deap_matlab_files/s15.mat ----------------
# record  s15.mat  time ->  19.30896806716919
# Processing deap_matlab_files/s16.mat ----------------
# record  s16.mat  time ->  20.223861694335938
# Processing deap_matlab_files/s17.mat ----------------
# record  s17.mat  time ->  19.240087509155273
# Processing deap_matlab_files/s18.mat ----------------
# record  s18.mat  time ->  17.82841944694519
# Processing deap_matlab_files/s19.mat ----------------
# record  s19.mat  time ->  19.143422842025757
# Processing deap_matlab_files/s20.mat ----------------
# record  s20.mat  time ->  23.23232364654541
# Processing deap_matlab_files/s21.mat ----------------
# record  s21.mat  time ->  37.42725920677185
# Processing deap_matlab_files/s22.mat ----------------
# record  s22.mat  time ->  33.64161396026611
# Processing deap_matlab_files/s23.mat ----------------
# record  s23.mat  time ->  37.30819749832153
# Processing deap_matlab_files/s24.mat ----------------
# record  s24.mat  time ->  34.77869462966919
# Processing deap_matlab_files/s25.mat ----------------
# record  s25.mat  time ->  28.914350748062134
# Processing deap_matlab_files/s26.mat ----------------
# record  s26.mat  time ->  19.473862886428833
# Processing deap_matlab_files/s27.mat ----------------
# record  s27.mat  time ->  18.830973863601685
# Processing deap_matlab_files/s28.mat ----------------
# record  s28.mat  time ->  19.820727825164795
# Processing deap_matlab_files/s29.mat ----------------
# record  s29.mat  time ->  19.746206283569336
# Processing deap_matlab_files/s30.mat ----------------
# record  s30.mat  time ->  18.351755380630493
# Processing deap_matlab_files/s31.mat ----------------
# record  s31.mat  time ->  18.060426712036133
# Processing deap_matlab_files/s32.mat ----------------
# record  s32.mat  time ->  19.28804302215576
# combination time ->  693.5253791809082
# ----------------------------------------------------------------
# total time ->  2496.374274253845

# %%
2496.374274253845/60
# Out:
# 41.60623790423075

# %%
3778.8399555683136/60.0
# Out:
# 62.98066592613856

# %%
2318.9093430042267/60
# Out:
# 38.648489050070445
