# %%
import numpy as np
import os
import time
import scipy.io as sio
import pandas as pd
import time
import pickle

np.random.seed(0)

def windows(data, size):
    start = 0
    while ((start+size) < data.shape[0]):
        yield int(start), int(start + size)
        start += size
        
def data_1Dto2D(data, Y=9, X=9):
    data_2D = np.zeros([Y, X])
    data_2D[0] = (0,0,0,data[0],0,data[16],0,0,0)
    data_2D[1] = (0,0,0,data[1],0,data[17],0,0,0)
    data_2D[2] = (data[3],0,data[2],0,data[18],0,data[19],0,data[20])
    data_2D[3] = (0,data[4],0,data[5],0,data[22],0,data[21],0)
    data_2D[4] = (data[7],0,data[6],0,data[23],0,data[24],0,data[25])
    data_2D[5] = (0,data[8],0,data[9],0,data[27],0,data[26],0)
    data_2D[6] = (data[11],0,data[10],0,data[15],0,data[28],0,data[29])
    data_2D[7] = (0,0,0,data[12],0,data[30],0,0,0)
    data_2D[8] = (0,0,0,data[13],data[14],data[31],0,0,0)
    # return shape:9*9
    return data_2D


def dataset_1Dto2D(dataset_1D):
    dataset_2D = np.zeros([dataset_1D.shape[0],9,9])
    for i in range(dataset_1D.shape[0]):
        dataset_2D[i] = data_1Dto2D(dataset_1D[i])
    # return shape: m*9*9
    return dataset_2D

def apply_mixup(dataset_file,window_size,label,yes_or_not): # initial empty label arrays
    
    print("Processing",dataset_file,'----------------')
    
#     file=dataset_dir+record_list[0]
#     label='valence'
    data_file_in = sio.loadmat(dataset_file)
#     print(data_file_in['data'].shape)
#     print(data_file_in['data'].transpose(0,2,1).shape)
    data_in = data_file_in["data"].transpose(0,2,1)
    if label=="arousal":
        label=1
    elif label=="valence":
        label=0
    label_in= data_file_in["labels"][:,label]>5
#     print(label_in.shape,label_in[1])
    # label_in
    label_inter	= np.empty([0]) # initial empty data arrays
    data_inter_cnn	= np.empty([0,window_size, 9, 9])
    data_inter_rnn	= np.empty([0, window_size, 32])
    trials = data_in.shape[0]
#     print(data_inter_cnn.shape,data_inter_rnn.shape,trials)
    # Data pre-processing
    # for trial in range(0,trials):
    # data_inter_cnn[0]
    # print(data_in)
#     yes_or_not='yes'
    for trial in range(0,trials):#trials
        if yes_or_not=="yes":
            base_signal = (data_in[trial,0:128,0:32]+data_in[trial,128:256,0:32]+data_in[trial,256:384,0:32])/3
    #         print(base_signal.shape)
    #         base_signal/=3
    #         print('+++++',base_signal.shape)

        else:
            base_signal = 0
        data = data_in[trial,384:8064,0:32]
    #     print(data.shape)
        # compute the deviation between baseline signals and experimental signals
        for i in range(0,60):
            data[i*128:(i+1)*128,0:32]=data[i*128:(i+1)*128,0:32]-base_signal
        label_index = trial
    #     print(data.shape)
#         label_index = trial
        #read data and label
    #     data = norm_dataset(data)

        norm_dataset_1D = np.zeros([data.shape[0], 32])
        for i in range(data.shape[0]):
    #         norm_dataset_1D[i] = feature_normalize(data[i])
            data_i=data[i]
            mean = data_i[data_i.nonzero()].mean()
            sigma = data_i[data_i. nonzero ()].std()
            data_normalized = data_i
            data_normalized[data_normalized.nonzero()] = (data_normalized[data_normalized.nonzero()] - mean)/sigma

            norm_dataset_1D[i]=data_normalized

        # 8064 - 7680 = 384 = 128*3 (for 3 secs & 128 hertz each)
    #     print('=======')
    #     print(norm_dataset_1D.shape)


    #     data, label = segment_signal_without_transition(data, label_in,label_index,window_size)


        for (start, end) in windows(data, window_size):
            # print(data.shape)
            if((len(data[start:end]) == window_size)):
                if(start == 0):
                    segments = data[start:end]
                    segments = np.vstack([segments, data[start:end]])

                    labels = np.array(label_in[label_index])
                    labels = np.append(labels, np.array(label_in[label_index]))
                else:
                    segments = np.vstack([segments, data[start:end]])
                    labels = np.append(labels, np.array(label_in[label_index])) # labels = np.append(labels, stats.mode(label[start:end])[0][0])
    #     return segments, labels
        data,label=segments,labels

    #     print(trial,'trial ',data.shape,label.shape)

        # cnn data process
    #     print('++++++++')
        data_cnn    = dataset_1Dto2D(data)
    #     print(data_cnn.shape)
        data_cnn    = data_cnn.reshape(int(data_cnn.shape[0]/window_size), window_size, 9, 9)
    #     print(data_cnn.shape)
        # rnn data process
        data_rnn    = data.reshape(int(data.shape[0]/window_size), window_size, 32)
    #     print(data_rnn.shape)
        # append new data and label
        data_inter_cnn  = np.vstack([data_inter_cnn, data_cnn])
        data_inter_rnn  = np.vstack([data_inter_rnn, data_rnn])
        label_inter = np.append(label_inter, label)
    #     print(data_inter_cnn.shape)
    #     print(data_inter_rnn.shape)
    #     print(label_inter.shape)

    # shuffle data
    index = np.array(range(0, len(label_inter)))
    np.random.shuffle(index)
    shuffled_data_cnn= data_inter_cnn[index]
    shuffled_data_rnn= data_inter_rnn[index]
    shuffled_label= label_inter[index]
#     print(shuffled_data_cnn.shape) # what is 120 for 120,128,9,9
#     print(shuffled_data_rnn.shape)
#     print(shuffled_label.shape)
#     print(len(record_list))
    return shuffled_data_cnn ,shuffled_data_rnn,shuffled_label,record_list

# %%
label_classes_list=['valence','arousal']
suffixes_list=['no','yes']

# %%
begin=time.time()
for label_class in label_classes_list:
    for suffix in suffixes_list:
        print('----------------------------------------------------------------')
        print('label_class = ',label_class,'suffix = ',suffix)
        begin1 = time.time()
        # print("time begin:",time.localtime())
        dataset_dir='deap_matlab_files/'
#         label_class='arousal'
#         suffix='yes'
        window_size=128
        record_list=[i for i in os.listdir(dataset_dir) if 
                     os.path.isfile(os.path.join(dataset_dir,i))]
        # record_list
        output_dir=   "./deap_shuffled_data/"
        output_dir = output_dir+suffix+"_"+label_class+"/"
        if os.path.isdir(output_dir)==False:
                os.makedirs(output_dir)

        for i in record_list:
            begin2=time.time()
            
            file = os.path.join(dataset_dir,i)
            shuffled_cnn_data,shuffled_rnn_data,shuffled_label,record = apply_mixup(file, window_size,label_class,suffix)
            output_data_cnn = output_dir+i+"_win_"+str(window_size)+"_cnn_dataset.pkl"
            output_data_rnn = output_dir+i+"_win_"+str(window_size)+"_rnn_dataset.pkl"
            output_label= output_dir+i+"_win_"+str(window_size)+"_labels.pkl"

            with open(output_data_cnn, "wb") as fp:
                pickle.dump( shuffled_cnn_data,fp, protocol=4)
            with open( output_data_rnn, "wb") as fp:
                pickle.dump(shuffled_rnn_data, fp, protocol=4)
            with open(output_label, "wb") as fp:
                pickle.dump(shuffled_label, fp)
                
            end2=time.time()
            print('record ',i,' time -> ',(end2-begin2))
        
        end1 = time.time()
        #     print("end time:",time.localtime())
        # https://stackoverflow.com/questions/23582489/python-pickle-protocol-choice
        print('combination time -> ',(end1-begin1))
        print('----------------------------------------------------------------')

end=time.time()
print('total time -> ',(end-begin))
# Out:
# ----------------------------------------------------------------
# label_class =  valence suffix =  no
# Processing deap_matlab_files/s01.mat ----------------
# record  s01.mat  time ->  16.257214069366455
# Processing deap_matlab_files/s02.mat ----------------
# record  s02.mat  time ->  17.195110082626343
# Processing deap_matlab_files/s03.mat ----------------
# record  s03.mat  time ->  18.544109344482422
# Processing deap_matlab_files/s04.mat ----------------
# record  s04.mat  time ->  16.805362462997437
# Processing deap_matlab_files/s05.mat ----------------
# record  s05.mat  time ->  16.94528293609619
# Processing deap_matlab_files/s06.mat ----------------
# record  s06.mat  time ->  17.389457941055298
# Processing deap_matlab_files/s07.mat ----------------
# record  s07.mat  time ->  16.79398202896118
# Processing deap_matlab_files/s08.mat ----------------
# record  s08.mat  time ->  17.100548028945923
# Processing deap_matlab_files/s09.mat ----------------
# record  s09.mat  time ->  17.319011211395264
# Processing deap_matlab_files/s10.mat ----------------
# record  s10.mat  time ->  17.37061595916748
# Processing deap_matlab_files/s11.mat ----------------
# record  s11.mat  time ->  16.618075847625732
# Processing deap_matlab_files/s12.mat ----------------
# record  s12.mat  time ->  17.17700219154358
# Processing deap_matlab_files/s13.mat ----------------
# record  s13.mat  time ->  16.391129970550537
# Processing deap_matlab_files/s14.mat ----------------
# record  s14.mat  time ->  16.554073333740234
# Processing deap_matlab_files/s15.mat ----------------
# record  s15.mat  time ->  16.36199378967285
# Processing deap_matlab_files/s16.mat ----------------
# record  s16.mat  time ->  16.541899919509888
# Processing deap_matlab_files/s17.mat ----------------
# record  s17.mat  time ->  16.70587396621704
# Processing deap_matlab_files/s18.mat ----------------
# record  s18.mat  time ->  17.093068599700928
# Processing deap_matlab_files/s19.mat ----------------
# record  s19.mat  time ->  16.438209772109985
# Processing deap_matlab_files/s20.mat ----------------
# record  s20.mat  time ->  20.7079758644104
# Processing deap_matlab_files/s21.mat ----------------
# record  s21.mat  time ->  17.629897356033325
# Processing deap_matlab_files/s22.mat ----------------
# record  s22.mat  time ->  17.258000373840332
# Processing deap_matlab_files/s23.mat ----------------
# record  s23.mat  time ->  17.90987467765808
# Processing deap_matlab_files/s24.mat ----------------
# record  s24.mat  time ->  16.93952202796936
# Processing deap_matlab_files/s25.mat ----------------
# record  s25.mat  time ->  17.699054718017578
# Processing deap_matlab_files/s26.mat ----------------
# record  s26.mat  time ->  17.58992624282837
# Processing deap_matlab_files/s27.mat ----------------
# record  s27.mat  time ->  17.399412393569946
# Processing deap_matlab_files/s28.mat ----------------
# record  s28.mat  time ->  16.86211133003235
# Processing deap_matlab_files/s29.mat ----------------
# record  s29.mat  time ->  17.17668128013611
# Processing deap_matlab_files/s30.mat ----------------
# record  s30.mat  time ->  16.83086395263672
# Processing deap_matlab_files/s31.mat ----------------
# record  s31.mat  time ->  19.171123027801514
# Processing deap_matlab_files/s32.mat ----------------
# record  s32.mat  time ->  20.810694217681885
# combination time ->  555.6030874252319
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# label_class =  valence suffix =  yes
# Processing deap_matlab_files/s01.mat ----------------
# record  s01.mat  time ->  16.754826545715332
# Processing deap_matlab_files/s02.mat ----------------
# record  s02.mat  time ->  17.648000478744507
# Processing deap_matlab_files/s03.mat ----------------
# record  s03.mat  time ->  17.39406108856201
# Processing deap_matlab_files/s04.mat ----------------
# record  s04.mat  time ->  17.364972829818726
# Processing deap_matlab_files/s05.mat ----------------
# record  s05.mat  time ->  18.46740436553955
# Processing deap_matlab_files/s06.mat ----------------
# record  s06.mat  time ->  19.600480318069458
# Processing deap_matlab_files/s07.mat ----------------
# record  s07.mat  time ->  18.88663101196289
# Processing deap_matlab_files/s08.mat ----------------
# record  s08.mat  time ->  18.027743101119995
# Processing deap_matlab_files/s09.mat ----------------
# record  s09.mat  time ->  17.482417106628418
# Processing deap_matlab_files/s10.mat ----------------
# record  s10.mat  time ->  17.80183720588684
# Processing deap_matlab_files/s11.mat ----------------
# record  s11.mat  time ->  16.979138374328613
# Processing deap_matlab_files/s12.mat ----------------
# record  s12.mat  time ->  18.1284077167511
# Processing deap_matlab_files/s13.mat ----------------
# record  s13.mat  time ->  16.98394465446472
# Processing deap_matlab_files/s14.mat ----------------
# record  s14.mat  time ->  17.37206244468689
# Processing deap_matlab_files/s15.mat ----------------
# record  s15.mat  time ->  16.80392336845398
# Processing deap_matlab_files/s16.mat ----------------
# record  s16.mat  time ->  16.614519357681274
# Processing deap_matlab_files/s17.mat ----------------
# record  s17.mat  time ->  16.510786533355713
# Processing deap_matlab_files/s18.mat ----------------
# record  s18.mat  time ->  17.26582670211792
# Processing deap_matlab_files/s19.mat ----------------
# record  s19.mat  time ->  17.910618543624878
# Processing deap_matlab_files/s20.mat ----------------
# record  s20.mat  time ->  17.827372312545776
# Processing deap_matlab_files/s21.mat ----------------
# record  s21.mat  time ->  16.83748769760132
# Processing deap_matlab_files/s22.mat ----------------
# record  s22.mat  time ->  16.72365379333496
# Processing deap_matlab_files/s23.mat ----------------
# record  s23.mat  time ->  16.944827556610107
# Processing deap_matlab_files/s24.mat ----------------
# record  s24.mat  time ->  17.075860023498535
# Processing deap_matlab_files/s25.mat ----------------
# record  s25.mat  time ->  16.9671847820282
# Processing deap_matlab_files/s26.mat ----------------
# record  s26.mat  time ->  17.05925440788269
# Processing deap_matlab_files/s27.mat ----------------
# record  s27.mat  time ->  16.781977653503418
# Processing deap_matlab_files/s28.mat ----------------
# record  s28.mat  time ->  16.915697813034058
# Processing deap_matlab_files/s29.mat ----------------
# record  s29.mat  time ->  17.09981060028076
# Processing deap_matlab_files/s30.mat ----------------
# record  s30.mat  time ->  16.754944324493408
# Processing deap_matlab_files/s31.mat ----------------
# record  s31.mat  time ->  16.997544527053833
# Processing deap_matlab_files/s32.mat ----------------
# record  s32.mat  time ->  17.326849460601807
# combination time ->  555.3240728378296
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# label_class =  arousal suffix =  no
# Processing deap_matlab_files/s01.mat ----------------
# record  s01.mat  time ->  16.79819941520691
# Processing deap_matlab_files/s02.mat ----------------
# record  s02.mat  time ->  16.860760927200317
# Processing deap_matlab_files/s03.mat ----------------
# record  s03.mat  time ->  19.19351863861084
# Processing deap_matlab_files/s04.mat ----------------
# record  s04.mat  time ->  18.16886258125305
# Processing deap_matlab_files/s05.mat ----------------
# record  s05.mat  time ->  17.981866359710693
# Processing deap_matlab_files/s06.mat ----------------
# record  s06.mat  time ->  17.893263816833496
# Processing deap_matlab_files/s07.mat ----------------
# record  s07.mat  time ->  18.147798776626587
# Processing deap_matlab_files/s08.mat ----------------
# record  s08.mat  time ->  18.39788842201233
# Processing deap_matlab_files/s09.mat ----------------
# record  s09.mat  time ->  17.885955810546875
# Processing deap_matlab_files/s10.mat ----------------
# record  s10.mat  time ->  17.4323947429657
# Processing deap_matlab_files/s11.mat ----------------
# record  s11.mat  time ->  16.898549556732178
# Processing deap_matlab_files/s12.mat ----------------
# record  s12.mat  time ->  16.763200044631958
# Processing deap_matlab_files/s13.mat ----------------
# record  s13.mat  time ->  16.901909351348877
# Processing deap_matlab_files/s14.mat ----------------
# record  s14.mat  time ->  17.205400705337524
# Processing deap_matlab_files/s15.mat ----------------
# record  s15.mat  time ->  16.755531072616577
# Processing deap_matlab_files/s16.mat ----------------
# record  s16.mat  time ->  16.936474561691284
# Processing deap_matlab_files/s17.mat ----------------
# record  s17.mat  time ->  16.94460391998291
# Processing deap_matlab_files/s18.mat ----------------
# record  s18.mat  time ->  17.151085376739502
# Processing deap_matlab_files/s19.mat ----------------
# record  s19.mat  time ->  17.016589164733887
# Processing deap_matlab_files/s20.mat ----------------
# record  s20.mat  time ->  17.390841245651245
# Processing deap_matlab_files/s21.mat ----------------
# record  s21.mat  time ->  17.320030450820923
# Processing deap_matlab_files/s22.mat ----------------
# record  s22.mat  time ->  17.60883665084839
# Processing deap_matlab_files/s23.mat ----------------
# record  s23.mat  time ->  18.123413801193237
# Processing deap_matlab_files/s24.mat ----------------
# record  s24.mat  time ->  17.9612033367157
# Processing deap_matlab_files/s25.mat ----------------
# record  s25.mat  time ->  18.091219425201416
# Processing deap_matlab_files/s26.mat ----------------
# record  s26.mat  time ->  18.046663284301758
# Processing deap_matlab_files/s27.mat ----------------
# record  s27.mat  time ->  19.75441861152649
# Processing deap_matlab_files/s28.mat ----------------
# record  s28.mat  time ->  20.48089861869812
# Processing deap_matlab_files/s29.mat ----------------
# record  s29.mat  time ->  22.593175888061523
# Processing deap_matlab_files/s30.mat ----------------
# record  s30.mat  time ->  23.759069204330444
# Processing deap_matlab_files/s31.mat ----------------
# record  s31.mat  time ->  20.8762845993042
# Processing deap_matlab_files/s32.mat ----------------
# record  s32.mat  time ->  18.454456567764282
# combination time ->  581.8063366413116
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# label_class =  arousal suffix =  yes
# Processing deap_matlab_files/s01.mat ----------------
# record  s01.mat  time ->  18.977498054504395
# Processing deap_matlab_files/s02.mat ----------------
# record  s02.mat  time ->  18.34005069732666
# Processing deap_matlab_files/s03.mat ----------------
# record  s03.mat  time ->  18.157771110534668
# Processing deap_matlab_files/s04.mat ----------------
# record  s04.mat  time ->  18.852688312530518
# Processing deap_matlab_files/s05.mat ----------------
# record  s05.mat  time ->  18.231125354766846
# Processing deap_matlab_files/s06.mat ----------------
# record  s06.mat  time ->  18.218679666519165
# Processing deap_matlab_files/s07.mat ----------------
# record  s07.mat  time ->  18.1527578830719
# Processing deap_matlab_files/s08.mat ----------------
# record  s08.mat  time ->  18.248689651489258
# Processing deap_matlab_files/s09.mat ----------------
# record  s09.mat  time ->  18.34087610244751
# Processing deap_matlab_files/s10.mat ----------------
# record  s10.mat  time ->  18.906326293945312
# Processing deap_matlab_files/s11.mat ----------------
# record  s11.mat  time ->  21.05436062812805
# Processing deap_matlab_files/s12.mat ----------------
# record  s12.mat  time ->  21.840376138687134
# Processing deap_matlab_files/s13.mat ----------------
# record  s13.mat  time ->  19.497548580169678
# Processing deap_matlab_files/s14.mat ----------------
# record  s14.mat  time ->  19.72297739982605
# Processing deap_matlab_files/s15.mat ----------------
# record  s15.mat  time ->  18.744076251983643
# Processing deap_matlab_files/s16.mat ----------------
# record  s16.mat  time ->  20.383167505264282
# Processing deap_matlab_files/s17.mat ----------------
# record  s17.mat  time ->  20.52870464324951
# Processing deap_matlab_files/s18.mat ----------------
# record  s18.mat  time ->  19.915772438049316
# Processing deap_matlab_files/s19.mat ----------------
# record  s19.mat  time ->  20.06629228591919
# Processing deap_matlab_files/s20.mat ----------------
# record  s20.mat  time ->  21.124812364578247
# Processing deap_matlab_files/s21.mat ----------------
# record  s21.mat  time ->  21.416564464569092
# Processing deap_matlab_files/s22.mat ----------------
# record  s22.mat  time ->  20.05518388748169
# Processing deap_matlab_files/s23.mat ----------------
# record  s23.mat  time ->  20.199448347091675
# Processing deap_matlab_files/s24.mat ----------------
# record  s24.mat  time ->  20.55635905265808
# Processing deap_matlab_files/s25.mat ----------------
# record  s25.mat  time ->  19.96720290184021
# Processing deap_matlab_files/s26.mat ----------------
# record  s26.mat  time ->  18.81629180908203
# Processing deap_matlab_files/s27.mat ----------------
# record  s27.mat  time ->  21.22307586669922
# Processing deap_matlab_files/s28.mat ----------------
# record  s28.mat  time ->  19.752260208129883
# Processing deap_matlab_files/s29.mat ----------------
# record  s29.mat  time ->  20.812655687332153
# Processing deap_matlab_files/s30.mat ----------------
# record  s30.mat  time ->  18.68911361694336
# Processing deap_matlab_files/s31.mat ----------------
# record  s31.mat  time ->  18.679473638534546
# Processing deap_matlab_files/s32.mat ----------------
# record  s32.mat  time ->  18.68397331237793
# combination time ->  626.1708598136902
# ----------------------------------------------------------------
# total time ->  2318.9093430042267

# %%
3778.8399555683136/60.0
# Out:
# 62.98066592613856

# %%
2318.9093430042267/60
# Out:
# 38.648489050070445
